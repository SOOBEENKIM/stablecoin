# %%
# %pip install pandas

# %%
import pandas as pd

# %%
# 1. CSV 불러오기
df = pd.read_csv('USDKRW.csv', header=None)

# 2. 컬럼명 지정
df.columns = ['datetime', 'price']

# 3. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 4. CSV로 저장
df.to_csv('USDKRW_clean.csv', index=False)

# %%
# 1. CSV 불러오기
df = pd.read_csv('VIXY.csv', header=None)

# 2. 컬럼명 지정
df.columns = ['datetime', 'price']

# 3. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 4. CSV로 저장
df.to_csv('VIXY_clean.csv', index=False)

# %%
# 1. CSV 불러오기
df = pd.read_csv('SPY US.csv', header=None)

# 2. 컬럼명 지정
df.columns = ['datetime', 'open', 'high', 'low', 'close']

# 3. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 4. CSV로 저장
df.to_csv('SPY US_clean.csv', index=False)

# %%
# 1. CSV 불러오기
df = pd.read_csv('DXY.csv', header=None)

# 2. 컬럼명 지정
df.columns = ['datetime', 'price']

# 3. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 4. CSV로 저장
df.to_csv('DXY_clean.csv', index=False)

# %%
# 1. CSV 불러오기
df = pd.read_csv('XAUUSD.csv', header=None)

# 2. 컬럼명 지정
df.columns = ['datetime', 'open', 'high', 'low', 'close']

# 3. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 4. CSV로 저장
df.to_csv('XAUUSD_clean.csv', index=False)

# %%
# 1. clean 파일 불러오기
df = pd.read_csv('USDKRW_clean.csv')

# 2. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 3. 정렬
df = df.sort_values('datetime')

# 4. index 설정
df = df.set_index('datetime')

# 5. 전체 1시간 단위 index 생성
full_index = pd.date_range(start=df.index.min(),
                           end=df.index.max(),
                           freq='1h')

# 6. reindex -> NaN 행 생성
df = df.reindex(full_index)

# 7. 다시 datetime 컬럼으로 돌리기
df = df.reset_index()
df = df.rename(columns={'index': 'datetime'})
df.to_csv('USDKRW_clean.csv', index=False)

# %%
# 1. 파일 불러오기
df = pd.read_csv('VIXY_clean.csv')

# 2. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')

# 3. datetime이 비어 있는 행 제거
df = df.dropna(subset=['datetime'])

# 4. 정렬
df = df.sort_values('datetime')

# 5. index 설정
df = df.set_index('datetime')

# 6. 시작 시각의 분(minute) 기준 잡기
minute_offset = df.index.min().minute
start = df.index.min().floor('h') + pd.Timedelta(minutes=minute_offset)

if start < df.index.min():
    start += pd.Timedelta(hours=1)

# 7. 전체 1시간 간격 index 생성
full_index = pd.date_range(
    start=start,
    end=df.index.max(),
    freq='1h'
)

# 8. 없는 시간 NaN 행 생성
df = df.reindex(full_index)

# 9. 다시 datetime 컬럼으로 복구
df = df.reset_index().rename(columns={'index': 'datetime'})

# 10. 저장
df.to_csv('VIXY_clean_1.csv', index=False)

# %%
# 1. 파일 불러오기
df = pd.read_csv('SPY US_clean.csv')

# 2. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')

# 3. datetime이 비어 있는 행 제거
df = df.dropna(subset=['datetime'])

# 4. 중복 datetime 제거
df = df.drop_duplicates(subset=['datetime'], keep='last')

# 5. 정렬
df = df.sort_values('datetime')

# 6. index 설정
df = df.set_index('datetime')

# 7. 시작 시각의 분(minute) 기준 잡기
minute_offset = df.index.min().minute
start = df.index.min().floor('h') + pd.Timedelta(minutes=minute_offset)

if start < df.index.min():
    start += pd.Timedelta(hours=1)

# 8. 전체 1시간 간격 index 생성
full_index = pd.date_range(
    start=start,
    end=df.index.max(),
    freq='1h'
)

# 9. 없는 시간 NaN 행 생성
df = df.reindex(full_index)

# 10. 다시 datetime 컬럼으로 복구
df = df.reset_index().rename(columns={'index': 'datetime'})

# 11. 저장
df.to_csv('SPY_clean_1.csv', index=False)

# %%
# 1. 파일 불러오기
df = pd.read_csv('DXY_clean.csv')

# 2. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')

# 3. datetime이 비어 있는 행 제거
df = df.dropna(subset=['datetime'])

# 4. 중복 datetime 제거
df = df.drop_duplicates(subset=['datetime'], keep='last')

# 5. 정렬
df = df.sort_values('datetime')

# 6. index 설정
df = df.set_index('datetime')

# 7. 시작 시각의 분(minute) 기준 잡기
minute_offset = df.index.min().minute
start = df.index.min().floor('h') + pd.Timedelta(minutes=minute_offset)

if start < df.index.min():
    start += pd.Timedelta(hours=1)

# 8. 전체 1시간 간격 index 생성
full_index = pd.date_range(
    start=start,
    end=df.index.max(),
    freq='1h'
)

# 9. 없는 시간 NaN 행 생성
df = df.reindex(full_index)

# 10. 다시 datetime 컬럼으로 복구
df = df.reset_index().rename(columns={'index': 'datetime'})

# 11. 저장
df.to_csv('DXY_clean_1.csv', index=False)

# %%
# 1. clean 파일 불러오기
df = pd.read_csv('XAUUSD_clean.csv')

# 2. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')

# 3. datetime 비어있거나 깨진 행 제거
df = df.dropna(subset=['datetime'])

# 4. 같은 datetime 중복 제거
df = df.drop_duplicates(subset='datetime', keep='last')

# 5. 정렬
df = df.sort_values('datetime')

# 6. index 설정
df = df.set_index('datetime')

# 7. 전체 1시간 단위 index 생성
full_index = pd.date_range(
    start=df.index.min(),
    end=df.index.max(),
    freq='1h'
)

# 8. reindex -> NaN 행 생성
df = df.reindex(full_index)

# 9. 다시 datetime 컬럼으로 돌리기
df = df.reset_index().rename(columns={'index': 'datetime'})

# 10. 저장
df.to_csv('XAUUSD_clean_1.csv', index=False)

# %%
df = pd.read_csv('XAUUSD_clean_1.csv')

# 1. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 2. 정렬
df = df.sort_values('datetime')

# 3. index 설정
df = df.set_index('datetime')

print("NaN 개수:")
print(df.isna().sum())
print("중복 datetime 존재 여부:", df.index.duplicated().any())
time_diff = df.index.to_series().diff().dropna()
print(time_diff.value_counts().head())
print(time_diff[time_diff != pd.Timedelta(hours=1)].head(20))
print("시작:", df.index.min())
print("끝:", df.index.max())

is_nan = df['close'].isna()

groups = (is_nan != is_nan.shift()).cumsum()
nan_blocks = df[is_nan].groupby(groups).size()

print("연속 NaN 구간:")
print(nan_blocks.head())

print(df[df['close'].isna()].head(50))
# Out:
# NaN 개수:
# open     2209
# high     2209
# low      2209
# close    2209
# dtype: int64
# 중복 datetime 존재 여부: False
# datetime
# 0 days 01:00:00    6991
# Name: count, dtype: int64
# Series([], Name: datetime, dtype: timedelta64[ns])
# 시작: 2025-06-01 18:00:00
# 끝: 2026-03-20 01:00:00
# 연속 NaN 구간:
# close
# 2     49
# 4     49
# 6      1
# 8      1
# 10     1
# dtype: int64
#                      open  high  low  close
# datetime
# 2025-06-06 17:00:00   NaN   NaN  NaN    NaN
# 2025-06-06 18:00:00   NaN   NaN  NaN    NaN
# 2025-06-06 19:00:00   NaN   NaN  NaN    NaN
# 2025-06-06 20:00:00   NaN   NaN  NaN    NaN
# 2025-06-06 21:00:00   NaN   NaN  NaN    NaN
# 2025-06-06 22:00:00   NaN   NaN  NaN    NaN
# 2025-06-06 23:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 00:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 01:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 02:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 03:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 04:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 05:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 06:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 07:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 08:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 09:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 10:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 11:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 12:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 13:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 14:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 15:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 16:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 17:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 18:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 19:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 20:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 21:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 22:00:00   NaN   NaN  NaN    NaN
# 2025-06-07 23:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 00:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 01:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 02:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 03:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 04:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 05:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 06:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 07:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 08:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 09:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 10:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 11:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 12:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 13:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 14:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 15:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 16:00:00   NaN   NaN  NaN    NaN
# 2025-06-08 17:00:00   NaN   NaN  NaN    NaN
# 2025-06-13 17:00:00   NaN   NaN  NaN    NaN

# %%
df = pd.read_csv('DXY_clean_1.csv')

# 1. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 2. 정렬
df = df.sort_values('datetime')

# 3. index 설정
df = df.set_index('datetime')

print("NaN 개수:")
print(df.isna().sum())
print("중복 datetime 존재 여부:", df.index.duplicated().any())

time_diff = df.index.to_series().diff().dropna()
print(time_diff.value_counts().head())

print(time_diff[time_diff != pd.Timedelta(hours=1)].head(20))

print("시작:", df.index.min())
print("끝:", df.index.max())

is_nan = df['price'].isna()

groups = (is_nan != is_nan.shift()).cumsum()
nan_blocks = df[is_nan].groupby(groups).size()

print("연속 NaN 구간:")
print(nan_blocks.head())

print(df[df['price'].isna()].head(50))
# Out:
# NaN 개수:
# price    2505
# dtype: int64
# 중복 datetime 존재 여부: False
# datetime
# 0 days 01:00:00    7301
# Name: count, dtype: int64
# Series([], Name: datetime, dtype: timedelta64[ns])
# 시작: 2025-05-19 19:30:00
# 끝: 2026-03-20 00:30:00
# 연속 NaN 구간:
# price
# 2      2
# 4      2
# 6      2
# 8     49
# 10     2
# dtype: int64
#                      price
# datetime
# 2025-05-20 17:30:00    NaN
# 2025-05-20 18:30:00    NaN
# 2025-05-21 17:30:00    NaN
# 2025-05-21 18:30:00    NaN
# 2025-05-22 17:30:00    NaN
# 2025-05-22 18:30:00    NaN
# 2025-05-23 17:30:00    NaN
# 2025-05-23 18:30:00    NaN
# 2025-05-23 19:30:00    NaN
# 2025-05-23 20:30:00    NaN
# 2025-05-23 21:30:00    NaN
# 2025-05-23 22:30:00    NaN
# 2025-05-23 23:30:00    NaN
# 2025-05-24 00:30:00    NaN
# 2025-05-24 01:30:00    NaN
# 2025-05-24 02:30:00    NaN
# 2025-05-24 03:30:00    NaN
# 2025-05-24 04:30:00    NaN
# 2025-05-24 05:30:00    NaN
# 2025-05-24 06:30:00    NaN
# 2025-05-24 07:30:00    NaN
# 2025-05-24 08:30:00    NaN
# 2025-05-24 09:30:00    NaN
# 2025-05-24 10:30:00    NaN
# 2025-05-24 11:30:00    NaN
# 2025-05-24 12:30:00    NaN
# 2025-05-24 13:30:00    NaN
# 2025-05-24 14:30:00    NaN
# 2025-05-24 15:30:00    NaN
# 2025-05-24 16:30:00    NaN
# 2025-05-24 17:30:00    NaN
# 2025-05-24 18:30:00    NaN
# 2025-05-24 19:30:00    NaN
# 2025-05-24 20:30:00    NaN
# 2025-05-24 21:30:00    NaN
# 2025-05-24 22:30:00    NaN
# 2025-05-24 23:30:00    NaN
# 2025-05-25 00:30:00    NaN
# 2025-05-25 01:30:00    NaN
# 2025-05-25 02:30:00    NaN
# 2025-05-25 03:30:00    NaN
# 2025-05-25 04:30:00    NaN
# 2025-05-25 05:30:00    NaN
# 2025-05-25 06:30:00    NaN
# 2025-05-25 07:30:00    NaN
# 2025-05-25 08:30:00    NaN
# 2025-05-25 09:30:00    NaN
# 2025-05-25 10:30:00    NaN
# 2025-05-25 11:30:00    NaN
# 2025-05-25 12:30:00    NaN

# %%
df = pd.read_csv('SPY_clean_1.csv')

# 1. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 2. 정렬
df = df.sort_values('datetime')

# 3. index 설정
df = df.set_index('datetime')

print("NaN 개수:")
print(df.isna().sum())
print("중복 datetime 존재 여부:", df.index.duplicated().any())

time_diff = df.index.to_series().diff().dropna()
print(time_diff.value_counts().head())

print(time_diff[time_diff != pd.Timedelta(hours=1)].head(20))

print("시작:", df.index.min())
print("끝:", df.index.max())

is_nan = df['close'].isna()

groups = (is_nan != is_nan.shift()).cumsum()
nan_blocks = df[is_nan].groupby(groups).size()

print("연속 NaN 구간:")
print(nan_blocks.head())

print(df[df['close'].isna()].head(50))
# Out:
# NaN 개수:
# open     5180
# high     5180
# low      5180
# close    5180
# dtype: int64
# 중복 datetime 존재 여부: False
# datetime
# 0 days 01:00:00    7546
# Name: count, dtype: int64
# Series([], Name: datetime, dtype: timedelta64[ns])
# 시작: 2025-05-09 09:30:00
# 끝: 2026-03-19 19:30:00
# 연속 NaN 구간:
# close
# 2     61
# 4     13
# 6     13
# 8     13
# 10    13
# dtype: int64
#                      open  high  low  close
# datetime
# 2025-05-09 20:30:00   NaN   NaN  NaN    NaN
# 2025-05-09 21:30:00   NaN   NaN  NaN    NaN
# 2025-05-09 22:30:00   NaN   NaN  NaN    NaN
# 2025-05-09 23:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 00:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 01:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 02:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 03:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 04:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 05:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 06:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 07:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 08:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 09:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 10:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 11:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 12:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 13:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 14:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 15:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 16:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 17:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 18:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 19:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 20:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 21:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 22:30:00   NaN   NaN  NaN    NaN
# 2025-05-10 23:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 00:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 01:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 02:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 03:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 04:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 05:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 06:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 07:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 08:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 09:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 10:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 11:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 12:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 13:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 14:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 15:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 16:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 17:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 18:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 19:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 20:30:00   NaN   NaN  NaN    NaN
# 2025-05-11 21:30:00   NaN   NaN  NaN    NaN

# %%
df = pd.read_csv('VIXY_clean_1.csv')

# 1. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 2. 정렬
df = df.sort_values('datetime')

# 3. index 설정
df = df.set_index('datetime')

print("NaN 개수:")
print(df.isna().sum())
print("중복 datetime 존재 여부:", df.index.duplicated().any())

time_diff = df.index.to_series().diff().dropna()
print(time_diff.value_counts().head())

print(time_diff[time_diff != pd.Timedelta(hours=1)].head(20))

print("시작:", df.index.min())
print("끝:", df.index.max())

is_nan = df['price'].isna()

groups = (is_nan != is_nan.shift()).cumsum()
nan_blocks = df[is_nan].groupby(groups).size()

print("연속 NaN 구간:")
print(nan_blocks.head())

print(df[df['price'].isna()].head(50))
# Out:
# NaN 개수:
# price    4306
# dtype: int64
# 중복 datetime 존재 여부: False
# datetime
# 0 days 01:00:00    7285
# Name: count, dtype: int64
# Series([], Name: datetime, dtype: timedelta64[ns])
# 시작: 2025-05-20 03:15:00
# 끝: 2026-03-19 16:15:00
# 연속 NaN 구간:
# price
# 2     10
# 4     10
# 6     10
# 8     58
# 10    15
# dtype: int64
#                      price
# datetime
# 2025-05-20 17:15:00    NaN
# 2025-05-20 18:15:00    NaN
# 2025-05-20 19:15:00    NaN
# 2025-05-20 20:15:00    NaN
# 2025-05-20 21:15:00    NaN
# 2025-05-20 22:15:00    NaN
# 2025-05-20 23:15:00    NaN
# 2025-05-21 00:15:00    NaN
# 2025-05-21 01:15:00    NaN
# 2025-05-21 02:15:00    NaN
# 2025-05-21 17:15:00    NaN
# 2025-05-21 18:15:00    NaN
# 2025-05-21 19:15:00    NaN
# 2025-05-21 20:15:00    NaN
# 2025-05-21 21:15:00    NaN
# 2025-05-21 22:15:00    NaN
# 2025-05-21 23:15:00    NaN
# 2025-05-22 00:15:00    NaN
# 2025-05-22 01:15:00    NaN
# 2025-05-22 02:15:00    NaN
# 2025-05-22 17:15:00    NaN
# 2025-05-22 18:15:00    NaN
# 2025-05-22 19:15:00    NaN
# 2025-05-22 20:15:00    NaN
# 2025-05-22 21:15:00    NaN
# 2025-05-22 22:15:00    NaN
# 2025-05-22 23:15:00    NaN
# 2025-05-23 00:15:00    NaN
# 2025-05-23 01:15:00    NaN
# 2025-05-23 02:15:00    NaN
# 2025-05-23 17:15:00    NaN
# 2025-05-23 18:15:00    NaN
# 2025-05-23 19:15:00    NaN
# 2025-05-23 20:15:00    NaN
# 2025-05-23 21:15:00    NaN
# 2025-05-23 22:15:00    NaN
# 2025-05-23 23:15:00    NaN
# 2025-05-24 00:15:00    NaN
# 2025-05-24 01:15:00    NaN
# 2025-05-24 02:15:00    NaN
# 2025-05-24 03:15:00    NaN
# 2025-05-24 04:15:00    NaN
# 2025-05-24 05:15:00    NaN
# 2025-05-24 06:15:00    NaN
# 2025-05-24 07:15:00    NaN
# 2025-05-24 08:15:00    NaN
# 2025-05-24 09:15:00    NaN
# 2025-05-24 10:15:00    NaN
# 2025-05-24 11:15:00    NaN
# 2025-05-24 12:15:00    NaN

# %%
df = pd.read_csv('USDKRW_clean.csv')

# 1. datetime 변환
df['datetime'] = pd.to_datetime(df['datetime'])

# 2. 정렬
df = df.sort_values('datetime')

# 3. index 설정
df = df.set_index('datetime')

print("NaN 개수:")
print(df.isna().sum())
print("중복 datetime 존재 여부:", df.index.duplicated().any())

time_diff = df.index.to_series().diff().dropna()
print(time_diff.value_counts().head())

print(time_diff[time_diff != pd.Timedelta(hours=1)].head(20))

print("시작:", df.index.min())
print("끝:", df.index.max())

is_nan = df['price'].isna()

groups = (is_nan != is_nan.shift()).cumsum()
nan_blocks = df[is_nan].groupby(groups).size()

print("연속 NaN 구간:")
print(nan_blocks.head())

print(df[df['price'].isna()].head(50))
# Out:
# NaN 개수:
# price    3674
# dtype: int64
# 중복 datetime 존재 여부: False
# datetime
# 0 days 01:00:00    7276
# Name: count, dtype: int64
# Series([], Name: datetime, dtype: timedelta64[ns])
# 시작: 2025-05-20 20:00:00
# 끝: 2026-03-20 00:00:00
# 연속 NaN 구간:
# price
# 2      7
# 4      7
# 6     55
# 8      7
# 10     7
# dtype: int64
#                      price
# datetime
# 2025-05-21 13:00:00    NaN
# 2025-05-21 14:00:00    NaN
# 2025-05-21 15:00:00    NaN
# 2025-05-21 16:00:00    NaN
# 2025-05-21 17:00:00    NaN
# 2025-05-21 18:00:00    NaN
# 2025-05-21 19:00:00    NaN
# 2025-05-22 13:00:00    NaN
# 2025-05-22 14:00:00    NaN
# 2025-05-22 15:00:00    NaN
# 2025-05-22 16:00:00    NaN
# 2025-05-22 17:00:00    NaN
# 2025-05-22 18:00:00    NaN
# 2025-05-22 19:00:00    NaN
# 2025-05-23 13:00:00    NaN
# 2025-05-23 14:00:00    NaN
# 2025-05-23 15:00:00    NaN
# 2025-05-23 16:00:00    NaN
# 2025-05-23 17:00:00    NaN
# 2025-05-23 18:00:00    NaN
# 2025-05-23 19:00:00    NaN
# 2025-05-23 20:00:00    NaN
# 2025-05-23 21:00:00    NaN
# 2025-05-23 22:00:00    NaN
# 2025-05-23 23:00:00    NaN
# 2025-05-24 00:00:00    NaN
# 2025-05-24 01:00:00    NaN
# 2025-05-24 02:00:00    NaN
# 2025-05-24 03:00:00    NaN
# 2025-05-24 04:00:00    NaN
# 2025-05-24 05:00:00    NaN
# 2025-05-24 06:00:00    NaN
# 2025-05-24 07:00:00    NaN
# 2025-05-24 08:00:00    NaN
# 2025-05-24 09:00:00    NaN
# 2025-05-24 10:00:00    NaN
# 2025-05-24 11:00:00    NaN
# 2025-05-24 12:00:00    NaN
# 2025-05-24 13:00:00    NaN
# 2025-05-24 14:00:00    NaN
# 2025-05-24 15:00:00    NaN
# 2025-05-24 16:00:00    NaN
# 2025-05-24 17:00:00    NaN
# 2025-05-24 18:00:00    NaN
# 2025-05-24 19:00:00    NaN
# 2025-05-24 20:00:00    NaN
# 2025-05-24 21:00:00    NaN
# 2025-05-24 22:00:00    NaN
# 2025-05-24 23:00:00    NaN
# 2025-05-25 00:00:00    NaN

# %% [markdown]
# [USDKRW]
# Following Kang et al. (2025), USD/KRW exchange rate data are aligned to a common time grid via resampling.
# In line with Choi et al. (2018), observations with missing values are excluded in the baseline specification.
# For robustness, forward-fill is applied during non-trading hours, while linear interpolation is avoided to prevent artificial exchange rate dynamics.
#
# -> 특히 USDKRW가 블룸버그 BGN/indicative 성격이면, 진짜 24/7 거래체결가격이라기보다 quote/state variable 성격이 강할 수 있어서, 짧은 공백에서 ffill을 robustness로 두는 건 이해 가능합니다. 다만 baseline에서 drop을 택할 거면, 왜 overlap-only가 필요한지를 분명히 써야 합니다. “Choi et al. (2018)”보다는 non-synchronous high-frequency alignment literature를 cite하는 편이 더 엄밀합니다.

# %% [markdown]
# [DXY]
# Similar to exchange rate variables, the Dollar Index (DXY) is treated as a traded financial variable with non-trading periods.
# Missing observations are excluded in the baseline following Choi et al. (2018), while forward-fill is used as a robustness approach.
# Linear interpolation is not applied to avoid introducing artificial price paths.
#
# -> DXY를 “exchange rate variables와 유사”하게 처리한 건 반은 맞고 반은 애매합니다. DXY 현물지수 자체보다 실제 거래 가능한 건 ICE Dollar Index futures 쪽이고, 이건 주중 거의 연속 거래지만 완전 24/7은 아닙니다. 그래서 DXY를 hourly로 쓸 때도, 주말·일부 휴장 구간엔 stale value가 생깁니다. 따라서 baseline overlap-only는 타당하고, ffill을 robustness로 두는 것도 가능하지만, 이것을 “exchange rate variable과 동일”하다고 단정하는 건 조금 거칩니다.

# %% [markdown]
# [XAUUSD]
# Gold prices (XAUUSD) are treated as continuously traded but still subject to liquidity variation across time zones.
# Following standard high-frequency finance practices, missing observations are excluded in the baseline, and forward-fill is used for robustness.
# Linear interpolation is avoided as it may distort return dynamics and volatility estimation.
#
# -> LBMA 설명대로 gold는 글로벌 OTC에서 사실상 24시간 거래되는 시장으로 이해할 수 있지만, 그래도 데이터 벤더/거래소별로 시간대별 공백과 liquidity 차이는 존재합니다. 그래서 선형보간 회피는 맞고, drop baseline + ffill robustness도 설명 가능합니다. 다만 XAUUSD는 SPY/VIX보다 훨씬 연속적인 시장이므로, 실제 결측 비율이 낮다면 baseline drop으로 인한 표본 손실이 상대적으로 덜할 수 있습니다.

# %% [markdown]
# [SPY (S&P ETF)] Equity market variables such as SPY are only traded during specific market hours.
# Therefore, non-trading periods are treated as missing observations and excluded in the baseline following Choi et al. (2018).
# Forward-fill is applied to maintain continuity in time-series alignment, while linear interpolation is avoided to prevent artificial price movement during market closure.
#
# -> SPY는 명백히 시장 폐장 시간이 존재하고, NYSE 기준 core 9:30–16:00 ET, extended도 20:00 ET까지만입니다. 이걸 hourly grid에 맞춰 ffill하면 밤새·주말 동안 인위적인 0수익률 구간이 길게 생깁니다. 이건 연속성 유지라는 장점은 있지만, return/VAR/volatility 분석에서는 자기상관, 변동성, shock timing을 왜곡할 수 있습니다. 그래서 SPY를 baseline에서 ffill하는 건, state variable로만 쓰는 경우엔 가능하지만, 연구가 stablecoin residual의 동학을 보는 계량분석이라면 baseline으로는 꽤 공격적입니다. baseline은 오히려 overlap-only가 더 안전합니다.

# %% [markdown]
# [VIX]
# The VIX index is treated as a state variable reflecting market-wide implied volatility.
# During non-trading periods, forward-fill is applied to preserve the latest observed market condition.
# Linear interpolation is avoided as it artificially smooths volatility dynamics and may bias econometric results.
#
# -> Cboe 기준 VIX 관련 상품과 지수는 과거보다 trading/calculation window가 넓지만, 네가 실제로 수집한 것이 cash VIX index인지 VIX futures인지에 따라 해석이 달라집니다. cash VIX를 단순 ffill하면 폐장 구간 state persistence를 가정하는 셈인데, overnight news가 클 경우 실제 위험 인식 변화를 놓칠 수 있습니다. 반면 Cboe는 VIX index가 overnight에도 disseminated된다고 안내하고, VIX futures도 거의 23시간 거래됩니다. 즉, 굳이 VIX를 hourly로 넣고 싶다면 cash VIX ffill보다 VX futures 또는 overnight-disseminated VIX series 사용이 더 낫습니다.

# %% [markdown]
# baseline은 전 변수 공통으로 overlap-only/common-support가 가장 엄밀하다.
# forward-fill은 robustness check로 두는 게 맞다.
# linear interpolation은 하지 않는 게 맞다.
# 다만, 전에 말했던 “SPY/VIX도 baseline overlap-only”는 네 연구 목적상 여전히 맞지만, 한 가지 보완이 필요하다.
# 가능하면 SPY 현물 ETF, cash VIX 대신 24시간에 더 가까운 대체지표(선물 기반 proxy)를 쓰는 것이 더 좋다.
# 즉, 방향은 유지되지만, 연구처럼 quantile / tail / persistence를 보는 경우에는 ffill의 위험성을 생각한 것보다 더 강하게 경계해야 한다고 보는 게 맞다.

# %% [markdown]
# [ 연구 설계 ]
#
# USDT 김치프리미엄에서 시장 공통 김치프리미엄을 제거하고 residual을 만든 뒤 그 변화량 ΔResidual이 어떤 스트레스 상황에서 더 크게 튀고 더 오래 남는지를 Quantile Regression / Quantile VAR로 보겠다.
# 즉, “baseline overlap-only, ffill robustness” 로 데이터 처리 해야함.
#
# 왜 어떤 시점에 residual이 크게 발생하는가, 왜 어떤 때는 더 오래 지속되는가 가 연구 질문임.
#
# 설명변수는 동시값보다 직전 시점의 값(lag)을 중심으로 쓸 예정. 단순 ffill하면, lag structure가 실제 경제적 동학이 아니라 시장 폐장 때문에 생긴 인공적 persistence를 반영하게 됨.
#
# 즉, lagged explanatory variables, persistence analysis, quantile dynamics 를 동시에 쓰는 경우엔, baseline을 overlap-only로 두는 쪽이 훨씬 방어적임.

# %% [markdown]
# Major Issues in High-Frequency Financial Data Analysis by L Zhang 2025
#
# -> asynchronous data (비동기 데이터) :
#
# - 서로 다른 자산이 다른 시각에 관측됨
# - 이걸 그대로 쓰면 lead-lag bias 발생
#
# 그래서 문헌에서는 :
#
# - 01:30 → “01:00~02:00 구간의 대표값”
# - 07:15 → “07:00~08:00 구간의 대표값”

# %%
import numpy as np

# %%
# def preprocess(path, col_name):
#     df = pd.read_csv(path)
#     df['datetime'] = pd.to_datetime(df['datetime'])
#     df = df.sort_values('datetime')

#     # 어떤 가격 컬럼을 쓸지 결정
#     if 'price' in df.columns:
#         value_col = 'price'
#     elif 'close' in df.columns:
#         value_col = 'close'
#     else:
#         raise ValueError(f"{path} 에서 사용할 가격 컬럼(price 또는 close)을 찾지 못함. 현재 컬럼: {list(df.columns)}")

#     df = df[['datetime', value_col]].dropna()
#     df = df.set_index('datetime')

#     # 1시간 bin의 마지막 관측값 사용
#     df = df.resample('1h').last()

#     # 최종 컬럼명 통일
#     df = df.rename(columns={value_col: col_name})

#     return df
def preprocess(path, col_name):
    df = pd.read_csv(path)
    df['datetime'] = pd.to_datetime(df['datetime'], utc=True)
    df = df.sort_values('datetime')

    if 'price' in df.columns:
        value_col = 'price'
    elif 'close' in df.columns:
        value_col = 'close'
    else:
        raise ValueError(
            f"{path} 에서 사용할 가격 컬럼(price 또는 close)을 찾지 못함. "
            f"현재 컬럼: {list(df.columns)}"
        )

    df = df[['datetime', value_col]].dropna()
    df = df.set_index('datetime')

    # 동일 timestamp 중복 제거
    df = df[~df.index.duplicated(keep='last')]

    # 1시간 bin 마지막 관측값 사용
    df = df.resample('1h').last()

    df = df.rename(columns={value_col: col_name})
    return df

# %%
# usdkrw = preprocess("USDKRW_clean.csv", "USDKRW")
# vix    = preprocess("VIXY_clean_1.csv", "VIX")
# spy    = preprocess("SPY_clean_1.csv", "SPY")
# dxy    = preprocess("DXY_clean_1.csv", "DXY")
# xau    = preprocess("XAUUSD_clean_1.csv", "XAUUSD")

# df = pd.concat([usdkrw, vix, spy, dxy, xau], axis=1, sort=True)
# df = df.sort_index()

# df = df.loc["2025-06-01 18:00":"2026-03-19 16:00"]
# data_baseline = df.dropna()
# df_ffill = df.copy()

# cols = ['USDKRW','VIX','SPY','DXY','XAUUSD']

# for col in cols:
#     df_ffill[f'{col}_stale'] = df_ffill[col].isna().astype(int)

# df_ffill[cols] = df_ffill[cols].ffill(limit=1)

# data_robust = df_ffill.dropna()

usdkrw = preprocess("USDKRW_clean.csv", "USDKRW")
vix    = preprocess("VIXY_clean_1.csv", "VIX")
spy    = preprocess("SPY_clean_1.csv", "SPY")
dxy    = preprocess("DXY_clean_1.csv", "DXY")
xau    = preprocess("XAUUSD_clean_1.csv", "XAUUSD")

# 공통 panel 생성
df = pd.concat([usdkrw, vix, spy, dxy, xau], axis=1, sort=True)
df = df.sort_index()

# 분석 표본 구간 제한
start = "2025-06-01 18:00:00+00:00"
end   = "2026-03-19 16:00:00+00:00"
df = df.loc[start:end]

print(df.head())
print(df.columns.tolist())
print(df.shape)

# baseline: overlap-only
data_baseline = df.dropna().copy()

# robustness: bounded ffill + stale flag
FFILL_LIMIT = 1
cols = ["USDKRW", "VIX", "SPY", "DXY", "XAUUSD"]

df_ffill = df.copy()

for col in cols:
    df_ffill[f"{col}_stale_flag"] = df_ffill[col].isna().astype(int)

df_ffill[cols] = df_ffill[cols].ffill(limit=FFILL_LIMIT)
data_robust = df_ffill.dropna().copy()

print("baseline shape:", data_baseline.shape)
print("robust shape  :", data_robust.shape)
# Out:
#                             USDKRW  VIX  SPY     DXY   XAUUSD
# datetime
# 2025-06-01 18:00:00+00:00      NaN  NaN  NaN  99.340  3313.04
# 2025-06-01 19:00:00+00:00      NaN  NaN  NaN  99.215  3310.01
# 2025-06-01 20:00:00+00:00  1377.81  NaN  NaN  99.123  3311.67
# 2025-06-01 21:00:00+00:00  1378.93  NaN  NaN  99.236  3303.48
# 2025-06-01 22:00:00+00:00  1378.50  NaN  NaN  99.303  3307.23
# ['USDKRW', 'VIX', 'SPY', 'DXY', 'XAUUSD']
# (6983, 5)
# baseline shape: (719, 5)
# robust shape  : (920, 10)

# %% [markdown]
# [ USDKRW, VIX, SPY, DXY, XAUUSD를 1시간 단위 공통 패널로 정리한 뒤, 완전 겹치는 시점만 쓰는 baseline 표본과, 1시간 이내 짧은 결측만 forward fill한 robustness 표본을 만드는 코드임. ]

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['USDKRW', 'VIX', 'SPY', 'DXY', 'XAUUSD'], dtype='object')
#                             USDKRW  VIX  SPY     DXY   XAUUSD
# datetime
# 2025-06-01 18:00:00+00:00      NaN  NaN  NaN  99.340  3313.04
# 2025-06-01 19:00:00+00:00      NaN  NaN  NaN  99.215  3310.01
# 2025-06-01 20:00:00+00:00  1377.81  NaN  NaN  99.123  3311.67
# 2025-06-01 21:00:00+00:00  1378.93  NaN  NaN  99.236  3303.48
# 2025-06-01 22:00:00+00:00  1378.50  NaN  NaN  99.303  3307.23

# %%
print(usdkrw.columns)
print(vix.columns)
print(spy.columns)
print(dxy.columns)
print(xau.columns)
# Out:
# Index(['USDKRW'], dtype='object')
# Index(['VIX'], dtype='object')
# Index(['SPY'], dtype='object')
# Index(['DXY'], dtype='object')
# Index(['XAUUSD'], dtype='object')

# %%
print("Non-missing counts by variable:")
print(df.notna().sum())

print("\nMissing ratio by variable:")
print(df.isna().mean().sort_values())

print("\nBaseline period:")
print(data_baseline.index.min(), "~", data_baseline.index.max())

print("\nRobust period:")
print(data_robust.index.min(), "~", data_robust.index.max())
# Out:
# Non-missing counts by variable:
# USDKRW    3462
# VIX       2859
# SPY       2199
# DXY       4592
# XAUUSD    4774
# dtype: int64
#
# Missing ratio by variable:
# XAUUSD    0.316340
# DXY       0.342403
# USDKRW    0.504225
# VIX       0.590577
# SPY       0.685092
# dtype: float64
#
# Baseline period:
# 2025-06-02 09:00:00+00:00 ~ 2026-03-19 12:00:00+00:00
#
# Robust period:
# 2025-06-02 09:00:00+00:00 ~ 2026-03-19 13:00:00+00:00

# %%
tmp = df.copy()
for col in df.columns:
    print(col, tmp.dropna(subset=[col]).shape[0])
# Out:
# USDKRW 3462
# VIX 2859
# SPY 2199
# DXY 4592
# XAUUSD 4774

# %%
print("df shape:", df.shape)
print("baseline shape:", data_baseline.shape)
print("robust shape:", data_robust.shape)

print("\nMissing values in df:")
print(df.isna().sum())

print("\nBaseline start/end:")
print(data_baseline.index.min(), data_baseline.index.max())

print("\nRobust start/end:")
print(data_robust.index.min(), data_robust.index.max())

print("\nHead of df:")
print(df.head())

print("\nHead of baseline:")
print(data_baseline.head())

print("\nHead of robust:")
print(data_robust.head())
# Out:
# df shape: (6983, 5)
# baseline shape: (719, 5)
# robust shape: (920, 10)
#
# Missing values in df:
# USDKRW    3521
# VIX       4124
# SPY       4784
# DXY       2391
# XAUUSD    2209
# dtype: int64
#
# Baseline start/end:
# 2025-06-02 09:00:00+00:00 2026-03-19 12:00:00+00:00
#
# Robust start/end:
# 2025-06-02 09:00:00+00:00 2026-03-19 13:00:00+00:00
#
# Head of df:
#                             USDKRW  VIX  SPY     DXY   XAUUSD
# datetime
# 2025-06-01 18:00:00+00:00      NaN  NaN  NaN  99.340  3313.04
# 2025-06-01 19:00:00+00:00      NaN  NaN  NaN  99.215  3310.01
# 2025-06-01 20:00:00+00:00  1377.81  NaN  NaN  99.123  3311.67
# 2025-06-01 21:00:00+00:00  1378.93  NaN  NaN  99.236  3303.48
# 2025-06-01 22:00:00+00:00  1378.50  NaN  NaN  99.303  3307.23
#
# Head of baseline:
#                             USDKRW    VIX      SPY     DXY   XAUUSD
# datetime
# 2025-06-02 09:00:00+00:00  1378.41  19.45  588.590  98.660  3371.97
# 2025-06-02 10:00:00+00:00  1376.84  18.97  588.550  98.723  3376.09
# 2025-06-02 11:00:00+00:00  1376.93  18.94  589.390  98.825  3374.70
# 2025-06-02 12:00:00+00:00  1378.80  18.92  589.840  98.881  3371.83
# 2025-06-03 09:00:00+00:00  1378.93  18.32  593.835  99.156  3345.94
#
# Head of robust:
#                             USDKRW    VIX     SPY     DXY   XAUUSD  \
# datetime
# 2025-06-02 09:00:00+00:00  1378.41  19.45  588.59  98.660  3371.97
# 2025-06-02 10:00:00+00:00  1376.84  18.97  588.55  98.723  3376.09
# 2025-06-02 11:00:00+00:00  1376.93  18.94  589.39  98.825  3374.70
# 2025-06-02 12:00:00+00:00  1378.80  18.92  589.84  98.881  3371.83
# 2025-06-02 13:00:00+00:00  1378.80  18.84  591.50  98.817  3374.44
#
#                            USDKRW_stale_flag  VIX_stale_flag  SPY_stale_flag  \
# datetime
# 2025-06-02 09:00:00+00:00                  0               0               0
# 2025-06-02 10:00:00+00:00                  0               0               0
# 2025-06-02 11:00:00+00:00                  0               0               0
# 2025-06-02 12:00:00+00:00                  0               0               0
# 2025-06-02 13:00:00+00:00                  1               0               0
#
#                            DXY_stale_flag  XAUUSD_stale_flag
# datetime
# 2025-06-02 09:00:00+00:00               0                  0
# 2025-06-02 10:00:00+00:00               0                  0
# 2025-06-02 11:00:00+00:00               0                  0
# 2025-06-02 12:00:00+00:00               0                  0
# 2025-06-02 13:00:00+00:00               0                  0

# %% [markdown]
# - baseline = main result
# - robust = sensitivity check

# %%
save_path = "./"  # 원하는 경로로 바꿔도 됨

# 1. 전체 정렬된 데이터 (NaN 포함)
df.to_csv(save_path + "exogenous_full_aligned.csv", index=True)

# 2. baseline (논문 메인 데이터)
data_baseline.to_csv(save_path + "exogenous_baseline_overlap.csv", index=True)

# 3. robust (ffill + stale 포함)
data_robust.to_csv(save_path + "exogenous_robust_ffill.csv", index=True)

print("CSV 저장 완료")
# Out:
# CSV 저장 완료

# %% [markdown]
# [ df: NaN 포함 full panel ]
#
# [ baseline: 완전 겹치는 표본 ]
#
# [ robust: ffill 적용 표본 ]

# %%
data_baseline.between_time("00:00","06:00")
# Out:
# Empty DataFrame
# Columns: [USDKRW, VIX, SPY, DXY, XAUUSD]
# Index: []

# %%
data_baseline['SPY'].diff().value_counts()
# Out:
# SPY
#  0.240    4
#  0.670    4
#  0.700    3
# -1.050    3
#  0.460    3
#          ..
# -0.365    1
#  0.185    1
#  0.200    1
#  0.900    1
# -0.910    1
# Name: count, Length: 624, dtype: int64

# %% [markdown]
# exogenous_baseline_overlap.csv :
#
# 모든 변수 동시에 존재하는 시점만
#
# 논문 메인 분석 데이터

# %%
# CSV 불러오기
df = pd.read_csv("exogenous_full_aligned.csv", parse_dates=['datetime'], index_col='datetime')
data_baseline = pd.read_csv("exogenous_baseline_overlap.csv", parse_dates=['datetime'], index_col='datetime')
data_robust = pd.read_csv("exogenous_robust_ffill.csv", parse_dates=['datetime'], index_col='datetime')

print("데이터 로드 완료")

cols = ['USDKRW','VIX','SPY','DXY','XAUUSD']

stale_df = pd.DataFrame({
    col: data_robust[f'{col}_stale_flag'].mean()
    for col in cols
}, index=['stale_ratio'])

print("\n=== Stale Ratio ===")
print(stale_df.T)

print("\n=== Observation Count ===")
print("Baseline obs:", len(data_baseline))
print("Robust obs:", len(data_robust))

print("\n=== Time Range ===")
print("Baseline:", data_baseline.index.min(), "~", data_baseline.index.max())
print("Robust  :", data_robust.index.min(), "~", data_robust.index.max())
# Out:
# 데이터 로드 완료
#
# === Stale Ratio ===
#         stale_ratio
# USDKRW     0.218478
# VIX        0.000000
# SPY        0.000000
# DXY        0.000000
# XAUUSD     0.000000
#
# === Observation Count ===
# Baseline obs: 719
# Robust obs: 920
#
# === Time Range ===
# Baseline: 2025-06-02 09:00:00+00:00 ~ 2026-03-19 12:00:00+00:00
# Robust  : 2025-06-02 09:00:00+00:00 ~ 2026-03-19 13:00:00+00:00

# %% [markdown]
# Forward-fill is limited to one hour, and stale observations are explicitly flagged.
# The stale ratio remains moderate (≈22%) only for USD/KRW due to market microstructure differences.

# %% [markdown]
# Major Issues in High-Frequency Financial Data Analysis by L Zhang 2025
#
# Bitcoin Microstructure and the Kimchi premium
#
# 정리
#
# 외생변수는 각 파일의 irregular timestamp를 1시간 bin으로 묶어(resample('1h').last()), 공통 분석구간으로 자른 뒤, baseline은 모든 변수가 동시에 관측된 시점만 남기고(dropna()), robustness에서는 최대 1시간까지만 forward-fill하고 어떤 값이 채워졌는지 _stale 더미로 표시함.
#
# 비동기성(asynchronous data) 문제를 다루는 전형적인 고빈도 전처리 논리와 일치하고, 고빈도 금융 문헌도 비동기성·비정상성·시장별 거래시간 차이를 핵심 문제로 봄.

# %% [markdown]
# 외생변수 끝 ==

# %%
# %pip install requests

# %%
import requests
import time

# 공통 설정
START_UTC = pd.Timestamp("2025-06-01 18:00:00", tz="UTC")
END_UTC   = pd.Timestamp("2026-03-19 16:00:00", tz="UTC")

# Binance spot
BINANCE_URL = "https://api.binance.com/api/v3/klines"
BINANCE_LIMIT = 1000  # official max 1000

BINANCE_SYMBOLS = {
    "BTC": "BTCUSDT",
    "ETH": "ETHUSDT",
    "XRP": "XRPUSDT",
    "SOL": "SOLUSDT",
    "DOGE": "DOGEUSDT",
    "USDT": "USDCUSDT",
}

# Upbit KRW markets + stablecoin
UPBIT_URL = "https://api.upbit.com/v1/candles/minutes/60"
UPBIT_LIMIT = 200  # official max 200

UPBIT_MARKETS = {
    "BTC": "KRW-BTC",
    "ETH": "KRW-ETH",
    "XRP": "KRW-XRP",
    "SOL": "KRW-SOL",
    "DOGE": "KRW-DOGE",
    "USDT": "KRW-USDT",
}

session = requests.Session()

def get_binance_klines_exact(symbol: str,
                             start_utc: pd.Timestamp,
                             end_utc: pd.Timestamp,
                             interval: str = "1h") -> pd.DataFrame:
    """
    Binance spot 1h klines, exact UTC window.
    Returns OHLCV indexed by open_time (UTC).
    """
    start_ms = int(start_utc.timestamp() * 1000)
    end_ms = int(end_utc.timestamp() * 1000)

    rows = []

    while start_ms <= end_ms:
        params = {
            "symbol": symbol,
            "interval": interval,
            "startTime": start_ms,
            "endTime": end_ms,
            "limit": BINANCE_LIMIT,
        }

        r = session.get(BINANCE_URL, params=params, timeout=20)
        r.raise_for_status()
        data = r.json()

        if not data:
            break

        rows.extend(data)

        last_open_ms = data[-1][0]
        next_start_ms = last_open_ms + 60 * 60 * 1000  # 다음 1시간 봉 시작
        if next_start_ms <= start_ms:
            break
        start_ms = next_start_ms

        time.sleep(0.2)

    if not rows:
        return pd.DataFrame(columns=["open", "high", "low", "close", "volume"])

    df = pd.DataFrame(rows, columns=[
        "open_time", "open", "high", "low", "close", "volume",
        "close_time", "quote_asset_volume", "num_trades",
        "taker_buy_base_volume", "taker_buy_quote_volume", "ignore"
    ])

    df["open_time"] = pd.to_datetime(df["open_time"], unit="ms", utc=True)
    df = df.drop_duplicates(subset=["open_time"]).sort_values("open_time")
    df = df.set_index("open_time")[["open", "high", "low", "close", "volume"]].astype(float)

    # 정확한 공통 구간으로 한 번 더 클립
    df = df.loc[start_utc:end_utc]

    # 안전하게 hourly grid 강제
    full_index = pd.date_range(start=start_utc, end=end_utc, freq="1h", tz="UTC")
    df = df.reindex(full_index)

    return df

def get_upbit_klines_exact(market: str,
                           start_utc: pd.Timestamp,
                           end_utc: pd.Timestamp) -> pd.DataFrame:
    """
    Upbit 60-minute candles in exact UTC window.
    Upbit candles exist only when trades occurred.
    Returns OHLCV indexed by candle_date_time_utc (UTC).
    """
    dfs = []
    to_cursor = end_utc

    while True:
        params = {
            "market": market,
            "count": UPBIT_LIMIT,
            "to": to_cursor.strftime("%Y-%m-%dT%H:%M:%S"),
        }

        r = session.get(UPBIT_URL, params=params, timeout=20)
        r.raise_for_status()
        data = r.json()

        if not isinstance(data, list) or len(data) == 0:
            break

        df = pd.DataFrame(data)

        df["candle_date_time_utc"] = pd.to_datetime(df["candle_date_time_utc"], utc=True)
        df = df.sort_values("candle_date_time_utc")
        dfs.append(df)

        oldest = df["candle_date_time_utc"].min()
        if oldest <= start_utc:
            break

        # 중복 방지용으로 oldest 직전 1초로 이동
        to_cursor = oldest - pd.Timedelta(seconds=1)
        time.sleep(0.2)

    if not dfs:
        return pd.DataFrame(columns=["open", "high", "low", "close", "volume"])

    out = pd.concat(dfs, axis=0)
    out = out.drop_duplicates(subset=["candle_date_time_utc"]).sort_values("candle_date_time_utc")
    out = out.set_index("candle_date_time_utc")

    out = out[[
        "opening_price",
        "high_price",
        "low_price",
        "trade_price",
        "candle_acc_trade_volume"
    ]].rename(columns={
        "opening_price": "open",
        "high_price": "high",
        "low_price": "low",
        "trade_price": "close",
        "candle_acc_trade_volume": "volume"
    }).astype(float)

    # 정확한 공통 구간으로 클립
    out = out.loc[start_utc:end_utc]

    # Upbit는 거래 없으면 캔들이 아예 없으므로, 여기선 NaN 유지
    full_index = pd.date_range(start=start_utc, end=end_utc, freq="1h", tz="UTC")
    out = out.reindex(full_index)

    return out

# %%
# Binance 수집
binance_data = {}

for name, symbol in BINANCE_SYMBOLS.items():
    print(f"[Binance] Downloading {name} ({symbol}) ...")
    df_b = get_binance_klines_exact(symbol, START_UTC, END_UTC, interval="1h")
    df_b.columns = [f"{name}_BINANCE_{c.upper()}" for c in df_b.columns]
    binance_data[name] = df_b
    print(name, df_b.shape, df_b.index.min(), df_b.index.max())

df_binance = pd.concat(binance_data.values(), axis=1, sort=True).sort_index()
# Out:
# [Binance] Downloading BTC (BTCUSDT) ...
# BTC (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Binance] Downloading ETH (ETHUSDT) ...
# ETH (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Binance] Downloading XRP (XRPUSDT) ...
# XRP (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Binance] Downloading SOL (SOLUSDT) ...
# SOL (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Binance] Downloading DOGE (DOGEUSDT) ...
# DOGE (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Binance] Downloading USDT (USDCUSDT) ...
# USDT (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00

# %% [markdown]
# [ Binance + Upbit에서 1시간 OHLCV 데이터를 정확한 시간 구간으로 수집하고, 공통 hourly grid로 맞춘 뒤 결측은 NaN으로 유지하는 데이터 수집 함수 ]

# %%
# Upbit 수집
upbit_data = {}

for name, market in UPBIT_MARKETS.items():
    print(f"[Upbit] Downloading {name} ({market}) ...")
    df_u = get_upbit_klines_exact(market, START_UTC, END_UTC)
    df_u.columns = [f"{name}_UPBIT_{c.upper()}" for c in df_u.columns]
    upbit_data[name] = df_u
    print(name, df_u.shape, df_u.index.min(), df_u.index.max())

df_upbit = pd.concat(upbit_data.values(), axis=1, sort=True).sort_index()

# 저장
df_binance.index.name = "datetime_utc"
df_upbit.index.name = "datetime_utc"

df_binance.to_csv("binance_1h_2025-06-01_2026-03-19.csv")
df_upbit.to_csv("upbit_1h_2025-06-01_2026-03-19.csv")

print("저장 완료")
print("Binance shape:", df_binance.shape)
print("Upbit shape:", df_upbit.shape)
# Out:
# [Upbit] Downloading BTC (KRW-BTC) ...
# BTC (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Upbit] Downloading ETH (KRW-ETH) ...
# ETH (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Upbit] Downloading XRP (KRW-XRP) ...
# XRP (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Upbit] Downloading SOL (KRW-SOL) ...
# SOL (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Upbit] Downloading DOGE (KRW-DOGE) ...
# DOGE (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# [Upbit] Downloading USDT (KRW-USDT) ...
# USDT (6983, 5) 2025-06-01 18:00:00+00:00 2026-03-19 16:00:00+00:00
# 저장 완료
# Binance shape: (6983, 30)
# Upbit shape: (6983, 30)

# %%
print("\n Binance columns")
print(df_binance.columns)

print("\n Upbit columns")
print(df_upbit.columns)
# Out:
#  Binance columns
# Index(['BTC_BINANCE_OPEN', 'BTC_BINANCE_HIGH', 'BTC_BINANCE_LOW',
#        'BTC_BINANCE_CLOSE', 'BTC_BINANCE_VOLUME', 'ETH_BINANCE_OPEN',
#        'ETH_BINANCE_HIGH', 'ETH_BINANCE_LOW', 'ETH_BINANCE_CLOSE',
#        'ETH_BINANCE_VOLUME', 'XRP_BINANCE_OPEN', 'XRP_BINANCE_HIGH',
#        'XRP_BINANCE_LOW', 'XRP_BINANCE_CLOSE', 'XRP_BINANCE_VOLUME',
#        'SOL_BINANCE_OPEN', 'SOL_BINANCE_HIGH', 'SOL_BINANCE_LOW',
#        'SOL_BINANCE_CLOSE', 'SOL_BINANCE_VOLUME', 'DOGE_BINANCE_OPEN',
#        'DOGE_BINANCE_HIGH', 'DOGE_BINANCE_LOW', 'DOGE_BINANCE_CLOSE',
#        'DOGE_BINANCE_VOLUME', 'USDT_BINANCE_OPEN', 'USDT_BINANCE_HIGH',
#        'USDT_BINANCE_LOW', 'USDT_BINANCE_CLOSE', 'USDT_BINANCE_VOLUME'],
#       dtype='object')
#
#  Upbit columns
# Index(['BTC_UPBIT_OPEN', 'BTC_UPBIT_HIGH', 'BTC_UPBIT_LOW', 'BTC_UPBIT_CLOSE',
#        'BTC_UPBIT_VOLUME', 'ETH_UPBIT_OPEN', 'ETH_UPBIT_HIGH', 'ETH_UPBIT_LOW',
#        'ETH_UPBIT_CLOSE', 'ETH_UPBIT_VOLUME', 'XRP_UPBIT_OPEN',
#        'XRP_UPBIT_HIGH', 'XRP_UPBIT_LOW', 'XRP_UPBIT_CLOSE',
#        'XRP_UPBIT_VOLUME', 'SOL_UPBIT_OPEN', 'SOL_UPBIT_HIGH', 'SOL_UPBIT_LOW',
#        'SOL_UPBIT_CLOSE', 'SOL_UPBIT_VOLUME', 'DOGE_UPBIT_OPEN',
#        'DOGE_UPBIT_HIGH', 'DOGE_UPBIT_LOW', 'DOGE_UPBIT_CLOSE',
#        'DOGE_UPBIT_VOLUME', 'USDT_UPBIT_OPEN', 'USDT_UPBIT_HIGH',
#        'USDT_UPBIT_LOW', 'USDT_UPBIT_CLOSE', 'USDT_UPBIT_VOLUME'],
#       dtype='object')

# %%
binance = pd.read_csv(
    "binance_1h_2025-06-01_2026-03-19.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

upbit = pd.read_csv(
    "upbit_1h_2025-06-01_2026-03-19.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

exog = pd.read_csv(
    "exogenous_baseline_overlap.csv",
    parse_dates=["datetime"],
    index_col="datetime"
)
# exog = pd.read_csv(
#     "exogenous_baseline_overlap.csv",
#     parse_dates=["datetime_utc"],
#     index_col="datetime_utc"
# )

# timezone 통일
binance.index = pd.to_datetime(binance.index, utc=True)
upbit.index = pd.to_datetime(upbit.index, utc=True)
exog.index = pd.to_datetime(exog.index, utc=True)

print("binance:", binance.shape)
print("upbit  :", upbit.shape)
print("exog   :", exog.shape)
# Out:
# binance: (6983, 30)
# upbit  : (6983, 30)
# exog   : (719, 5)

# %%
# close price만 사용

coins = ["BTC", "ETH", "XRP", "SOL", "DOGE"]

bin_close = pd.DataFrame(index=binance.index)
up_close = pd.DataFrame(index=upbit.index)

for c in coins:
    bin_close[f"{c}_BINANCE_CLOSE"] = binance[f"{c}_BINANCE_CLOSE"]
    up_close[f"{c}_UPBIT_CLOSE"] = upbit[f"{c}_UPBIT_CLOSE"]

# USDT (업비트)
# up_close["USDT_UPBIT_CLOSE"] = upbit["USDT_UPBIT_CLOSE"]
bin_close["USDT_BINANCE_CLOSE"] = binance["USDT_BINANCE_CLOSE"]
up_close["USDT_UPBIT_CLOSE"] = upbit["USDT_UPBIT_CLOSE"]

# FX
fx = exog[["USDKRW"]].copy()

# %%
# baseline exog 시간축 기준
# panel = exog[["USDKRW"]].join(bin_close, how="left").join(up_close, how="left")
panel = bin_close.join(up_close, how="outer").sort_index()

print(panel.shape)
print(panel.head())
# print("\nUSDKRW NaN count:", panel["USDKRW"].isna().sum())
# Out:
# (6983, 12)
#                            BTC_BINANCE_CLOSE  ETH_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00          104900.01            2520.20
# 2025-06-01 19:00:00+00:00          105121.94            2526.38
# 2025-06-01 20:00:00+00:00          104948.91            2525.70
# 2025-06-01 21:00:00+00:00          105496.54            2539.40
# 2025-06-01 22:00:00+00:00          105512.18            2535.28
#
#                            XRP_BINANCE_CLOSE  SOL_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00             2.1573             154.72
# 2025-06-01 19:00:00+00:00             2.1675             155.89
# 2025-06-01 20:00:00+00:00             2.1552             155.69
# 2025-06-01 21:00:00+00:00             2.1725             156.91
# 2025-06-01 22:00:00+00:00             2.1728             157.20
#
#                            DOGE_BINANCE_CLOSE  USDT_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00             0.19084              0.9995
# 2025-06-01 19:00:00+00:00             0.19188              0.9994
# 2025-06-01 20:00:00+00:00             0.19139              0.9995
# 2025-06-01 21:00:00+00:00             0.19321              0.9995
# 2025-06-01 22:00:00+00:00             0.19364              0.9994
#
#                            BTC_UPBIT_CLOSE  ETH_UPBIT_CLOSE  XRP_UPBIT_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00      148295000.0        3563000.0           3051.0
# 2025-06-01 19:00:00+00:00      148483000.0        3570000.0           3061.0
# 2025-06-01 20:00:00+00:00      148083000.0        3565000.0           3043.0
# 2025-06-01 21:00:00+00:00      148739000.0        3582000.0           3064.0
# 2025-06-01 22:00:00+00:00      149011000.0        3580000.0           3067.0
#
#                            SOL_UPBIT_CLOSE  DOGE_UPBIT_CLOSE  USDT_UPBIT_CLOSE
# datetime_utc
# 2025-06-01 18:00:00+00:00         218850.0             269.7            1413.5
# 2025-06-01 19:00:00+00:00         220100.0             271.0            1411.0
# 2025-06-01 20:00:00+00:00         219500.0             270.0            1411.0
# 2025-06-01 21:00:00+00:00         221150.0             273.0            1410.5
# 2025-06-01 22:00:00+00:00         222050.0             273.4            1412.0

# %% [markdown]
# [ panel은 exog baseline 시간축 기준 패널이 아니라,
#
# crypto 가격들의 union 시간축 패널 ]

# %%
# exog baseline에서 FX만 가져오기
fx = exog[["USDKRW"]].copy()

# crypto panel + FX
panel = panel.join(fx, how="left").sort_index()

print(panel.shape)
print(panel[["USDKRW"]].head())
print("\nUSDKRW NaN count:", panel["USDKRW"].isna().sum())
# Out:
# (6983, 13)
#                            USDKRW
# datetime_utc
# 2025-06-01 18:00:00+00:00     NaN
# 2025-06-01 19:00:00+00:00     NaN
# 2025-06-01 20:00:00+00:00     NaN
# 2025-06-01 21:00:00+00:00     NaN
# 2025-06-01 22:00:00+00:00     NaN
#
# USDKRW NaN count: 6264

# %%
for c in coins:
    panel[f"{c}_KP"] = (
        panel[f"{c}_UPBIT_CLOSE"] /
        (panel[f"{c}_BINANCE_CLOSE"] * panel["USDKRW"])
        - 1
    )

# panel["USDT_DEV"] = panel["USDT_UPBIT_CLOSE"] / panel["USDKRW"] - 1
panel["USDT_KP"] = (
    panel["USDT_UPBIT_CLOSE"] /
    (panel["USDT_BINANCE_CLOSE"] * panel["USDKRW"])
    - 1
)

# %%
# kp_cols = [f"{c}_KP" for c in coins] + ["USDT_DEV"]
kp_coin_cols = [f"{c}_KP" for c in coins]
panel["MKT_KP_EQ"] = panel[kp_coin_cols].mean(axis=1)

panel["RESIDUAL_RAW"] = panel["USDT_KP"] - panel["MKT_KP_EQ"]

check_cols = kp_coin_cols + ["USDT_KP", "MKT_KP_EQ", "RESIDUAL_RAW"]

# print(panel[kp_cols].head())
# print("\nNaN counts:")
# print(panel[kp_cols].isna().sum())

# print("\nSummary stats:")
# print(panel[kp_cols].describe())
print("\nHead:")
print(panel[check_cols].head())

print("\nNaN counts:")
print(panel[check_cols].isna().sum())

print("\nSummary stats:")
print(panel[check_cols].describe())
# Out:
# Head:
#                            BTC_KP  ETH_KP  XRP_KP  SOL_KP  DOGE_KP  USDT_KP  \
# datetime_utc
# 2025-06-01 18:00:00+00:00     NaN     NaN     NaN     NaN      NaN      NaN
# 2025-06-01 19:00:00+00:00     NaN     NaN     NaN     NaN      NaN      NaN
# 2025-06-01 20:00:00+00:00     NaN     NaN     NaN     NaN      NaN      NaN
# 2025-06-01 21:00:00+00:00     NaN     NaN     NaN     NaN      NaN      NaN
# 2025-06-01 22:00:00+00:00     NaN     NaN     NaN     NaN      NaN      NaN
#
#                            MKT_KP_EQ  RESIDUAL_RAW
# datetime_utc
# 2025-06-01 18:00:00+00:00        NaN           NaN
# 2025-06-01 19:00:00+00:00        NaN           NaN
# 2025-06-01 20:00:00+00:00        NaN           NaN
# 2025-06-01 21:00:00+00:00        NaN           NaN
# 2025-06-01 22:00:00+00:00        NaN           NaN
#
# NaN counts:
# BTC_KP          6264
# ETH_KP          6264
# XRP_KP          6264
# SOL_KP          6264
# DOGE_KP         6264
# USDT_KP         6264
# MKT_KP_EQ       6264
# RESIDUAL_RAW    6264
# dtype: int64
#
# Summary stats:
#            BTC_KP      ETH_KP      XRP_KP      SOL_KP     DOGE_KP     USDT_KP  \
# count  719.000000  719.000000  719.000000  719.000000  719.000000  719.000000
# mean     0.010381    0.010289    0.010341    0.010379    0.010518    0.010407
# std      0.017814    0.017822    0.017671    0.017748    0.018119    0.017635
# min     -0.022618   -0.022414   -0.023345   -0.022898   -0.025424   -0.022704
# 25%     -0.000210   -0.000312   -0.000463   -0.000214   -0.000514   -0.000017
# 50%      0.009487    0.009794    0.009556    0.009701    0.009361    0.009743
# 75%      0.018310    0.018111    0.018205    0.018134    0.018250    0.017852
# max      0.082502    0.082924    0.080986    0.082189    0.083158    0.081208
#
#         MKT_KP_EQ  RESIDUAL_RAW
# count  719.000000    719.000000
# mean     0.010382      0.000025
# std      0.017802      0.000972
# min     -0.022695     -0.005381
# 25%     -0.000438     -0.000495
# 50%      0.009624      0.000143
# 75%      0.018220      0.000659
# max      0.082352      0.002410

# %% [markdown]
# - 각 코인의 한국 가격 vs 글로벌 가격 vs 환율을 이용해 김치프리미엄(KP) 계산
# - USDT에 대해서도 같은 방식으로 USDT_KP 계산
# - 5개 코인의 평균 premium을 시장 전체 premium proxy (MKT_KP_EQ)로 만듦
# - USDT_KP - MKT_KP_EQ로 Residual을 만듦
#
# 글로벌 가격(Binance), 국내 가격(Upbit), 환율(USDKRW)을 결합해서 각 코인의 김치프리미엄을 계산하고, 그 평균을 시장 공통 premium proxy로 만든 뒤, USDT premium에서 이를 뺀 residual을 생성한 코드임.

# %%
# for c in coins:
#     panel[f"{c}_KP_pct"] = panel[f"{c}_KP"] * 100

# panel["USDT_DEV_pct"] = panel["USDT_DEV"] * 100
for c in coins:
    panel[f"{c}_KP_pct"] = panel[f"{c}_KP"] * 100

panel["USDT_KP_pct"] = panel["USDT_KP"] * 100
panel["MKT_KP_EQ_pct"] = panel["MKT_KP_EQ"] * 100
panel["RESIDUAL_RAW_pct"] = panel["RESIDUAL_RAW"] * 100

# %%
panel.index.name = "datetime_utc"

panel.to_csv("crypto_kp_panel_baseline.csv")

print("저장 완료: crypto_kp_panel_baseline.csv")
# Out:
# 저장 완료: crypto_kp_panel_baseline.csv

# %% [markdown]
# [ 김치프리미엄 및 residual 변수를 비율형과 퍼센트형 둘 다 갖춘 상태로 정리해서 최종 baseline 패널 파일로 저장하는 코드 ]

# %%
# exog_baseline = pd.read_csv(
#     "exogenous_baseline_overlap.csv",
#     parse_dates=["datetime"],
#     index_col="datetime"
# )

# exog_baseline.index = pd.to_datetime(exog_baseline.index, utc=True)

# # 기존 panel은 이미 USDKRW 포함이라 나머지만 붙이기
# exog_vars = exog_baseline.drop(columns=["USDKRW"])

# final_df = panel.join(exog_vars)

# print(final_df.shape)
# print(final_df.head())
# print(final_df[["USDKRW", "VIX", "SPY", "DXY", "XAUUSD"]].isna().sum())
# 1. exogenous baseline load
exog_baseline = pd.read_csv(
    "exogenous_baseline_overlap.csv",
    parse_dates=["datetime"],
    index_col="datetime"
)

# 2. index 완전 통일
panel.index = pd.to_datetime(panel.index, utc=True)
exog_baseline.index = pd.to_datetime(exog_baseline.index, utc=True)

# 3. index 이름도 통일
panel.index.name = "datetime_utc"
exog_baseline.index.name = "datetime_utc"

# 4. panel은 이미 USDKRW 포함이므로 나머지 exog만 사용
exog_vars = exog_baseline.drop(columns=["USDKRW"])

# 5. merge
final_df = panel.join(exog_vars)

# 6. 확인
print(final_df.shape)
print(final_df.head())
print(final_df[["USDKRW", "VIX", "SPY", "DXY", "XAUUSD"]].isna().sum())

# 7. 저장
final_df.index.name = "datetime_utc"
final_df.to_csv("final_dataset_baseline.csv")

print("최종 저장 완료: final_dataset_baseline.csv")
# Out:
# (6983, 33)
#                            BTC_BINANCE_CLOSE  ETH_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00          104900.01            2520.20
# 2025-06-01 19:00:00+00:00          105121.94            2526.38
# 2025-06-01 20:00:00+00:00          104948.91            2525.70
# 2025-06-01 21:00:00+00:00          105496.54            2539.40
# 2025-06-01 22:00:00+00:00          105512.18            2535.28
#
#                            XRP_BINANCE_CLOSE  SOL_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00             2.1573             154.72
# 2025-06-01 19:00:00+00:00             2.1675             155.89
# 2025-06-01 20:00:00+00:00             2.1552             155.69
# 2025-06-01 21:00:00+00:00             2.1725             156.91
# 2025-06-01 22:00:00+00:00             2.1728             157.20
#
#                            DOGE_BINANCE_CLOSE  USDT_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00             0.19084              0.9995
# 2025-06-01 19:00:00+00:00             0.19188              0.9994
# 2025-06-01 20:00:00+00:00             0.19139              0.9995
# 2025-06-01 21:00:00+00:00             0.19321              0.9995
# 2025-06-01 22:00:00+00:00             0.19364              0.9994
#
#                            BTC_UPBIT_CLOSE  ETH_UPBIT_CLOSE  XRP_UPBIT_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00      148295000.0        3563000.0           3051.0
# 2025-06-01 19:00:00+00:00      148483000.0        3570000.0           3061.0
# 2025-06-01 20:00:00+00:00      148083000.0        3565000.0           3043.0
# 2025-06-01 21:00:00+00:00      148739000.0        3582000.0           3064.0
# 2025-06-01 22:00:00+00:00      149011000.0        3580000.0           3067.0
#
#                            SOL_UPBIT_CLOSE  ...  XRP_KP_pct  SOL_KP_pct  \
# datetime_utc                                ...
# 2025-06-01 18:00:00+00:00         218850.0  ...         NaN         NaN
# 2025-06-01 19:00:00+00:00         220100.0  ...         NaN         NaN
# 2025-06-01 20:00:00+00:00         219500.0  ...         NaN         NaN
# 2025-06-01 21:00:00+00:00         221150.0  ...         NaN         NaN
# 2025-06-01 22:00:00+00:00         222050.0  ...         NaN         NaN
#
#                            DOGE_KP_pct  USDT_KP_pct  MKT_KP_EQ_pct  \
# datetime_utc
# 2025-06-01 18:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 19:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 20:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 21:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 22:00:00+00:00          NaN          NaN            NaN
#
#                            RESIDUAL_RAW_pct  VIX  SPY  DXY  XAUUSD
# datetime_utc
# 2025-06-01 18:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 19:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 20:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 21:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 22:00:00+00:00               NaN  NaN  NaN  NaN     NaN
#
# [5 rows x 33 columns]
# USDKRW    6264
# VIX       6264
# SPY       6264
# DXY       6264
# XAUUSD    6264
# dtype: int64
# 최종 저장 완료: final_dataset_baseline.csv

# %%
# # index 완전 통일
# panel.index = pd.to_datetime(panel.index, utc=True)
# exog_baseline.index = pd.to_datetime(exog_baseline.index, utc=True)

# # 이름도 통일
# panel.index.name = "datetime_utc"
# exog_baseline.index.name = "datetime_utc"
# final_df = panel.join(exog_vars, how="left")

# %%
# final_df.index.name = "datetime_utc"

# final_df.to_csv("final_dataset_baseline.csv")

# print("최종 저장 완료: final_dataset_baseline.csv")

# %%
# # 1. final dataset load
# final_df = pd.read_csv(
#     "final_dataset_baseline.csv",
#     parse_dates=["datetime_utc"],
#     index_col="datetime_utc"
# )

# # timezone 유지/통일
# final_df.index = pd.to_datetime(final_df.index, utc=True)

# print("final_df shape:", final_df.shape)
# print(final_df.head())
# 1. final dataset load
final_df = pd.read_csv(
    "final_dataset_baseline.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

final_df.index = pd.to_datetime(final_df.index, utc=True)

print("final_df shape:", final_df.shape)
print(final_df.head())

# 2. strict baseline usable sample 먼저 추출
baseline_df = final_df.dropna(subset=["USDKRW", "VIX", "SPY", "DXY", "XAUUSD"]).copy()

print("baseline_df shape:", baseline_df.shape)

# 3. 외생변수 log return 생성
exog_cols = ["VIX", "SPY", "DXY", "XAUUSD"]

for col in exog_cols:
    baseline_df[f"{col}_ret"] = np.log(baseline_df[col]).diff()

print(baseline_df[[*exog_cols, "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret"]].head())
# Out:
# final_df shape: (6983, 33)
#                            BTC_BINANCE_CLOSE  ETH_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00          104900.01            2520.20
# 2025-06-01 19:00:00+00:00          105121.94            2526.38
# 2025-06-01 20:00:00+00:00          104948.91            2525.70
# 2025-06-01 21:00:00+00:00          105496.54            2539.40
# 2025-06-01 22:00:00+00:00          105512.18            2535.28
#
#                            XRP_BINANCE_CLOSE  SOL_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00             2.1573             154.72
# 2025-06-01 19:00:00+00:00             2.1675             155.89
# 2025-06-01 20:00:00+00:00             2.1552             155.69
# 2025-06-01 21:00:00+00:00             2.1725             156.91
# 2025-06-01 22:00:00+00:00             2.1728             157.20
#
#                            DOGE_BINANCE_CLOSE  USDT_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00             0.19084              0.9995
# 2025-06-01 19:00:00+00:00             0.19188              0.9994
# 2025-06-01 20:00:00+00:00             0.19139              0.9995
# 2025-06-01 21:00:00+00:00             0.19321              0.9995
# 2025-06-01 22:00:00+00:00             0.19364              0.9994
#
#                            BTC_UPBIT_CLOSE  ETH_UPBIT_CLOSE  XRP_UPBIT_CLOSE  \
# datetime_utc
# 2025-06-01 18:00:00+00:00      148295000.0        3563000.0           3051.0
# 2025-06-01 19:00:00+00:00      148483000.0        3570000.0           3061.0
# 2025-06-01 20:00:00+00:00      148083000.0        3565000.0           3043.0
# 2025-06-01 21:00:00+00:00      148739000.0        3582000.0           3064.0
# 2025-06-01 22:00:00+00:00      149011000.0        3580000.0           3067.0
#
#                            SOL_UPBIT_CLOSE  ...  XRP_KP_pct  SOL_KP_pct  \
# datetime_utc                                ...
# 2025-06-01 18:00:00+00:00         218850.0  ...         NaN         NaN
# 2025-06-01 19:00:00+00:00         220100.0  ...         NaN         NaN
# 2025-06-01 20:00:00+00:00         219500.0  ...         NaN         NaN
# 2025-06-01 21:00:00+00:00         221150.0  ...         NaN         NaN
# 2025-06-01 22:00:00+00:00         222050.0  ...         NaN         NaN
#
#                            DOGE_KP_pct  USDT_KP_pct  MKT_KP_EQ_pct  \
# datetime_utc
# 2025-06-01 18:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 19:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 20:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 21:00:00+00:00          NaN          NaN            NaN
# 2025-06-01 22:00:00+00:00          NaN          NaN            NaN
#
#                            RESIDUAL_RAW_pct  VIX  SPY  DXY  XAUUSD
# datetime_utc
# 2025-06-01 18:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 19:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 20:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 21:00:00+00:00               NaN  NaN  NaN  NaN     NaN
# 2025-06-01 22:00:00+00:00               NaN  NaN  NaN  NaN     NaN
#
# [5 rows x 33 columns]
# baseline_df shape: (719, 33)
#                              VIX      SPY     DXY   XAUUSD   VIX_ret  \
# datetime_utc
# 2025-06-02 09:00:00+00:00  19.45  588.590  98.660  3371.97       NaN
# 2025-06-02 10:00:00+00:00  18.97  588.550  98.723  3376.09 -0.024988
# 2025-06-02 11:00:00+00:00  18.94  589.390  98.825  3374.70 -0.001583
# 2025-06-02 12:00:00+00:00  18.92  589.840  98.881  3371.83 -0.001057
# 2025-06-03 09:00:00+00:00  18.32  593.835  99.156  3345.94 -0.032226
#
#                             SPY_ret   DXY_ret  XAUUSD_ret
# datetime_utc
# 2025-06-02 09:00:00+00:00       NaN       NaN         NaN
# 2025-06-02 10:00:00+00:00 -0.000068  0.000638    0.001221
# 2025-06-02 11:00:00+00:00  0.001426  0.001033   -0.000412
# 2025-06-02 12:00:00+00:00  0.000763  0.000566   -0.000851
# 2025-06-03 09:00:00+00:00  0.006750  0.002777   -0.007708

# %%
# # 2. 외생변수 변환
# # level -> log return
# exog_cols = ["VIX", "SPY", "DXY", "XAUUSD"]

# for col in exog_cols:
#     final_df[f"{col}_ret"] = np.log(final_df[col]).diff()

# print(final_df[[*exog_cols, "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret"]].head())

# %%
# # 3. 회귀용 clean dataset 생성
# reg_cols = [
#     "BTC_KP", "ETH_KP", "XRP_KP", "SOL_KP", "DOGE_KP",
#     "USDT_DEV",
#     "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret"
# ]

# reg_df = final_df[reg_cols].dropna().copy()

# print("reg_df shape:", reg_df.shape)
# print(reg_df.head())
# 3. 회귀용 clean dataset 생성 (baseline_df 기준)
reg_cols = [
    "BTC_KP", "ETH_KP", "XRP_KP", "SOL_KP", "DOGE_KP",
    "USDT_KP",
    "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret"
]

reg_df = baseline_df[reg_cols].dropna().copy()

print("reg_df shape:", reg_df.shape)
print(reg_df.head())
# Out:
# reg_df shape: (718, 10)
#                              BTC_KP    ETH_KP    XRP_KP    SOL_KP   DOGE_KP  \
# datetime_utc
# 2025-06-02 10:00:00+00:00  0.022679  0.022106  0.022344  0.021943  0.022071
# 2025-06-02 11:00:00+00:00  0.022892  0.022224  0.022787  0.022292  0.022541
# 2025-06-02 12:00:00+00:00  0.020342  0.019509  0.019730  0.020342  0.019885
# 2025-06-03 09:00:00+00:00  0.015298  0.014369  0.014423  0.015525  0.014781
# 2025-06-03 10:00:00+00:00  0.015599  0.015537  0.015275  0.015781  0.015555
#
#                             USDT_KP   VIX_ret   SPY_ret   DXY_ret  XAUUSD_ret
# datetime_utc
# 2025-06-02 10:00:00+00:00  0.022155 -0.024988 -0.000068  0.000638    0.001221
# 2025-06-02 11:00:00+00:00  0.021725 -0.001583  0.001426  0.001033   -0.000412
# 2025-06-02 12:00:00+00:00  0.020340 -0.001057  0.000763  0.000566   -0.000851
# 2025-06-03 09:00:00+00:00  0.014801 -0.032226  0.006750  0.002777   -0.007708
# 2025-06-03 10:00:00+00:00  0.015364 -0.018733  0.001893  0.000544    0.000161

# %%
# # index 이름 명확히
# final_df.index.name = "datetime_utc"
# reg_df.index.name = "datetime_utc"

# # 1. 전체 데이터 (KP + exog + returns 포함)
# final_df.to_csv("final_dataset_baseline_with_returns.csv")

# # 2. 회귀용 clean dataset (dropna 완료된 것)
# reg_df.to_csv("regression_dataset_baseline.csv")

# print("저장 완료")
# print("1) final_dataset_baseline_with_returns.csv")
# print("2) regression_dataset_baseline.csv")
# index 이름 명확히
final_df.index.name = "datetime_utc"
baseline_df.index.name = "datetime_utc"
reg_df.index.name = "datetime_utc"

# 저장
final_df.to_csv("final_dataset_baseline_with_returns.csv")
baseline_df.to_csv("baseline_dataset_clean.csv")
reg_df.to_csv("regression_dataset_baseline.csv")

print("저장 완료")
print("1) final_dataset_baseline_with_returns.csv")
print("2) baseline_dataset_clean.csv")
print("3) regression_dataset_baseline.csv")
# Out:
# 저장 완료
# 1) final_dataset_baseline_with_returns.csv
# 2) baseline_dataset_clean.csv
# 3) regression_dataset_baseline.csv

# %% [markdown]
# 최종 파일 - regression_dataset_baseline.csv (실제 분석/회귀에 쓰는 최종 데이터셋)
#
# baseline_dataset_clean.csv (clean baseline 데이터)
#
# final_dataset_baseline_with_returns.csv (전체 데이터 저장)

# %%
print(baseline_df.columns)
# Out:
# Index(['BTC_BINANCE_CLOSE', 'ETH_BINANCE_CLOSE', 'XRP_BINANCE_CLOSE',
#        'SOL_BINANCE_CLOSE', 'DOGE_BINANCE_CLOSE', 'USDT_BINANCE_CLOSE',
#        'BTC_UPBIT_CLOSE', 'ETH_UPBIT_CLOSE', 'XRP_UPBIT_CLOSE',
#        'SOL_UPBIT_CLOSE', 'DOGE_UPBIT_CLOSE', 'USDT_UPBIT_CLOSE', 'USDKRW',
#        'BTC_KP', 'ETH_KP', 'XRP_KP', 'SOL_KP', 'DOGE_KP', 'USDT_KP',
#        'MKT_KP_EQ', 'RESIDUAL_RAW', 'BTC_KP_pct', 'ETH_KP_pct', 'XRP_KP_pct',
#        'SOL_KP_pct', 'DOGE_KP_pct', 'USDT_KP_pct', 'MKT_KP_EQ_pct',
#        'RESIDUAL_RAW_pct', 'VIX', 'SPY', 'DXY', 'XAUUSD', 'VIX_ret', 'SPY_ret',
#        'DXY_ret', 'XAUUSD_ret'],
#       dtype='object')

# %%
# print(reg_df.isna().sum())
# print(reg_df.describe())

# %% [markdown]
# final_dataset_baseline_with_returns.csv
# - 전체 데이터 보존
# - 나중에 robustness / 다른 모델 다시 돌릴 때 필요
#
# regression_dataset_baseline.csv
# - 바로 VAR / OLS / Granger 넣는 데이터
# - 이미 clean 상태 (NaN 없음)

# %% [markdown]
# final_dataset_baseline_with_returns.csv
# - full hourly index 유지
# - crypto 가격들 있음
# - USDKRW, VIX, SPY, DXY, XAUUSD는 strict baseline 시간대에서만 값 있음
# - VIX_ret, SPY_ret, DXY_ret, XAUUSD_ret는 여기선 사실 해석용이 아니라 붙여놓은 상태에 가까움
#
# baseline_dataset_clean.csv
# - strict overlap-only sample
# - crypto close + KP + exog level + exog return까지 포함
# - 현재 실증의 메인 clean panel
#
# regression_dataset_baseline.csv
# - BTC_KP~DOGE_KP
# - USDT_KP
# - VIX_ret, SPY_ret, DXY_ret, XAUUSD_ret
# - 즉, 기존 baseline 회귀용 요약 패널

# %%
import pandas as pd
import numpy as np

# final_df = pd.read_csv(
#     "final_dataset_baseline.csv",
#     parse_dates=["datetime_utc"],
#     index_col="datetime_utc"
# )

# binance = pd.read_csv(
#     "binance_1h_2025-06-01_2026-03-19.csv",
#     parse_dates=["datetime_utc"],
#     index_col="datetime_utc"
# )

# upbit = pd.read_csv(
#     "upbit_1h_2025-06-01_2026-03-19.csv",
#     parse_dates=["datetime_utc"],
#     index_col="datetime_utc"
# )

# # timezone 통일
# final_df.index = pd.to_datetime(final_df.index, utc=True)
# binance.index = pd.to_datetime(binance.index, utc=True)
# upbit.index = pd.to_datetime(upbit.index, utc=True)

# print("final_df:", final_df.shape)
# print("binance :", binance.shape)
# print("upbit   :", upbit.shape)

baseline_df = pd.read_csv(
    "baseline_dataset_clean.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

binance = pd.read_csv(
    "binance_1h_2025-06-01_2026-03-19.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

upbit = pd.read_csv(
    "upbit_1h_2025-06-01_2026-03-19.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

# timezone 통일
baseline_df.index = pd.to_datetime(baseline_df.index, utc=True)
binance.index = pd.to_datetime(binance.index, utc=True)
upbit.index = pd.to_datetime(upbit.index, utc=True)

print("baseline_df:", baseline_df.shape)
print("binance    :", binance.shape)
print("upbit      :", upbit.shape)

# # =========================
# # 2) exogenous returns 다시 생성
# # =========================
# exog_cols = ["VIX", "SPY", "DXY", "XAUUSD"]

# for col in exog_cols:
#     final_df[f"{col}_ret"] = np.log(final_df[col]).diff()

# print("\nExogenous returns added:")
# print(final_df[[*exog_cols, "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret"]].head())

# # =========================
# # 3) micro variables 생성
# # =========================
# coins = ["BTC", "ETH", "XRP", "SOL", "DOGE"]

# micro = pd.DataFrame(index=final_df.index)

# # (a) BTC global return
# micro["BTC_RET"] = np.log(
#     binance["BTC_BINANCE_CLOSE"].reindex(final_df.index)
# ).diff()

# # (b) BTC rolling volatility (24 observations)
# micro["BTC_VOL_24"] = micro["BTC_RET"].rolling(window=24, min_periods=24).std()

# # (c) coin-specific volume ratios
# #     raw ratio + log ratio 둘 다 생성
# for c in coins:
#     bin_vol = binance[f"{c}_BINANCE_VOLUME"].reindex(final_df.index)
#     up_vol = upbit[f"{c}_UPBIT_VOLUME"].reindex(final_df.index)

#     micro[f"{c}_VOL_RATIO"] = bin_vol / up_vol
#     micro[f"{c}_VOL_RATIO_LOG"] = np.log(bin_vol / up_vol)

# print("\nMicro variables head:")
# print(micro.head())

# print("\nNaN counts in micro:")
# print(micro.isna().sum())

# # =========================
# # 4) merge
# # =========================
# final_micro_df = final_df.join(micro)

# print("\nMerged shape:", final_micro_df.shape)
# print(final_micro_df.head())

# # =========================
# # 5) regression dataset 생성
# # =========================
# reg_cols_micro = [
#     "BTC_KP", "ETH_KP", "XRP_KP", "SOL_KP", "DOGE_KP",
#     "USDT_DEV",
#     "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret",
#     "BTC_RET", "BTC_VOL_24",
#     "BTC_VOL_RATIO_LOG", "ETH_VOL_RATIO_LOG", "XRP_VOL_RATIO_LOG",
#     "SOL_VOL_RATIO_LOG", "DOGE_VOL_RATIO_LOG"
# ]

# # 존재하지 않는 컬럼 체크
# missing_cols = [c for c in reg_cols_micro if c not in final_micro_df.columns]
# print("\nMissing columns:", missing_cols)

# reg_micro_df = final_micro_df[reg_cols_micro].dropna().copy()

# print("\nreg_micro_df shape:", reg_micro_df.shape)
# print(reg_micro_df.head())

# # =========================
# # 6) 저장
# # =========================
# final_micro_df.index.name = "datetime_utc"
# reg_micro_df.index.name = "datetime_utc"

# final_micro_df.to_csv("final_dataset_baseline_with_micro.csv")
# reg_micro_df.to_csv("regression_dataset_baseline_with_micro.csv")

# print("\n저장 완료")
# print("1) final_dataset_baseline_with_micro.csv")
# print("2) regression_dataset_baseline_with_micro.csv")
# Out:
# baseline_df: (719, 37)
# binance    : (6983, 30)
# upbit      : (6983, 30)

# %%
# 2) micro variables 생성 (수정 버전)
coins = ["BTC", "ETH", "XRP", "SOL", "DOGE"]

micro = pd.DataFrame(index=baseline_df.index)

# --------------------------------------------------
# (A) BTC micro variables는 Binance full hourly 기준으로 먼저 계산
# --------------------------------------------------
btc_full = pd.DataFrame(index=binance.index.copy())
btc_full["BTC_CLOSE"] = binance["BTC_BINANCE_CLOSE"]

# 진짜 1시간 수익률
btc_full["BTC_RET"] = np.log(btc_full["BTC_CLOSE"]).diff()

# 진짜 24시간 rolling volatility
btc_full["BTC_VOL_24"] = btc_full["BTC_RET"].rolling(window=24, min_periods=24).std()

# 비대칭 shock 변수
btc_full["BTC_RET_POS"] = btc_full["BTC_RET"].clip(lower=0)
btc_full["BTC_RET_NEG"] = btc_full["BTC_RET"].clip(upper=0)
btc_full["BTC_RET_ABS"] = btc_full["BTC_RET"].abs()

# downside proxy: 최근 24시간 하방 반응
btc_full["BTC_DOWNSIDE_24"] = (
    btc_full["BTC_RET"].clip(upper=0) ** 2
).rolling(window=24, min_periods=24).mean()

# 큰 충격 dummy는 full hourly BTC_RET 기준으로 계산
up_thr = btc_full["BTC_RET"].quantile(0.95)
down_thr = btc_full["BTC_RET"].quantile(0.05)

btc_full["BTC_BIG_UP"] = (btc_full["BTC_RET"] >= up_thr).astype(int)
btc_full["BTC_BIG_DOWN"] = (btc_full["BTC_RET"] <= down_thr).astype(int)

# baseline sample index에 맞춰 가져오기
btc_cols = [
    "BTC_RET", "BTC_VOL_24",
    "BTC_RET_POS", "BTC_RET_NEG", "BTC_RET_ABS",
    "BTC_DOWNSIDE_24", "BTC_BIG_UP", "BTC_BIG_DOWN"
]

micro[btc_cols] = btc_full[btc_cols].reindex(baseline_df.index)

# --------------------------------------------------
# (B) coin-specific volume ratios
# --------------------------------------------------
for c in coins:
    bin_vol = binance[f"{c}_BINANCE_VOLUME"].reindex(baseline_df.index)
    up_vol = upbit[f"{c}_UPBIT_VOLUME"].reindex(baseline_df.index)

    # 0 또는 음수 로그 방지
    bin_vol = bin_vol.where(bin_vol > 0)
    up_vol = up_vol.where(up_vol > 0)

    ratio = bin_vol / up_vol
    micro[f"{c}_VOL_RATIO"] = ratio
    micro[f"{c}_VOL_RATIO_LOG"] = np.log(ratio)

# --------------------------------------------------
# (C) 추가 권장 변수 1: USDKRW return
# --------------------------------------------------
baseline_df["USDKRW_ret"] = np.log(baseline_df["USDKRW"]).diff()

# --------------------------------------------------
# (D) 추가 권장 변수 2: USDT-specific volume ratio
# --------------------------------------------------
usdt_bin_vol = binance["USDT_BINANCE_VOLUME"].reindex(baseline_df.index)
usdt_up_vol = upbit["USDT_UPBIT_VOLUME"].reindex(baseline_df.index)

usdt_bin_vol = usdt_bin_vol.where(usdt_bin_vol > 0)
usdt_up_vol = usdt_up_vol.where(usdt_up_vol > 0)

micro["USDT_VOL_RATIO"] = usdt_bin_vol / usdt_up_vol
micro["USDT_VOL_RATIO_LOG"] = np.log(micro["USDT_VOL_RATIO"])

print("\nMicro variables head:")
print(micro.head())

print("\nNaN counts in micro:")
print(micro.isna().sum())

# 3) merge
baseline_micro_df = baseline_df.join(micro, how="left")

print("\nMerged shape:", baseline_micro_df.shape)
print(baseline_micro_df.head())
# Out:
# Micro variables head:
#                             BTC_RET  BTC_VOL_24  BTC_RET_POS  BTC_RET_NEG  \
# datetime_utc
# 2025-06-02 09:00:00+00:00 -0.007080         NaN     0.000000    -0.007080
# 2025-06-02 10:00:00+00:00 -0.002053         NaN     0.000000    -0.002053
# 2025-06-02 11:00:00+00:00 -0.003102         NaN     0.000000    -0.003102
# 2025-06-02 12:00:00+00:00  0.001466         NaN     0.001466     0.000000
# 2025-06-03 09:00:00+00:00  0.000981    0.003214     0.000981     0.000000
#
#                            BTC_RET_ABS  BTC_DOWNSIDE_24  BTC_BIG_UP  \
# datetime_utc
# 2025-06-02 09:00:00+00:00     0.007080              NaN           0
# 2025-06-02 10:00:00+00:00     0.002053              NaN           0
# 2025-06-02 11:00:00+00:00     0.003102              NaN           0
# 2025-06-02 12:00:00+00:00     0.001466              NaN           0
# 2025-06-03 09:00:00+00:00     0.000981         0.000005           0
#
#                            BTC_BIG_DOWN  BTC_VOL_RATIO  BTC_VOL_RATIO_LOG  \
# datetime_utc
# 2025-06-02 09:00:00+00:00             1      17.682336           2.872566
# 2025-06-02 10:00:00+00:00             0      13.330279           2.590038
# 2025-06-02 11:00:00+00:00             0      12.860196           2.554137
# 2025-06-02 12:00:00+00:00             0       9.763010           2.278601
# 2025-06-03 09:00:00+00:00             0      12.730429           2.543995
#
#                            ETH_VOL_RATIO  ETH_VOL_RATIO_LOG  XRP_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00      14.116220           2.647324       2.226084
# 2025-06-02 10:00:00+00:00      15.805640           2.760367       2.254182
# 2025-06-02 11:00:00+00:00      12.636921           2.536623       1.336496
# 2025-06-02 12:00:00+00:00      10.556668           2.356758       2.091484
# 2025-06-03 09:00:00+00:00      16.230852           2.786914       1.907621
#
#                            XRP_VOL_RATIO_LOG  SOL_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00           0.800244      15.109090
# 2025-06-02 10:00:00+00:00           0.812787      14.617914
# 2025-06-02 11:00:00+00:00           0.290051      32.684554
# 2025-06-02 12:00:00+00:00           0.737874      24.945358
# 2025-06-03 09:00:00+00:00           0.645857      15.210237
#
#                            SOL_VOL_RATIO_LOG  DOGE_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00           2.715297        2.551379
# 2025-06-02 10:00:00+00:00           2.682248        4.512164
# 2025-06-02 11:00:00+00:00           3.486903        1.844553
# 2025-06-02 12:00:00+00:00           3.216688        2.394749
# 2025-06-03 09:00:00+00:00           2.721969        2.819423
#
#                            DOGE_VOL_RATIO_LOG  USDT_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00            0.936634        8.954279
# 2025-06-02 10:00:00+00:00            1.506777       18.139295
# 2025-06-02 11:00:00+00:00            0.612237       19.635228
# 2025-06-02 12:00:00+00:00            0.873278       35.155500
# 2025-06-03 09:00:00+00:00            1.036532       10.874272
#
#                            USDT_VOL_RATIO_LOG
# datetime_utc
# 2025-06-02 09:00:00+00:00            2.192131
# 2025-06-02 10:00:00+00:00            2.898081
# 2025-06-02 11:00:00+00:00            2.977325
# 2025-06-02 12:00:00+00:00            3.559781
# 2025-06-03 09:00:00+00:00            2.386400
#
# NaN counts in micro:
# BTC_RET               0
# BTC_VOL_24            4
# BTC_RET_POS           0
# BTC_RET_NEG           0
# BTC_RET_ABS           0
# BTC_DOWNSIDE_24       4
# BTC_BIG_UP            0
# BTC_BIG_DOWN          0
# BTC_VOL_RATIO         0
# BTC_VOL_RATIO_LOG     0
# ETH_VOL_RATIO         0
# ETH_VOL_RATIO_LOG     0
# XRP_VOL_RATIO         0
# XRP_VOL_RATIO_LOG     0
# SOL_VOL_RATIO         0
# SOL_VOL_RATIO_LOG     0
# DOGE_VOL_RATIO        0
# DOGE_VOL_RATIO_LOG    0
# USDT_VOL_RATIO        0
# USDT_VOL_RATIO_LOG    0
# dtype: int64
#
# Merged shape: (719, 58)
#                            BTC_BINANCE_CLOSE  ETH_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-02 09:00:00+00:00          104585.36            2481.52
# 2025-06-02 10:00:00+00:00          104370.85            2482.10
# 2025-06-02 11:00:00+00:00          104047.64            2480.94
# 2025-06-02 12:00:00+00:00          104200.32            2497.69
# 2025-06-03 09:00:00+00:00          105198.11            2614.49
#
#                            XRP_BINANCE_CLOSE  SOL_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-02 09:00:00+00:00             2.1531             153.54
# 2025-06-02 10:00:00+00:00             2.1462             154.01
# 2025-06-02 11:00:00+00:00             2.1430             153.45
# 2025-06-02 12:00:00+00:00             2.1522             154.21
# 2025-06-03 09:00:00+00:00             2.1990             159.89
#
#                            DOGE_BINANCE_CLOSE  USDT_BINANCE_CLOSE  \
# datetime_utc
# 2025-06-02 09:00:00+00:00             0.18968              0.9994
# 2025-06-02 10:00:00+00:00             0.19009              0.9994
# 2025-06-02 11:00:00+00:00             0.18928              0.9994
# 2025-06-02 12:00:00+00:00             0.19044              0.9994
# 2025-06-03 09:00:00+00:00             0.19481              0.9994
#
#                            BTC_UPBIT_CLOSE  ETH_UPBIT_CLOSE  XRP_UPBIT_CLOSE  \
# datetime_utc
# 2025-06-02 09:00:00+00:00      147099000.0        3492000.0           3028.0
# 2025-06-02 10:00:00+00:00      146961000.0        3493000.0           3021.0
# 2025-06-02 11:00:00+00:00      146546000.0        3492000.0           3018.0
# 2025-06-02 12:00:00+00:00      146594000.0        3511000.0           3026.0
# 2025-06-03 09:00:00+00:00      147280000.0        3657000.0           3076.0
#
#                            SOL_UPBIT_CLOSE  ...  ETH_VOL_RATIO  \
# datetime_utc                                ...
# 2025-06-02 09:00:00+00:00         216000.0  ...      14.116220
# 2025-06-02 10:00:00+00:00         216700.0  ...      15.805640
# 2025-06-02 11:00:00+00:00         216000.0  ...      12.636921
# 2025-06-02 12:00:00+00:00         216950.0  ...      10.556668
# 2025-06-03 09:00:00+00:00         223900.0  ...      16.230852
#
#                            ETH_VOL_RATIO_LOG  XRP_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00           2.647324       2.226084
# 2025-06-02 10:00:00+00:00           2.760367       2.254182
# 2025-06-02 11:00:00+00:00           2.536623       1.336496
# 2025-06-02 12:00:00+00:00           2.356758       2.091484
# 2025-06-03 09:00:00+00:00           2.786914       1.907621
#
#                            XRP_VOL_RATIO_LOG  SOL_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00           0.800244      15.109090
# 2025-06-02 10:00:00+00:00           0.812787      14.617914
# 2025-06-02 11:00:00+00:00           0.290051      32.684554
# 2025-06-02 12:00:00+00:00           0.737874      24.945358
# 2025-06-03 09:00:00+00:00           0.645857      15.210237
#
#                            SOL_VOL_RATIO_LOG  DOGE_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00           2.715297        2.551379
# 2025-06-02 10:00:00+00:00           2.682248        4.512164
# 2025-06-02 11:00:00+00:00           3.486903        1.844553
# 2025-06-02 12:00:00+00:00           3.216688        2.394749
# 2025-06-03 09:00:00+00:00           2.721969        2.819423
#
#                            DOGE_VOL_RATIO_LOG  USDT_VOL_RATIO  \
# datetime_utc
# 2025-06-02 09:00:00+00:00            0.936634        8.954279
# 2025-06-02 10:00:00+00:00            1.506777       18.139295
# 2025-06-02 11:00:00+00:00            0.612237       19.635228
# 2025-06-02 12:00:00+00:00            0.873278       35.155500
# 2025-06-03 09:00:00+00:00            1.036532       10.874272
#
#                            USDT_VOL_RATIO_LOG
# datetime_utc
# 2025-06-02 09:00:00+00:00            2.192131
# 2025-06-02 10:00:00+00:00            2.898081
# 2025-06-02 11:00:00+00:00            2.977325
# 2025-06-02 12:00:00+00:00            3.559781
# 2025-06-03 09:00:00+00:00            2.386400
#
# [5 rows x 58 columns]

# %% [markdown]
# baseline 데이터에 “BTC 기반 시장 상태 + 거래량 비율 + 환율 변화” 같은 micro 변수들을 추가해서 분석용 feature를 확장하는 코드
#
# 1️⃣ BTC 기반 시장 상태 변수
# - BTC_RET → 1시간 로그수익률
# - BTC_VOL_24 → 24시간 변동성
# - BTC_RET_POS / NEG / ABS → 비대칭 충격
# - BTC_DOWNSIDE_24 → 하방 리스크
# - BTC_BIG_UP / DOWN → 극단 이벤트 더미
#
# -> 시장 충격 / 변동성 / tail risk 변수
#
# 2️⃣ 코인별 거래량 비율
# - BINANCE_VOLUME / UPBIT_VOLUME
# - VOL_RATIO, VOL_RATIO_LOG
#
# -> 글로벌 vs 국내 수급 차이 proxy
#
# 3️⃣ 환율 변화
#
# - USDKRW_ret
#
# -> FX shock 변수
#
# 4️⃣ USDT 전용 변수
# - USDT_VOL_RATIO, USDT_VOL_RATIO_LOG
#
# -> stablecoin-specific 수급 변수

# %% [markdown]
# baseline_micro_df = baseline_df + micro variables

# %%
# 4) 회귀용 dataset 생성

# (A) KP 설명용 dataset
# reg_cols_kp = [
#     "USDT_KP",
#     "MKT_KP_EQ",
#     "BTC_KP", "ETH_KP", "XRP_KP", "SOL_KP", "DOGE_KP",
#     "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret",
#     "BTC_RET", "BTC_VOL_24",
#     "BTC_RET_POS", "BTC_RET_NEG", "BTC_RET_ABS",
#     "BTC_DOWNSIDE_24", "BTC_BIG_UP", "BTC_BIG_DOWN",
#     "BTC_VOL_RATIO_LOG", "ETH_VOL_RATIO_LOG", "XRP_VOL_RATIO_LOG",
#     "SOL_VOL_RATIO_LOG", "DOGE_VOL_RATIO_LOG"
# ]
reg_cols_kp = [
    "USDT_KP",
    "MKT_KP_EQ",
    "BTC_KP", "ETH_KP", "XRP_KP", "SOL_KP", "DOGE_KP",
    "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret", "USDKRW_ret",
    "BTC_RET", "BTC_VOL_24",
    "BTC_RET_POS", "BTC_RET_NEG", "BTC_RET_ABS",
    "BTC_DOWNSIDE_24", "BTC_BIG_UP", "BTC_BIG_DOWN",
    "BTC_VOL_RATIO_LOG", "ETH_VOL_RATIO_LOG", "XRP_VOL_RATIO_LOG",
    "SOL_VOL_RATIO_LOG", "DOGE_VOL_RATIO_LOG",
    "USDT_VOL_RATIO_LOG"
]

missing_kp = [c for c in reg_cols_kp if c not in baseline_micro_df.columns]
print("\nMissing columns in reg_cols_kp:", missing_kp)

reg_kp_df = baseline_micro_df[reg_cols_kp].dropna().copy()

print("\nreg_kp_df shape:", reg_kp_df.shape)
print(reg_kp_df.head())

# (B) Residual 설명용 dataset
# reg_cols_resid = [
#     "RESIDUAL_RAW",
#     "USDT_KP",
#     "MKT_KP_EQ",
#     "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret",
#     "BTC_RET", "BTC_VOL_24",
#     "BTC_RET_POS", "BTC_RET_NEG", "BTC_RET_ABS",
#     "BTC_DOWNSIDE_24", "BTC_BIG_UP", "BTC_BIG_DOWN",
#     "BTC_VOL_RATIO_LOG", "ETH_VOL_RATIO_LOG", "XRP_VOL_RATIO_LOG",
#     "SOL_VOL_RATIO_LOG", "DOGE_VOL_RATIO_LOG"
# ]
reg_cols_resid = [
    "RESIDUAL_RAW",
    "USDT_KP",
    "MKT_KP_EQ",
    "VIX_ret", "SPY_ret", "DXY_ret", "XAUUSD_ret", "USDKRW_ret",
    "BTC_RET", "BTC_VOL_24",
    "BTC_RET_POS", "BTC_RET_NEG", "BTC_RET_ABS",
    "BTC_DOWNSIDE_24", "BTC_BIG_UP", "BTC_BIG_DOWN",
    "BTC_VOL_RATIO_LOG", "ETH_VOL_RATIO_LOG", "XRP_VOL_RATIO_LOG",
    "SOL_VOL_RATIO_LOG", "DOGE_VOL_RATIO_LOG",
    "USDT_VOL_RATIO_LOG"
]

missing_resid = [c for c in reg_cols_resid if c not in baseline_micro_df.columns]
print("\nMissing columns in reg_cols_resid:", missing_resid)

reg_resid_df = baseline_micro_df[reg_cols_resid].dropna().copy()

print("\nreg_resid_df shape:", reg_resid_df.shape)
print(reg_resid_df.head())

# 5) 저장
baseline_micro_df.index.name = "datetime_utc"
reg_kp_df.index.name = "datetime_utc"
reg_resid_df.index.name = "datetime_utc"

baseline_micro_df.to_csv("baseline_dataset_with_micro.csv")
reg_kp_df.to_csv("regression_dataset_kp.csv")
reg_resid_df.to_csv("regression_dataset_residual.csv")

print("\n저장 완료")
print("1) baseline_dataset_with_micro.csv")
print("2) regression_dataset_kp.csv")
print("3) regression_dataset_residual.csv")
# Out:
# Missing columns in reg_cols_kp: []
#
# reg_kp_df shape: (715, 26)
#                             USDT_KP  MKT_KP_EQ    BTC_KP    ETH_KP    XRP_KP  \
# datetime_utc
# 2025-06-03 09:00:00+00:00  0.014801   0.014879  0.015298  0.014369  0.014423
# 2025-06-03 10:00:00+00:00  0.015364   0.015550  0.015599  0.015537  0.015275
# 2025-06-03 11:00:00+00:00  0.014405   0.014170  0.014067  0.014814  0.013589
# 2025-06-03 12:00:00+00:00  0.014606   0.014666  0.015402  0.014583  0.014199
# 2025-06-04 09:00:00+00:00  0.017073   0.016224  0.016048  0.016991  0.016028
#
#                              SOL_KP   DOGE_KP   VIX_ret   SPY_ret   DXY_ret  \
# datetime_utc
# 2025-06-03 09:00:00+00:00  0.015525  0.014781 -0.032226  0.006750  0.002777
# 2025-06-03 10:00:00+00:00  0.015781  0.015555 -0.018733  0.001893  0.000544
# 2025-06-03 11:00:00+00:00  0.013773  0.014608  0.000000  0.001839  0.000242
# 2025-06-03 12:00:00+00:00  0.014140  0.015004 -0.007817  0.001157 -0.000232
# 2025-06-04 09:00:00+00:00  0.016022  0.016032 -0.001122  0.001398 -0.003382
#
#                            ...  BTC_RET_ABS  BTC_DOWNSIDE_24  BTC_BIG_UP  \
# datetime_utc               ...
# 2025-06-03 09:00:00+00:00  ...     0.000981         0.000005           0
# 2025-06-03 10:00:00+00:00  ...     0.000788         0.000005           0
# 2025-06-03 11:00:00+00:00  ...     0.000059         0.000004           0
# 2025-06-03 12:00:00+00:00  ...     0.000197         0.000004           0
# 2025-06-04 09:00:00+00:00  ...     0.003686         0.000004           0
#
#                            BTC_BIG_DOWN  BTC_VOL_RATIO_LOG  ETH_VOL_RATIO_LOG  \
# datetime_utc
# 2025-06-03 09:00:00+00:00             0           2.543995           2.786914
# 2025-06-03 10:00:00+00:00             0           2.542522           2.783112
# 2025-06-03 11:00:00+00:00             0           2.063594           2.213595
# 2025-06-03 12:00:00+00:00             0           2.757255           2.118577
# 2025-06-04 09:00:00+00:00             0           3.135486           1.936312
#
#                            XRP_VOL_RATIO_LOG  SOL_VOL_RATIO_LOG  \
# datetime_utc
# 2025-06-03 09:00:00+00:00           0.645857           2.721969
# 2025-06-03 10:00:00+00:00           0.931404           2.844275
# 2025-06-03 11:00:00+00:00           0.841107           2.359952
# 2025-06-03 12:00:00+00:00           0.121273           2.802226
# 2025-06-04 09:00:00+00:00           0.225175           2.459097
#
#                            DOGE_VOL_RATIO_LOG  USDT_VOL_RATIO_LOG
# datetime_utc
# 2025-06-03 09:00:00+00:00            1.036532            2.386400
# 2025-06-03 10:00:00+00:00            1.180370            2.651287
# 2025-06-03 11:00:00+00:00            0.539042            2.879421
# 2025-06-03 12:00:00+00:00            1.104768            3.771512
# 2025-06-04 09:00:00+00:00            0.954689            2.175561
#
# [5 rows x 26 columns]
#
# Missing columns in reg_cols_resid: []
#
# reg_resid_df shape: (715, 22)
#                            RESIDUAL_RAW   USDT_KP  MKT_KP_EQ   VIX_ret  \
# datetime_utc
# 2025-06-03 09:00:00+00:00     -0.000078  0.014801   0.014879 -0.032226
# 2025-06-03 10:00:00+00:00     -0.000185  0.015364   0.015550 -0.018733
# 2025-06-03 11:00:00+00:00      0.000235  0.014405   0.014170  0.000000
# 2025-06-03 12:00:00+00:00     -0.000059  0.014606   0.014666 -0.007817
# 2025-06-04 09:00:00+00:00      0.000849  0.017073   0.016224 -0.001122
#
#                             SPY_ret   DXY_ret  XAUUSD_ret  USDKRW_ret  \
# datetime_utc
# 2025-06-03 09:00:00+00:00  0.006750  0.002777   -0.007708    0.000094
# 2025-06-03 10:00:00+00:00  0.001893  0.000544    0.000161   -0.000813
# 2025-06-03 11:00:00+00:00  0.001839  0.000242    0.001180    0.000588
# 2025-06-03 12:00:00+00:00  0.001157 -0.000232   -0.000519   -0.000914
# 2025-06-04 09:00:00+00:00  0.001398 -0.003382    0.001805   -0.007813
#
#                             BTC_RET  BTC_VOL_24  ...  BTC_RET_ABS  \
# datetime_utc                                     ...
# 2025-06-03 09:00:00+00:00  0.000981    0.003214  ...     0.000981
# 2025-06-03 10:00:00+00:00  0.000788    0.003178  ...     0.000788
# 2025-06-03 11:00:00+00:00  0.000059    0.003092  ...     0.000059
# 2025-06-03 12:00:00+00:00  0.000197    0.003086  ...     0.000197
# 2025-06-04 09:00:00+00:00  0.003686    0.003333  ...     0.003686
#
#                            BTC_DOWNSIDE_24  BTC_BIG_UP  BTC_BIG_DOWN  \
# datetime_utc
# 2025-06-03 09:00:00+00:00         0.000005           0             0
# 2025-06-03 10:00:00+00:00         0.000005           0             0
# 2025-06-03 11:00:00+00:00         0.000004           0             0
# 2025-06-03 12:00:00+00:00         0.000004           0             0
# 2025-06-04 09:00:00+00:00         0.000004           0             0
#
#                            BTC_VOL_RATIO_LOG  ETH_VOL_RATIO_LOG  \
# datetime_utc
# 2025-06-03 09:00:00+00:00           2.543995           2.786914
# 2025-06-03 10:00:00+00:00           2.542522           2.783112
# 2025-06-03 11:00:00+00:00           2.063594           2.213595
# 2025-06-03 12:00:00+00:00           2.757255           2.118577
# 2025-06-04 09:00:00+00:00           3.135486           1.936312
#
#                            XRP_VOL_RATIO_LOG  SOL_VOL_RATIO_LOG  \
# datetime_utc
# 2025-06-03 09:00:00+00:00           0.645857           2.721969
# 2025-06-03 10:00:00+00:00           0.931404           2.844275
# 2025-06-03 11:00:00+00:00           0.841107           2.359952
# 2025-06-03 12:00:00+00:00           0.121273           2.802226
# 2025-06-04 09:00:00+00:00           0.225175           2.459097
#
#                            DOGE_VOL_RATIO_LOG  USDT_VOL_RATIO_LOG
# datetime_utc
# 2025-06-03 09:00:00+00:00            1.036532            2.386400
# 2025-06-03 10:00:00+00:00            1.180370            2.651287
# 2025-06-03 11:00:00+00:00            0.539042            2.879421
# 2025-06-03 12:00:00+00:00            1.104768            3.771512
# 2025-06-04 09:00:00+00:00            0.954689            2.175561
#
# [5 rows x 22 columns]
#
# 저장 완료
# 1) baseline_dataset_with_micro.csv
# 2) regression_dataset_kp.csv
# 3) regression_dataset_residual.csv

# %% [markdown]
# - strict baseline clean panel 기반
# - USDT premium과 market premium 분리
# - residual을 별도 종속변수 후보로 보관
# - asymmetric shock 반영

# %%
print("\nMissing columns in reg_cols_kp:", missing_kp)
print("\nMissing columns in reg_cols_resid:", missing_resid)
# Out:
# Missing columns in reg_cols_kp: []
#
# Missing columns in reg_cols_resid: []

# %% [markdown]
# 비트코인, 스테이블코인 끝 ==

# %% [markdown]
# regression 기반 진짜 residual 생성

# %% [markdown]
# [ RESIDUAL_OLS가 핵심 변수 ]
#
# RESIDUAL_RAW : 단순 차이 / USDT_KP - MKT_KP_EQ
#
# RESIDUAL_OLS : 회귀 기반 / 공통요인 제거된 잔차

# %%
import pandas as pd
import statsmodels.api as sm

df = pd.read_csv(
    "regression_dataset_residual.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

# Step 1: USDT_KP ~ MKT_KP_EQ
X = sm.add_constant(df["MKT_KP_EQ"])
y = df["USDT_KP"]

model = sm.OLS(y, X).fit()

print(model.summary())

# Step 2: residual
df["RESIDUAL_OLS"] = model.resid
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                USDT_KP   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 2.435e+05
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):               0.00
# Time:                        11:49:05   Log-Likelihood:                 3958.3
# No. Observations:                 715   AIC:                            -7913.
# Df Residuals:                     713   BIC:                            -7903.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001   4.13e-05      3.334      0.001    5.66e-05       0.000
# MKT_KP_EQ      0.9892      0.002    493.471      0.000       0.985       0.993
# ==============================================================================
# Omnibus:                      110.919   Durbin-Watson:                   1.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.629
# Skew:                          -0.888   Prob(JB):                     1.67e-49
# Kurtosis:                       5.094   Cond. No.                         56.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# [ 시장 공통 프리미엄을 제거해서 RESIDUAL_OLS를 만드는 코드 ]

# %% [markdown]
# 1. “김치 프리미엄은 대부분 공통 시장 요인이고, USDT는 거의 완벽하게 그걸 따라간다.”
#
#     기존 연구: “USDT premium 자체 분석”
#
#     연구: “USDT premium 중에서도 residual만이 진짜 의미 있음
#
#     RESIDUAL_OLS = “시장 공통 요인으로 설명 안 되는 USDT 특이 프리미엄”
#
# 2. Durbin-Watson ≈ 1.08 -> 잔차 자기상관 있음
#
#     시계열 구조 있음
#
#     그냥 OLS로 끝내면 안 됨
#
#     -> 나중에 HAC / Newey-West 써야 함

# %% [markdown]
# [그렇게 만든 residual이 어떤 변수들에 의해 설명되는지 보는 코드]
#
# RESIDUAL_OLS를 종속변수로 두고 거시 변수 + BTC micro 변수로 회귀해서
#
# “시장 공통 요인을 제거하고도 남은 USDT 고유 괴리가, 외부 충격이나 BTC 리스크 변수와 관련이 있는가?”
#
# 를 보는 코드

# %%
import statsmodels.api as sm

# X 구성 (핵심 변수만 먼저)
X = df[
    [
        "VIX_ret",
        "SPY_ret",
        "DXY_ret",
        "XAUUSD_ret",
        "BTC_RET",
        "BTC_VOL_24",
        "BTC_RET_NEG",
        "BTC_DOWNSIDE_24",
        "BTC_BIG_DOWN"
    ]
]

X = sm.add_constant(X)
y = df["RESIDUAL_OLS"]

# model = sm.OLS(y, X).fit()
model = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           RESIDUAL_OLS   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     4.072
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           4.12e-05
# Time:                        11:49:05   Log-Likelihood:                 3999.7
# No. Observations:                 715   AIC:                            -7979.
# Df Residuals:                     705   BIC:                            -7934.
# Df Model:                           9
# Covariance Type:                  HAC
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0002      0.000      1.548      0.122   -5.24e-05       0.000
# VIX_ret            -0.0002      0.001     -0.203      0.839      -0.002       0.002
# SPY_ret             0.0046      0.012      0.388      0.698      -0.018       0.028
# DXY_ret            -0.0034      0.015     -0.217      0.828      -0.034       0.027
# XAUUSD_ret          0.0007      0.004      0.182      0.855      -0.007       0.008
# BTC_RET            -0.0224      0.020     -1.129      0.259      -0.061       0.017
# BTC_VOL_24          0.0250      0.038      0.664      0.507      -0.049       0.099
# BTC_RET_NEG         0.0544      0.040      1.374      0.169      -0.023       0.132
# BTC_DOWNSIDE_24   -20.3576      5.831     -3.491      0.000     -31.786      -8.929
# BTC_BIG_DOWN      7.41e-05      0.000      0.215      0.830      -0.001       0.001
# ==============================================================================
# Omnibus:                       89.828   Durbin-Watson:                   1.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              199.036
# Skew:                          -0.707   Prob(JB):                     6.03e-44
# Kurtosis:                       5.164   Cond. No.                     1.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 1.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# [
# - RESIDUAL_OLS는 완전한 noise는 아님
# - 모형 전체가 유의함
# - 거시 수익률 변수들은 별 설명력이 없음. VIX/SPY/DXY/XAUUSD 모두 유의하지 않음
# - BTC 관련 변수 중에서는 최근 24시간 downside stress가 핵심
# - BTC_DOWNSIDE_24만 강하게 유의한 음(-)의 효과
#
# 따라서 USDT residual은 시장 공통 premium 제거 후에도, crypto downside stress에 비대칭적으로 반응할 가능성이 있음
#
# 시장 공통 김치프리미엄을 제거한 뒤에도 USDT residual은 단순 거시충격보다 BTC의 누적 하방 스트레스(BTC_DOWNSIDE_24)에 유의하게 반응하며, 그 방향은 음(-)이다.
#
# ]

# %% [markdown]
# 첫째, Step 1에서 만든 RESIDUAL_OLS를 Step 2에서 설명변수로 돌린 흐름이 맞다. 즉 지금은 “시장 공통 김프를 제거하고도 남는 USDT 고유 괴리”를 설명하려는 구조로 가고 있어서, 연구 방향과 맞다.
#
# 둘째, HAC 표준오차를 쓴 것도 맞다. Durbin-Watson이 여전히 1.256이라 자기상관이 남아 있고, 시계열 데이터라 HAC를 쓰는 게 맞다.
#
# 셋째, 완전히 아무 것도 안 나오는 결과는 아니다. BTC_DOWNSIDE_24가 유의하고, 전체 F-stat도 유의하다. 즉 residual이 완전히 순수 잡음은 아니라는 신호는 있다.
#
# 유의하지 않은 것 :
#     VIX_ret
#     SPY_ret
#     DXY_ret
#     XAUUSD_ret
#     BTC_RET
#     BTC_VOL_24
#     BTC_RET_NEG
#     BTC_BIG_DOWN
#
# 이 변수들은 현재 specification에서는 residual 설명력이 약해 보임

# %% [markdown]
# USDT premium 자체는 거의 전부 시장 공통 김프로 설명된다. (Step 1 결과)
#
# 그걸 제거한 residual은 크지 않고, 그 residual 중 설명 가능한 부분도 제한적이다. 다만 단순 수익률 부호보다 downside stress 누적 지표가 더 중요할 수 있다
#
# 즉 “수익률이 올라도 김프가 세고, 떨어져도 김프가 세다”는 피드백 때문에 단순 BTC_RET 하나로는 안 된다고 했잖아. 지금 결과도 실제로 BTC_RET는 안 잡히고, BTC_DOWNSIDE_24 같은 비선형/누적 스트레스 지표만 잡힌다는 쪽으로 나오고 있음

# %%
# Cell 1: 현재 df에서 depeg 후보 컬럼 확인
print("df columns:")
print(df.columns.tolist())

candidate_cols = [
    c for c in df.columns
    if ("DEPEG" in c.upper())
    or ("USDC" in c.upper())
    or ("GLOBAL" in c.upper())
    or ("USDTUSD" in c.upper())
    or ("USDCUSDT" in c.upper())
    or ("USDTUSDC" in c.upper())
]

print("\nPossible depeg-related columns:")
print(candidate_cols)
# Out:
# df columns:
# ['RESIDUAL_RAW', 'USDT_KP', 'MKT_KP_EQ', 'VIX_ret', 'SPY_ret', 'DXY_ret', 'XAUUSD_ret', 'USDKRW_ret', 'BTC_RET', 'BTC_VOL_24', 'BTC_RET_POS', 'BTC_RET_NEG', 'BTC_RET_ABS', 'BTC_DOWNSIDE_24', 'BTC_BIG_UP', 'BTC_BIG_DOWN', 'BTC_VOL_RATIO_LOG', 'ETH_VOL_RATIO_LOG', 'XRP_VOL_RATIO_LOG', 'SOL_VOL_RATIO_LOG', 'DOGE_VOL_RATIO_LOG', 'USDT_VOL_RATIO_LOG', 'RESIDUAL_OLS']
#
# Possible depeg-related columns:
# []

# %%
# Cell 2: 현재 메모리에 있는 원천 데이터에서 depeg 후보 찾기

for name, obj in list(globals().items()):
    if isinstance(obj, pd.DataFrame):
        cols = [c for c in obj.columns if ("USDT" in c.upper()) or ("USDC" in c.upper())]
        if len(cols) > 0:
            print(f"\n[{name}]")
            print(cols)
# Out:
# [df]
# ['USDT_KP', 'USDT_VOL_RATIO_LOG']
#
# [df_b]
# ['USDT_BINANCE_OPEN', 'USDT_BINANCE_HIGH', 'USDT_BINANCE_LOW', 'USDT_BINANCE_CLOSE', 'USDT_BINANCE_VOLUME']
#
# [df_binance]
# ['USDT_BINANCE_OPEN', 'USDT_BINANCE_HIGH', 'USDT_BINANCE_LOW', 'USDT_BINANCE_CLOSE', 'USDT_BINANCE_VOLUME']
#
# [df_u]
# ['USDT_UPBIT_OPEN', 'USDT_UPBIT_HIGH', 'USDT_UPBIT_LOW', 'USDT_UPBIT_CLOSE', 'USDT_UPBIT_VOLUME']
#
# [df_upbit]
# ['USDT_UPBIT_OPEN', 'USDT_UPBIT_HIGH', 'USDT_UPBIT_LOW', 'USDT_UPBIT_CLOSE', 'USDT_UPBIT_VOLUME']
#
# [binance]
# ['USDT_BINANCE_OPEN', 'USDT_BINANCE_HIGH', 'USDT_BINANCE_LOW', 'USDT_BINANCE_CLOSE', 'USDT_BINANCE_VOLUME']
#
# [upbit]
# ['USDT_UPBIT_OPEN', 'USDT_UPBIT_HIGH', 'USDT_UPBIT_LOW', 'USDT_UPBIT_CLOSE', 'USDT_UPBIT_VOLUME']
#
# [bin_close]
# ['USDT_BINANCE_CLOSE']
#
# [up_close]
# ['USDT_UPBIT_CLOSE']
#
# [panel]
# ['USDT_BINANCE_CLOSE', 'USDT_UPBIT_CLOSE', 'USDT_KP', 'USDT_KP_pct']
#
# [final_df]
# ['USDT_BINANCE_CLOSE', 'USDT_UPBIT_CLOSE', 'USDT_KP', 'USDT_KP_pct']
#
# [baseline_df]
# ['USDT_BINANCE_CLOSE', 'USDT_UPBIT_CLOSE', 'USDT_KP', 'USDT_KP_pct']
#
# [reg_df]
# ['USDT_KP']
#
# [micro]
# ['USDT_VOL_RATIO', 'USDT_VOL_RATIO_LOG']
#
# [baseline_micro_df]
# ['USDT_BINANCE_CLOSE', 'USDT_UPBIT_CLOSE', 'USDT_KP', 'USDT_KP_pct', 'USDT_VOL_RATIO', 'USDT_VOL_RATIO_LOG']
#
# [reg_kp_df]
# ['USDT_KP', 'USDT_VOL_RATIO_LOG']
#
# [reg_resid_df]
# ['USDT_KP', 'USDT_VOL_RATIO_LOG']

# %%
# Cell 3: USDT_BINANCE_CLOSE 값 범위 확인
print("USDT_BINANCE_CLOSE head:")
print(baseline_micro_df["USDT_BINANCE_CLOSE"].head(10))

print("\nUSDT_BINANCE_CLOSE summary:")
print(baseline_micro_df["USDT_BINANCE_CLOSE"].describe())
# Out:
# USDT_BINANCE_CLOSE head:
# datetime_utc
# 2025-06-02 09:00:00+00:00    0.9994
# 2025-06-02 10:00:00+00:00    0.9994
# 2025-06-02 11:00:00+00:00    0.9994
# 2025-06-02 12:00:00+00:00    0.9994
# 2025-06-03 09:00:00+00:00    0.9994
# 2025-06-03 10:00:00+00:00    0.9993
# 2025-06-03 11:00:00+00:00    0.9993
# 2025-06-03 12:00:00+00:00    0.9993
# 2025-06-04 09:00:00+00:00    0.9993
# 2025-06-04 10:00:00+00:00    0.9993
# Name: USDT_BINANCE_CLOSE, dtype: float64
#
# USDT_BINANCE_CLOSE summary:
# count    719.000000
# mean       0.999929
# std        0.000477
# min        0.999100
# 25%        0.999600
# 50%        0.999900
# 75%        1.000100
# max        1.001600
# Name: USDT_BINANCE_CLOSE, dtype: float64

# %% [markdown]
# [ depeg 관련 변수를 새로 만들기 전에, 이미 확보한 데이터에서 어떤 컬럼을 depeg proxy로 쓸 수 있는지 확인하는 탐색 단계 ]

# %%
# Cell 4: baseline_micro_df에서 depeg 변수 붙이기

df = df.join(baseline_micro_df[["USDT_BINANCE_CLOSE"]], how="left")

df["DEPEG_GLOBAL"] = (df["USDT_BINANCE_CLOSE"] - 1.0).abs()

print(df[["USDT_BINANCE_CLOSE", "DEPEG_GLOBAL"]].head())
print("\nMissing DEPEG_GLOBAL:", df["DEPEG_GLOBAL"].isna().sum())
print("\nDEPEG summary:")
print(df["DEPEG_GLOBAL"].describe())
# Out:
#                            USDT_BINANCE_CLOSE  DEPEG_GLOBAL
# datetime_utc
# 2025-06-03 09:00:00+00:00              0.9994        0.0006
# 2025-06-03 10:00:00+00:00              0.9993        0.0007
# 2025-06-03 11:00:00+00:00              0.9993        0.0007
# 2025-06-03 12:00:00+00:00              0.9993        0.0007
# 2025-06-04 09:00:00+00:00              0.9993        0.0007
#
# Missing DEPEG_GLOBAL: 0
#
# DEPEG summary:
# count    715.000000
# mean       0.000375
# std        0.000302
# min        0.000000
# 25%        0.000100
# 50%        0.000300
# 75%        0.000500
# max        0.001600
# Name: DEPEG_GLOBAL, dtype: float64

# %%
# Cell 5: Stage 2 residual (depeg 제거)

import statsmodels.api as sm

X = sm.add_constant(df["DEPEG_GLOBAL"])
y = df["RESIDUAL_OLS"]

model_depeg = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})

print(model_depeg.summary())

# 최종 residual
df["RESIDUAL_FINAL"] = model_depeg.resid

print("\nRESIDUAL_FINAL summary:")
print(df["RESIDUAL_FINAL"].describe())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           RESIDUAL_OLS   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     4.101
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):             0.0432
# Time:                        11:49:05   Log-Likelihood:                 3967.2
# No. Observations:                 715   AIC:                            -7930.
# Df Residuals:                     713   BIC:                            -7921.
# Df Model:                           1
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0002   9.78e-05      1.904      0.057   -5.46e-06       0.000
# DEPEG_GLOBAL    -0.4964      0.245     -2.025      0.043      -0.977      -0.016
# ==============================================================================
# Omnibus:                      113.130   Durbin-Watson:                   1.104
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              259.716
# Skew:                          -0.858   Prob(JB):                     4.01e-57
# Kurtosis:                       5.402   Cond. No.                     3.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 3.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# RESIDUAL_FINAL summary:
# count    7.150000e+02
# mean    -7.763797e-20
# std      9.426537e-04
# min     -5.410193e-03
# 25%     -5.257328e-04
# 50%      8.890861e-05
# 75%      6.222176e-04
# max      2.273317e-03
# Name: RESIDUAL_FINAL, dtype: float64

# %% [markdown]
# [이미 만든 RESIDUAL_OLS에 글로벌 stablecoin depeg 요인을 하나 더 붙인 것]
#
# USDT_BINANCE_CLOSE가 1달러에서 얼마나 벗어났는지 절대값으로 측정
#
# 즉 글로벌 USDT depeg 강도 proxy 생성
#
# 시장 공통 김치프리미엄을 제거한 residual에서, 이번에는 글로벌 depeg 성분까지 추가로 제거한 것 (회귀)
#
# RESIDUAL_FINAL은:
#
# - 1차로 USDT_KP ~ MKT_KP_EQ 해서 시장 공통 프리미엄 제거
# - 2차로 RESIDUAL_OLS ~ DEPEG_GLOBAL 해서 글로벌 depeg 제거
#
# 를 거친 뒤 남은 값

# %% [markdown]
# 더 clean한 spec을 만들어야 함

# %%
# X = df[
#     [
#         "DXY_ret",
#         "BTC_VOL_24",
#         "BTC_DOWNSIDE_24"
#     ]
# ]

# X = sm.add_constant(X)
# y = df["RESIDUAL_OLS"]

# model = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})
# print(model.summary())
# Cell 6: 진짜 구조 분석 (Stage 3)

import statsmodels.api as sm

X = df[
    [
        "DXY_ret",
        "BTC_VOL_24",
        "BTC_DOWNSIDE_24"
    ]
]

X = sm.add_constant(X)

# 여기만 바뀜
y = df["RESIDUAL_FINAL"]

model = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     7.461
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           6.36e-05
# Time:                        11:49:05   Log-Likelihood:                 3998.5
# No. Observations:                 715   AIC:                            -7989.
# Df Residuals:                     711   BIC:                            -7971.
# Df Model:                           3
# Covariance Type:                  HAC
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0002      0.000      1.433      0.152   -6.93e-05       0.000
# DXY_ret            -0.0070      0.014     -0.487      0.626      -0.035       0.021
# BTC_VOL_24          0.0028      0.040      0.070      0.944      -0.075       0.080
# BTC_DOWNSIDE_24   -17.2660      6.178     -2.795      0.005     -29.375      -5.157
# ==============================================================================
# Omnibus:                       94.223   Durbin-Watson:                   1.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.386
# Skew:                          -0.714   Prob(JB):                     1.88e-49
# Kurtosis:                       5.343   Cond. No.                     1.12e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 1.12e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# [ 이미 시장프리미엄(RESIDUL_OLS), 글로벌 depeg(RESIDUAL_FINAL) 제거했고, “그래도 남은 한국 USDT 고유 괴리가 무엇에 의해 설명되는지” 보는 회귀 ]

# %% [markdown]
# [ DXY_ret → 달러 강세 영향
#
# BTC_VOL_24 → 시장 변동성
#
# BTC_DOWNSIDE_24 → 하방 스트레스 (핵심)
#
# 즉 macro + crypto risk → 한국 USDT 괴리 설명 ]

# %% [markdown]
# BTC_DOWNSIDE_24 계수 음수 : downside stress ↑ → residual ↓
#
# downside stress (누적 하락 압력) → 유의

# %%
plot_df = df[["RESIDUAL_FINAL", "BTC_DOWNSIDE_24"]].dropna().copy()

plot_df = (plot_df - plot_df.mean()) / plot_df.std()

plot_df.plot(figsize=(12,5), title="Standardized: Residual vs Downside")
# Out:
# <Axes: title={'center': 'Standardized: Residual vs Downside'}, xlabel='datetime_utc'>

# %% [markdown]
# downside risk와 residual이 같이 움직이는지 직관적으로 확인
#
# 모든 공통 요인을 제거한 뒤 남은 USDT 고유 괴리를, BTC 하방 리스크와 거시변수로 설명하고, 동시에 둘의 동행성을 시각적으로 확인하는 단계

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1) 비교용 데이터 준비
compare_df = df[["RESIDUAL_FINAL", "BTC_DOWNSIDE_24"]].dropna().copy()

# 표준화
compare_df["RESIDUAL_Z"] = (
    compare_df["RESIDUAL_FINAL"] - compare_df["RESIDUAL_FINAL"].mean()
) / compare_df["RESIDUAL_FINAL"].std()

compare_df["DOWNSIDE_Z"] = (
    compare_df["BTC_DOWNSIDE_24"] - compare_df["BTC_DOWNSIDE_24"].mean()
) / compare_df["BTC_DOWNSIDE_24"].std()

# 2) 차이(Residual - Downside)
compare_df["Z_DIFF"] = compare_df["RESIDUAL_Z"] - compare_df["DOWNSIDE_Z"]
compare_df["Z_SUM"]  = compare_df["RESIDUAL_Z"] + compare_df["DOWNSIDE_Z"]

print("Head:")
print(compare_df[["RESIDUAL_Z", "DOWNSIDE_Z", "Z_DIFF"]].head())

print("\nSummary:")
print(compare_df[["RESIDUAL_Z", "DOWNSIDE_Z", "Z_DIFF"]].describe())

# 3) 전체 상관계수
corr = compare_df["RESIDUAL_Z"].corr(compare_df["DOWNSIDE_Z"])
print("\nCorrelation(Residual_Z, Downside_Z):", corr)

# 4) 단순 회귀: 표준화 residual ~ 표준화 downside
X = sm.add_constant(compare_df["DOWNSIDE_Z"])
y = compare_df["RESIDUAL_Z"]

model_std = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})
print("\nRegression: RESIDUAL_Z ~ DOWNSIDE_Z")
print(model_std.summary())

# 5) rolling correlation
window = 24
compare_df["ROLL_CORR_24"] = (
    compare_df["RESIDUAL_Z"].rolling(window).corr(compare_df["DOWNSIDE_Z"])
)

# 6) plot
plt.figure(figsize=(12, 5))
plt.plot(compare_df.index, compare_df["Z_DIFF"], label="Z_DIFF = Residual_Z - Downside_Z")
plt.axhline(0, linestyle="--")
plt.title("Standardized Difference: Residual - Downside")
plt.xlabel("datetime_utc")
plt.ylabel("Z-score difference")
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
plt.plot(compare_df.index, compare_df["ROLL_CORR_24"], label="24h Rolling Corr")
plt.axhline(0, linestyle="--")
plt.title("24h Rolling Correlation: Residual vs Downside")
plt.xlabel("datetime_utc")
plt.ylabel("Correlation")
plt.legend()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(compare_df["DOWNSIDE_Z"], compare_df["RESIDUAL_Z"], alpha=0.5)
plt.xlabel("DOWNSIDE_Z")
plt.ylabel("RESIDUAL_Z")
plt.title("Scatter: Residual_Z vs Downside_Z")
plt.show()
# Out:
# Head:
#                            RESIDUAL_Z  DOWNSIDE_Z    Z_DIFF
# datetime_utc
# 2025-06-03 09:00:00+00:00    0.060030   -0.424500  0.484530
# 2025-06-03 10:00:00+00:00    0.006784   -0.435480  0.442263
# 2025-06-03 11:00:00+00:00    0.436185   -0.460536  0.896720
# 2025-06-03 12:00:00+00:00    0.130264   -0.460536  0.590799
# 2025-06-04 09:00:00+00:00    1.111652   -0.450348  1.562000
#
# Summary:
#          RESIDUAL_Z  DOWNSIDE_Z        Z_DIFF
# count  7.150000e+02  715.000000  7.150000e+02
# mean   3.975064e-17    0.000000  3.975064e-17
# std    1.000000e+00    1.000000  1.605663e+00
# min   -5.739322e+00   -0.686195 -1.174646e+01
# 25%   -5.577158e-01   -0.511235 -6.325908e-01
# 50%    9.431737e-02   -0.277498  2.853119e-01
# 75%    6.600702e-01    0.163425  9.983973e-01
# max    2.411614e+00    9.546653  2.690434e+00
#
# Correlation(Residual_Z, Downside_Z): -0.28907728091964
#
# Regression: RESIDUAL_Z ~ DOWNSIDE_Z
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             RESIDUAL_Z   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     20.39
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           7.38e-06
# Time:                        11:49:07   Log-Likelihood:                -982.84
# No. Observations:                 715   AIC:                             1970.
# Df Residuals:                     713   BIC:                             1979.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.125e-17      0.058   3.68e-16      1.000      -0.113       0.113
# DOWNSIDE_Z    -0.2891      0.064     -4.516      0.000      -0.415      -0.164
# ==============================================================================
# Omnibus:                       93.631   Durbin-Watson:                   1.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              223.459
# Skew:                          -0.709   Prob(JB):                     3.00e-49
# Kurtosis:                       5.343   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction

# %%
# 차이가 큰 구간 상위 10개
top_gap = compare_df["Z_DIFF"].abs().sort_values(ascending=False).head(10)
print("\nTop 10 absolute gaps:")
print(compare_df.loc[top_gap.index, ["RESIDUAL_Z", "DOWNSIDE_Z", "Z_DIFF"]])
# Out:
# Top 10 absolute gaps:
#                            RESIDUAL_Z  DOWNSIDE_Z     Z_DIFF
# datetime_utc
# 2026-02-06 10:00:00+00:00   -2.445731    9.300729 -11.746460
# 2026-02-06 09:00:00+00:00   -2.184074    9.546653 -11.730727
# 2026-02-06 11:00:00+00:00   -0.383878    9.148419  -9.532297
# 2025-12-01 09:00:00+00:00   -4.529948    3.576871  -8.106819
# 2025-12-01 11:00:00+00:00   -4.156876    3.643969  -7.800845
# 2025-11-21 10:00:00+00:00   -2.483332    5.006010  -7.489343
# 2025-12-01 10:00:00+00:00   -3.859242    3.568023  -7.427264
# 2025-11-21 09:00:00+00:00   -1.384362    5.012825  -6.397187
# 2025-11-21 11:00:00+00:00   -1.045854    5.065393  -6.111247
# 2026-02-04 11:00:00+00:00   -1.334605    4.034399  -5.369004

# %% [markdown]
# [ USDT residual은 BTC downside risk와 관련되어 움직이지만, 극단적 하방 상황에서는 그 충격을 완전히 반영하지 못하고 상대적으로 둔화된 반응을 보인다. ]

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(6,5))
# plt.scatter(df["BTC_DOWNSIDE_24"], df["RESIDUAL_FINAL"], alpha=0.3)
# plt.xlabel("BTC_DOWNSIDE_24")
# plt.ylabel("RESIDUAL_FINAL")
# plt.title("Residual vs Downside (Scatter)")
# plt.show()

# %%
# thr = df["BTC_DOWNSIDE_24"].quantile(0.9)

# subset = df[df["BTC_DOWNSIDE_24"] >= thr]

# subset[["RESIDUAL_FINAL", "BTC_DOWNSIDE_24"]].plot(
#     figsize=(12,5),
#     title="Top 10% Downside Periods"
# )

# %%
df.loc[df["BTC_DOWNSIDE_24"].nlargest(10).index, 
       ["RESIDUAL_FINAL", "BTC_DOWNSIDE_24", "DXY_ret", "DEPEG_GLOBAL"]]
# Out:
#                            RESIDUAL_FINAL  BTC_DOWNSIDE_24   DXY_ret  \
# datetime_utc
# 2026-02-06 09:00:00+00:00       -0.002059         0.000164 -0.000553
# 2026-02-06 10:00:00+00:00       -0.002305         0.000160 -0.000594
# 2026-02-06 11:00:00+00:00       -0.000362         0.000158  0.000205
# 2025-11-21 11:00:00+00:00       -0.000986         0.000093 -0.000339
# 2025-11-21 09:00:00+00:00       -0.001305         0.000092  0.000389
# 2025-11-21 10:00:00+00:00       -0.002341         0.000092  0.000678
# 2026-02-04 11:00:00+00:00       -0.001258         0.000076 -0.001014
# 2026-02-04 09:00:00+00:00       -0.000290         0.000076  0.001960
# 2026-02-04 10:00:00+00:00       -0.001241         0.000076  0.001117
# 2025-12-01 11:00:00+00:00       -0.003918         0.000070 -0.000151
#
#                            DEPEG_GLOBAL
# datetime_utc
# 2026-02-06 09:00:00+00:00        0.0012
# 2026-02-06 10:00:00+00:00        0.0011
# 2026-02-06 11:00:00+00:00        0.0010
# 2025-11-21 11:00:00+00:00        0.0010
# 2025-11-21 09:00:00+00:00        0.0010
# 2025-11-21 10:00:00+00:00        0.0009
# 2026-02-04 11:00:00+00:00        0.0012
# 2026-02-04 09:00:00+00:00        0.0012
# 2026-02-04 10:00:00+00:00        0.0011
# 2025-12-01 11:00:00+00:00        0.0000

# %%
# X = df[
#     [
#         "BTC_DOWNSIDE_24",
#         "DXY_ret"
#     ]
# ]

# X = sm.add_constant(X)
# y = df["RESIDUAL_OLS"]

# model = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})
# print(model.summary())
X = df[
    [
        "BTC_DOWNSIDE_24",
        "DXY_ret"
    ]
]

X = sm.add_constant(X)
y = df["RESIDUAL_FINAL"]

model = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     10.26
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           4.05e-05
# Time:                        11:49:08   Log-Likelihood:                 3998.5
# No. Observations:                 715   AIC:                            -7991.
# Df Residuals:                     712   BIC:                            -7977.
# Df Model:                           2
# Covariance Type:                  HAC
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0002   5.86e-05      3.362      0.001    8.22e-05       0.000
# BTC_DOWNSIDE_24   -16.9953      3.757     -4.523      0.000     -24.359      -9.631
# DXY_ret            -0.0069      0.014     -0.481      0.630      -0.035       0.021
# ==============================================================================
# Omnibus:                       94.145   Durbin-Watson:                   1.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.364
# Skew:                          -0.713   Prob(JB):                     1.91e-49
# Kurtosis:                       5.344   Cond. No.                     6.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 6.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# [ BTC downside effect가 다른 변수 없이도 독립적으로 유효한지 검증하는 코드 ]
#
# [ 시장 공통 premium과 글로벌 depeg를 제거한 뒤에도, 한국 USDT residual은 BTC의 누적 하방 스트레스에 유의하게 음(-)의 방향으로 반응하며, 이 효과는 축소모형에서도 유지된다. ]

# %% [markdown]
# 12월~1월 구간에서
# - downside_24 급증
# - residual 급락 (큰 음수 spike)

# %%
# import statsmodels.formula.api as smf

# # 90% quantile (premium 높은 구간)
# model_q90 = smf.quantreg(
#     "RESIDUAL_OLS ~ BTC_DOWNSIDE_24 + DXY_ret",
#     df
# ).fit(q=0.9)

# print(model_q90.summary())
import statsmodels.formula.api as smf

model_q10 = smf.quantreg(
    "RESIDUAL_FINAL ~ BTC_DOWNSIDE_24 + DXY_ret",
    df
).fit(q=0.1)

print(model_q10.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   Pseudo R-squared:              0.05651
# Model:                       QuantReg   Bandwidth:                   0.0003984
# Method:                 Least Squares   Sparsity:                     0.006563
# Date:                Thu, 09 Apr 2026   No. Observations:                  715
# Time:                        11:49:08   Df Residuals:                      712
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -0.0007   8.72e-05     -8.502      0.000      -0.001      -0.001
# BTC_DOWNSIDE_24   -42.2044      3.927    -10.747      0.000     -49.915     -34.494
# DXY_ret             0.0310      0.034      0.922      0.357      -0.035       0.097
# ===================================================================================
#
# The condition number is large, 6.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model_q50 = smf.quantreg(
    "RESIDUAL_FINAL ~ BTC_DOWNSIDE_24 + DXY_ret",
    df
).fit(q=0.5)

print(model_q50.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   Pseudo R-squared:              0.04183
# Model:                       QuantReg   Bandwidth:                   0.0004572
# Method:                 Least Squares   Sparsity:                     0.001977
# Date:                Thu, 09 Apr 2026   No. Observations:                  715
# Time:                        11:49:08   Df Residuals:                      712
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.0002   4.57e-05      5.286      0.000       0.000       0.000
# BTC_DOWNSIDE_24   -15.9406      2.315     -6.886      0.000     -20.486     -11.395
# DXY_ret            -0.0156      0.018     -0.853      0.394      -0.051       0.020
# ===================================================================================
#
# The condition number is large, 6.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model_q90 = smf.quantreg(
    "RESIDUAL_FINAL ~ BTC_DOWNSIDE_24 + DXY_ret",
    df
).fit(q=0.9)

print(model_q90.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   Pseudo R-squared:              0.02783
# Model:                       QuantReg   Bandwidth:                   0.0003847
# Method:                 Least Squares   Sparsity:                     0.004043
# Date:                Thu, 09 Apr 2026   No. Observations:                  715
# Time:                        11:49:08   Df Residuals:                      712
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.0012   5.97e-05     19.924      0.000       0.001       0.001
# BTC_DOWNSIDE_24    -9.7697      3.465     -2.819      0.005     -16.573      -2.966
# DXY_ret            -0.0485      0.017     -2.792      0.005      -0.083      -0.014
# ===================================================================================
#
# The condition number is large, 6.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# [ BTC downside는 평균 효과가 아니라 “위기 상황에서 폭발하는 변수”다 ]

# %% [markdown]
# 두 Quantile 결과를 보면,
#
# - 첫 번째가 상위 분위수(q=0.9)
# - 두 번째가 하위 분위수(q=0.1)
#
# 그 기준으로 해석하면:
#
# 1. BTC_DOWNSIDE_24는 두 분위수 모두 강하게 유의
#     q=0.9: 계수 약 -1.03, 유의
#     q=0.1: 계수 약 -3.71, 유의
#
#     이건 아주 중요한 결과야.     즉, BTC downside stress 누적이 residual에 영향을 준다는 건 평균회귀뿐 아니라 분위수 회귀에서도 유지된다.
#
#     그리고 더 중요한 건, 하위 분위수에서 절대값이 훨씬 크다는 점이야. 즉, residual이 하단 꼬리로 크게 무너지는 구간에서 downside stress의 영향이 훨씬 강하다는 뜻
#
#     단순 평균적 움직임이 아니라, 극단 구간에서 residual의 반응 구조가 다르다.
#
# 2. DXY_ret는 상위 분위수에서만 약하게 유의
#     q=0.9에서는 유의
#     q=0.1에서는 유의하지 않음
#
#     즉, 달러 스트레스는 모든 극단 구간에 공통으로 작동하는 게 아니라, 특정 꼬리에서만 의미 있을 수 있다는 신호.

# %% [markdown]
# 시장 공통 김프를 제거한 뒤에도 USDT residual이 의미 있는가
# 그 residual은 언제 커지거나 오래 가는가
# 평균이 아니라 극단 구간에서 작동하는 비대칭성이 있는가
#
# 지금 결과는 최소한 3번에 대해 강한 지지를 준다.
#
# 특히,
#
# OLS에서는 BTC_DOWNSIDE_24가 유의했고
# Quantile에서도 유의했고
# 특히 하위 꼬리에서 더 강하게 유의
#
# 하니까, “Residual은 단순 noise가 아니라 downside stress에 비대칭적으로 반응한다”는 방향으로 가고 있다고 볼 수 있어.

# %%
# Cell 1: quantile sweep (수정 버전)
import pandas as pd
import statsmodels.formula.api as smf

quantiles = [0.1, 0.25, 0.5, 0.75, 0.9]
results = []

for q in quantiles:
    mod = smf.quantreg(
        "RESIDUAL_FINAL ~ BTC_DOWNSIDE_24 + DXY_ret",
        df
    ).fit(q=q)

    results.append({
        "q": q,
        "beta_downside": mod.params["BTC_DOWNSIDE_24"],
        "p_downside": mod.pvalues["BTC_DOWNSIDE_24"],
        "beta_dxy": mod.params["DXY_ret"],
        "p_dxy": mod.pvalues["DXY_ret"],
    })

res_df = pd.DataFrame(results)
print(res_df)
# Out:
#       q  beta_downside    p_downside  beta_dxy     p_dxy
# 0  0.10     -42.204414  4.548972e-25  0.031043  0.357062
# 1  0.25     -21.659251  4.038692e-16  0.008612  0.716173
# 2  0.50     -15.940615  1.264727e-11 -0.015573  0.393801
# 3  0.75     -13.295889  1.085414e-06 -0.019450  0.307101
# 4  0.90      -9.769672  4.946970e-03 -0.048481  0.005380

# %% [markdown]
# q ↓ → coefficient magnitude ↑
#
# downside stress 효과가 lower tail에서 훨씬 강하다
#
# 평상시는 영향 약함 / 극단 상황에는 영향 폭발
#
# p-value 전 구간에서 거의 0 -> robustness 확보
#
# downside stress = core driver :
#
#     DXY = 보조적 / 특정 구간만 영향

# %%
# Cell 2: quantile coefficient plot
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.plot(res_df["q"], res_df["beta_downside"], marker="o")
plt.axhline(0, linestyle="--")
plt.xlabel("Quantile")
plt.ylabel("Coefficient on BTC_DOWNSIDE_24")
plt.title("Quantile Regression Coefficients: RESIDUAL_FINAL")
plt.show()

# %%
# model_raw_q10 = smf.quantreg(
#     "USDT_KP ~ BTC_DOWNSIDE_24 + DXY_ret",
#     df
# ).fit(q=0.1)

# model_raw_q90 = smf.quantreg(
#     "USDT_KP ~ BTC_DOWNSIDE_24 + DXY_ret",
#     df
# ).fit(q=0.9)

# print(model_raw_q10.summary())
# print(model_raw_q90.summary())

# %%
# print("q=0.1 params")
# print(model_raw_q10.params)
# print(model_raw_q10.pvalues)

# print("\nq=0.9 params")
# print(model_raw_q90.params)
# print(model_raw_q90.pvalues)

# %%
# raw_res = pd.DataFrame({
#     "q": [0.1, 0.9],
#     "beta_downside": [model_raw_q10.params["BTC_DOWNSIDE_24"],
#                       model_raw_q90.params["BTC_DOWNSIDE_24"]],
#     "p_downside": [model_raw_q10.pvalues["BTC_DOWNSIDE_24"],
#                    model_raw_q90.pvalues["BTC_DOWNSIDE_24"]],
#     "beta_dxy": [model_raw_q10.params["DXY_ret"],
#                  model_raw_q90.params["DXY_ret"]],
#     "p_dxy": [model_raw_q10.pvalues["DXY_ret"],
#               model_raw_q90.pvalues["DXY_ret"]],
# })
# print(raw_res)

# %%
# import statsmodels.formula.api as smf
# import pandas as pd

# model_raw_q10 = smf.quantreg(
#     "USDT_KP ~ BTC_DOWNSIDE_24 + DXY_ret",
#     df
# ).fit(q=0.1)

# model_raw_q50 = smf.quantreg(
#     "USDT_KP ~ BTC_DOWNSIDE_24 + DXY_ret",
#     df
# ).fit(q=0.5)

# model_raw_q90 = smf.quantreg(
#     "USDT_KP ~ BTC_DOWNSIDE_24 + DXY_ret",
#     df
# ).fit(q=0.9)

# raw_quantile_res = pd.DataFrame({
#     "q": [0.1, 0.5, 0.9],
#     "beta_downside": [
#         model_raw_q10.params["BTC_DOWNSIDE_24"],
#         model_raw_q50.params["BTC_DOWNSIDE_24"],
#         model_raw_q90.params["BTC_DOWNSIDE_24"],
#     ],
#     "p_downside": [
#         model_raw_q10.pvalues["BTC_DOWNSIDE_24"],
#         model_raw_q50.pvalues["BTC_DOWNSIDE_24"],
#         model_raw_q90.pvalues["BTC_DOWNSIDE_24"],
#     ],
#     "beta_dxy": [
#         model_raw_q10.params["DXY_ret"],
#         model_raw_q50.params["DXY_ret"],
#         model_raw_q90.params["DXY_ret"],
#     ],
#     "p_dxy": [
#         model_raw_q10.pvalues["DXY_ret"],
#         model_raw_q50.pvalues["DXY_ret"],
#         model_raw_q90.pvalues["DXY_ret"],
#     ],
# })

# print(raw_quantile_res)

# %% [markdown]
# downside stress ↑ → USDT premium 자체는 커진다
#
# 즉 BTC 하락 압력 누적 → 한국 USDT 가격이 더 비싸진다 (달러 수요 ↑)

# %%
# Cell 1: VIX level 붙이고 HIGH_STRESS 만들기

# df에는 현재 VIX_ret만 있고 VIX level은 없으므로 baseline_micro_df에서 붙임
if "VIX" not in df.columns:
    df = df.join(baseline_micro_df[["VIX"]], how="left")

print("Missing VIX after join:", df["VIX"].isna().sum())

# high-stress threshold: sample 75th percentile
vix_thr = df["VIX"].quantile(0.75)
df["HIGH_STRESS"] = (df["VIX"] >= vix_thr).astype(int)

print("VIX threshold:", vix_thr)
print(df["HIGH_STRESS"].value_counts(dropna=False))
# Out:
# Missing VIX after join: 0
# VIX threshold: 18.735
# HIGH_STRESS
# 0    536
# 1    179
# Name: count, dtype: int64

# %% [markdown]
# BTC downside 효과가 quantile 때문이냐 vs 진짜 시장 스트레스 때문이냐 -> quantile 결과 해석을 더 강화하려는 시도

# %%
# Cell 2: regime sample 확인

df_high = df[df["HIGH_STRESS"] == 1].copy()
df_low  = df[df["HIGH_STRESS"] == 0].copy()

print("HIGH_STRESS shape:", df_high.shape)
print("LOW_STRESS shape :", df_low.shape)

print("\nHIGH_STRESS VIX summary")
print(df_high["VIX"].describe())

print("\nLOW_STRESS VIX summary")
print(df_low["VIX"].describe())
# Out:
# HIGH_STRESS shape: (179, 28)
# LOW_STRESS shape : (536, 28)
#
# HIGH_STRESS VIX summary
# count    179.000000
# mean      21.750559
# std        2.554920
# min       18.750000
# 25%       19.710000
# 50%       20.870000
# 75%       23.370000
# max       31.570000
# Name: VIX, dtype: float64
#
# LOW_STRESS VIX summary
# count    536.000000
# mean      16.332780
# std        1.108623
# min       13.480000
# 25%       15.440000
# 50%       16.435000
# 75%       17.065000
# max       18.720000
# Name: VIX, dtype: float64

# %%
# Cell 3: regime split OLS

import statsmodels.api as sm

def run_regime_ols(data, label):
    tmp = data[["RESIDUAL_FINAL", "BTC_DOWNSIDE_24", "DXY_ret"]].dropna().copy()

    X = tmp[["BTC_DOWNSIDE_24", "DXY_ret"]]
    X = sm.add_constant(X)
    y = tmp["RESIDUAL_FINAL"]

    model = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})

    print(f"\n===== {label} =====")
    print(model.summary())

run_regime_ols(df_high, "HIGH STRESS")
run_regime_ols(df_low, "LOW STRESS")
# Out:
# ===== HIGH STRESS =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     7.212
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           0.000976
# Time:                        11:49:08   Log-Likelihood:                 991.06
# No. Observations:                 179   AIC:                            -1976.
# Df Residuals:                     176   BIC:                            -1967.
# Df Model:                           2
# Covariance Type:                  HAC
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0001      0.000      0.798      0.425      -0.000       0.000
# BTC_DOWNSIDE_24   -12.6541      3.361     -3.765      0.000     -19.241      -6.067
# DXY_ret            -0.0066      0.023     -0.288      0.773      -0.052       0.038
# ==============================================================================
# Omnibus:                        0.282   Durbin-Watson:                   1.566
# Prob(Omnibus):                  0.869   Jarque-Bera (JB):                0.438
# Skew:                          -0.045   Prob(JB):                        0.803
# Kurtosis:                       2.775   Cond. No.                     5.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 5.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== LOW STRESS =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     4.011
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):             0.0187
# Time:                        11:49:08   Log-Likelihood:                 3009.6
# No. Observations:                 536   AIC:                            -6013.
# Df Residuals:                     533   BIC:                            -6000.
# Df Model:                           2
# Covariance Type:                  HAC
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0002   7.04e-05      3.230      0.001    8.94e-05       0.000
# BTC_DOWNSIDE_24   -19.7565      6.983     -2.829      0.005     -33.443      -6.070
# DXY_ret            -0.0068      0.019     -0.363      0.716      -0.043       0.030
# ==============================================================================
# Omnibus:                      108.051   Durbin-Watson:                   1.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.062
# Skew:                          -0.938   Prob(JB):                     2.36e-74
# Kurtosis:                       6.415   Cond. No.                     7.25e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 7.25e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Cell 4: interaction regression

tmp = df[["RESIDUAL_FINAL", "BTC_DOWNSIDE_24", "DXY_ret", "HIGH_STRESS"]].dropna().copy()
tmp["DOWN_x_STRESS"] = tmp["BTC_DOWNSIDE_24"] * tmp["HIGH_STRESS"]

X = tmp[["BTC_DOWNSIDE_24", "HIGH_STRESS", "DOWN_x_STRESS", "DXY_ret"]]
X = sm.add_constant(X)
y = tmp["RESIDUAL_FINAL"]

model_inter = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": 5})
print(model_inter.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     8.085
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           2.23e-06
# Time:                        11:49:08   Log-Likelihood:                 3999.8
# No. Observations:                 715   AIC:                            -7990.
# Df Residuals:                     710   BIC:                            -7967.
# Df Model:                           4
# Covariance Type:                  HAC
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0002    6.9e-05      3.292      0.001     9.2e-05       0.000
# BTC_DOWNSIDE_24   -19.7568      6.671     -2.962      0.003     -32.831      -6.682
# HIGH_STRESS        -0.0001      0.000     -0.855      0.392      -0.000       0.000
# DOWN_x_STRESS       7.1031      7.547      0.941      0.347      -7.689      21.895
# DXY_ret            -0.0067      0.014     -0.467      0.640      -0.035       0.021
# ==============================================================================
# Omnibus:                       88.621   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.694
# Skew:                          -0.674   Prob(JB):                     1.07e-46
# Kurtosis:                       5.300   Cond. No.                     1.50e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# [2] The condition number is large, 1.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# HIGH_STRESS가 언제 발생했는지 시간 확인
stress_dates = df.loc[df["HIGH_STRESS"] == 1].index.to_series()

print("First 20 HIGH_STRESS timestamps:")
print(stress_dates.head(20))

print("\nLast 20 HIGH_STRESS timestamps:")
print(stress_dates.tail(20))

# 날짜별 개수 집계
stress_by_day = stress_dates.dt.date.value_counts().sort_index()
print("\nHIGH_STRESS counts by day:")
print(stress_by_day.tail(30))
# Out:
# First 20 HIGH_STRESS timestamps:
# datetime_utc
# 2025-06-13 09:00:00+00:00   2025-06-13 09:00:00+00:00
# 2025-06-13 10:00:00+00:00   2025-06-13 10:00:00+00:00
# 2025-06-13 11:00:00+00:00   2025-06-13 11:00:00+00:00
# 2025-06-13 12:00:00+00:00   2025-06-13 12:00:00+00:00
# 2025-06-16 09:00:00+00:00   2025-06-16 09:00:00+00:00
# 2025-06-16 10:00:00+00:00   2025-06-16 10:00:00+00:00
# 2025-06-16 11:00:00+00:00   2025-06-16 11:00:00+00:00
# 2025-06-16 12:00:00+00:00   2025-06-16 12:00:00+00:00
# 2025-06-17 09:00:00+00:00   2025-06-17 09:00:00+00:00
# 2025-06-17 10:00:00+00:00   2025-06-17 10:00:00+00:00
# 2025-06-17 11:00:00+00:00   2025-06-17 11:00:00+00:00
# 2025-06-17 12:00:00+00:00   2025-06-17 12:00:00+00:00
# 2025-06-18 09:00:00+00:00   2025-06-18 09:00:00+00:00
# 2025-06-18 10:00:00+00:00   2025-06-18 10:00:00+00:00
# 2025-06-18 11:00:00+00:00   2025-06-18 11:00:00+00:00
# 2025-06-18 12:00:00+00:00   2025-06-18 12:00:00+00:00
# 2025-06-20 09:00:00+00:00   2025-06-20 09:00:00+00:00
# 2025-06-20 10:00:00+00:00   2025-06-20 10:00:00+00:00
# 2025-06-20 11:00:00+00:00   2025-06-20 11:00:00+00:00
# 2025-06-20 12:00:00+00:00   2025-06-20 12:00:00+00:00
# Name: datetime_utc, dtype: datetime64[ns, UTC]
#
# Last 20 HIGH_STRESS timestamps:
# datetime_utc
# 2026-03-13 09:00:00+00:00   2026-03-13 09:00:00+00:00
# 2026-03-13 10:00:00+00:00   2026-03-13 10:00:00+00:00
# 2026-03-13 11:00:00+00:00   2026-03-13 11:00:00+00:00
# 2026-03-13 12:00:00+00:00   2026-03-13 12:00:00+00:00
# 2026-03-16 09:00:00+00:00   2026-03-16 09:00:00+00:00
# 2026-03-16 10:00:00+00:00   2026-03-16 10:00:00+00:00
# 2026-03-16 11:00:00+00:00   2026-03-16 11:00:00+00:00
# 2026-03-16 12:00:00+00:00   2026-03-16 12:00:00+00:00
# 2026-03-17 09:00:00+00:00   2026-03-17 09:00:00+00:00
# 2026-03-17 10:00:00+00:00   2026-03-17 10:00:00+00:00
# 2026-03-17 11:00:00+00:00   2026-03-17 11:00:00+00:00
# 2026-03-17 12:00:00+00:00   2026-03-17 12:00:00+00:00
# 2026-03-18 09:00:00+00:00   2026-03-18 09:00:00+00:00
# 2026-03-18 10:00:00+00:00   2026-03-18 10:00:00+00:00
# 2026-03-18 11:00:00+00:00   2026-03-18 11:00:00+00:00
# 2026-03-18 12:00:00+00:00   2026-03-18 12:00:00+00:00
# 2026-03-19 09:00:00+00:00   2026-03-19 09:00:00+00:00
# 2026-03-19 10:00:00+00:00   2026-03-19 10:00:00+00:00
# 2026-03-19 11:00:00+00:00   2026-03-19 11:00:00+00:00
# 2026-03-19 12:00:00+00:00   2026-03-19 12:00:00+00:00
# Name: datetime_utc, dtype: datetime64[ns, UTC]
#
# HIGH_STRESS counts by day:
# datetime_utc
# 2026-01-21    1
# 2026-01-29    1
# 2026-02-04    2
# 2026-02-05    3
# 2026-02-06    1
# 2026-02-12    2
# 2026-02-13    3
# 2026-02-17    3
# 2026-02-18    3
# 2026-02-19    3
# 2026-02-20    3
# 2026-02-23    3
# 2026-02-24    3
# 2026-02-25    1
# 2026-02-26    3
# 2026-02-27    3
# 2026-03-02    3
# 2026-03-03    3
# 2026-03-04    3
# 2026-03-05    3
# 2026-03-06    3
# 2026-03-09    4
# 2026-03-10    4
# 2026-03-11    4
# 2026-03-12    4
# 2026-03-13    4
# 2026-03-16    4
# 2026-03-17    4
# 2026-03-18    4
# 2026-03-19    4
# Name: count, dtype: int64

# %% [markdown]
# cell 3 - 시장 불안 구간에서 BTC downside 효과가 더 큰지 직접 비교하려고
#
# cell 4 - high-stress일 때 BTC downside 효과가 통계적으로 더 강해지는지 한 번에 검정하려고
#
# “BTC downside 효과가 단순 평균 효과가 아니라, VIX가 높은 스트레스 국면에서 더 강해지는가?"를 알아보려고 한 거고, 그 질문에 가장 직접적으로 답하는 건 interaction regression 결과임.

# %% [markdown]
# BTC downside 효과는 시장 불안 때문이 아니라, tail-risk 구조 자체에서 발생한다.

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(12,3))
# plt.plot(df.index, df["HIGH_STRESS"], drawstyle="steps-post")
# plt.title("HIGH_STRESS over time")
# plt.xlabel("datetime_utc")
# plt.ylabel("HIGH_STRESS")
# plt.show()

# %% [markdown]
# 아까 residual에서는 음수
#
# 지금 raw에서는 양수
#
# raw → 전체 효과 (양) / residual → 시장공통 제거 후 남은 부분 (다른 방향 가능)

# %% [markdown]
# BTC downside stress는 USDT premium을 강하게 증가시킨다

# %%
# df["USDT_KP"].describe()

# %% [markdown]
# standarization

# %%
# df["BTC_DOWNSIDE_24_std"] = (
#     df["BTC_DOWNSIDE_24"] - df["BTC_DOWNSIDE_24"].mean()
# ) / df["BTC_DOWNSIDE_24"].std()
# standardized downside
df["BTC_DOWNSIDE_24_std"] = (
    df["BTC_DOWNSIDE_24"] - df["BTC_DOWNSIDE_24"].mean()
) / df["BTC_DOWNSIDE_24"].std()

# %%
# import statsmodels.formula.api as smf

# quantiles = [0.1, 0.5, 0.9]

# results_std = []

# for q in quantiles:
#     mod = smf.quantreg(
#         "USDT_KP ~ BTC_DOWNSIDE_24_std + DXY_ret",
#         df
#     ).fit(q=q)

#     results_std.append({
#         "q": q,
#         "beta_downside_std": mod.params["BTC_DOWNSIDE_24_std"],
#         "p_downside_std": mod.pvalues["BTC_DOWNSIDE_24_std"],
#         "beta_dxy": mod.params["DXY_ret"],
#         "p_dxy": mod.pvalues["DXY_ret"],
#     })

# res_std_df = pd.DataFrame(results_std)
# print(res_std_df)

#beta_downside_std 음수나와야함
import statsmodels.formula.api as smf

quantiles = [0.1, 0.5, 0.9]
results_q = []

for q in quantiles:
    mod = smf.quantreg(
        "RESIDUAL_FINAL ~ BTC_DOWNSIDE_24_std + DXY_ret",
        df
    ).fit(q=q)

    results_q.append({
        "q": q,
        "beta_downside_std": mod.params["BTC_DOWNSIDE_24_std"],
        "p_downside_std": mod.pvalues["BTC_DOWNSIDE_24_std"],
        "beta_dxy": mod.params["DXY_ret"],
        "p_dxy": mod.pvalues["DXY_ret"],
    })

res_q_df = pd.DataFrame(results_q)
print(res_q_df)
# Out:
#      q  beta_downside_std  p_downside_std  beta_dxy     p_dxy
# 0  0.1          -0.000675    4.562606e-25  0.031042  0.357086
# 1  0.5          -0.000255    1.361316e-11 -0.015857  0.385494
# 2  0.9          -0.000156    4.946970e-03 -0.048481  0.005380

# %%
# Cell 1: standardized downside가 제대로 만들어졌는지 확인
print(df[["BTC_DOWNSIDE_24", "BTC_DOWNSIDE_24_std"]].describe())

corr_val = df[["BTC_DOWNSIDE_24", "BTC_DOWNSIDE_24_std"]].corr().iloc[0,1]
print("\nCorrelation:", corr_val)
# Out:
#        BTC_DOWNSIDE_24  BTC_DOWNSIDE_24_std
# count     7.150000e+02           715.000000
# mean      1.159116e-05             0.000000
# std       1.599683e-05             1.000000
# min       6.142127e-07            -0.686195
# 25%       3.413023e-06            -0.511235
# 50%       7.152076e-06            -0.277498
# 75%       1.420545e-05             0.163425
# max       1.643074e-04             9.546653
#
# Correlation: 1.0000000000000007

# %%
# Cell 2: 같은 종속변수(RESIDUAL_FINAL)로 standardized downside OLS 재확인
import statsmodels.formula.api as smf

mod_check = smf.ols(
    "RESIDUAL_FINAL ~ BTC_DOWNSIDE_24_std + DXY_ret",
    data=df
).fit()

print(mod_check.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     32.56
# Date:                Thu, 09 Apr 2026   Prob (F-statistic):           2.96e-14
# Time:                        11:49:08   Log-Likelihood:                 3998.5
# No. Observations:                 715   AIC:                            -7991.
# Df Residuals:                     712   BIC:                            -7977.
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            5.121e-08   3.38e-05      0.002      0.999   -6.63e-05    6.64e-05
# BTC_DOWNSIDE_24_std    -0.0003   3.38e-05     -8.032      0.000      -0.000      -0.000
# DXY_ret                -0.0069      0.017     -0.415      0.678      -0.040       0.026
# ==============================================================================
# Omnibus:                       94.145   Durbin-Watson:                   1.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.364
# Skew:                          -0.713   Prob(JB):                     1.91e-49
# Kurtosis:                       5.344   Cond. No.                         494.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Cell 3: ETH full-hourly return / downside 생성
import pandas as pd
import numpy as np

eth_full = pd.DataFrame(index=binance.index.copy())
eth_full["ETH_CLOSE"] = binance["ETH_BINANCE_CLOSE"]

eth_full["ETH_RET"] = np.log(eth_full["ETH_CLOSE"]).diff()

eth_full["ETH_DOWNSIDE_24"] = (
    eth_full["ETH_RET"].clip(upper=0) ** 2
).rolling(window=24, min_periods=24).mean()

# 현재 분석 표본 df index에 맞춰 붙이기
df["ETH_DOWNSIDE_24"] = eth_full["ETH_DOWNSIDE_24"].reindex(df.index)

print(df[["ETH_DOWNSIDE_24"]].head())
print("\nMissing ETH_DOWNSIDE_24:", df["ETH_DOWNSIDE_24"].isna().sum())
# Out:
#                            ETH_DOWNSIDE_24
# datetime_utc
# 2025-06-03 09:00:00+00:00         0.000009
# 2025-06-03 10:00:00+00:00         0.000009
# 2025-06-03 11:00:00+00:00         0.000009
# 2025-06-03 12:00:00+00:00         0.000009
# 2025-06-04 09:00:00+00:00         0.000013
#
# Missing ETH_DOWNSIDE_24: 0

# %%
# Cell 4: ETH downside standardized
df["ETH_DOWNSIDE_24_std"] = (
    df["ETH_DOWNSIDE_24"] - df["ETH_DOWNSIDE_24"].mean()
) / df["ETH_DOWNSIDE_24"].std()

print(df[["ETH_DOWNSIDE_24", "ETH_DOWNSIDE_24_std"]].describe())
# Out:
#        ETH_DOWNSIDE_24  ETH_DOWNSIDE_24_std
# count       715.000000         7.150000e+02
# mean          0.000028         3.975064e-17
# std           0.000031         1.000000e+00
# min           0.000001        -8.487780e-01
# 25%           0.000009        -5.893787e-01
# 50%           0.000016        -3.684091e-01
# 75%           0.000034         2.193432e-01
# max           0.000235         6.738101e+00

# %%
# Cell 5: ETH downside quantile regression
import statsmodels.formula.api as smf
import pandas as pd

quantiles = [0.1, 0.5, 0.9]
results_eth = []

for q in quantiles:
    mod = smf.quantreg(
        "RESIDUAL_FINAL ~ ETH_DOWNSIDE_24_std + DXY_ret",
        df
    ).fit(q=q)

    results_eth.append({
        "q": q,
        "beta_eth_std": mod.params["ETH_DOWNSIDE_24_std"],
        "p_eth_std": mod.pvalues["ETH_DOWNSIDE_24_std"],
        "beta_dxy": mod.params["DXY_ret"],
        "p_dxy": mod.pvalues["DXY_ret"],
    })

res_eth_df = pd.DataFrame(results_eth)
print(res_eth_df)
# Out:
#      q  beta_eth_std  p_eth_std  beta_dxy     p_dxy
# 0  0.1     -0.000182   0.011482  0.037535  0.282443
# 1  0.5     -0.000111   0.004707 -0.011225  0.560014
# 2  0.9     -0.000017   0.685413 -0.065000  0.000460

# %%
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(df["RESIDUAL_FINAL"].dropna())

print("ADF Statistic:", adf_result[0])
print("p-value:", adf_result[1])
print("Used lags:", adf_result[2])
print("N obs:", adf_result[3])
print("Critical values:")
for k, v in adf_result[4].items():
    print(f"  {k}: {v}")
# Out:
# ADF Statistic: -3.5670739562817975
# p-value: 0.00642261605787704
# Used lags: 15
# N obs: 699
# Critical values:
#   1%: -3.439739809554328
#   5%: -2.86568368980381
#   10%: -2.5689766074363334

# %%
from statsmodels.tsa.stattools import kpss

kpss_result = kpss(df["RESIDUAL_FINAL"].dropna(), regression="c", nlags="auto")

print("KPSS Statistic:", kpss_result[0])
print("p-value:", kpss_result[1])
print("Used lags:", kpss_result[2])
print("Critical values:")
for k, v in kpss_result[3].items():
    print(f"  {k}: {v}")
# Out:
# KPSS Statistic: 1.9023426280742655
# p-value: 0.01
# Used lags: 14
# Critical values:
#   10%: 0.347
#   5%: 0.463
#   2.5%: 0.574
#   1%: 0.739
# C:\Users\김수빈\AppData\Local\Temp\ipykernel_49928\511776910.py:3: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_result = kpss(df["RESIDUAL_FINAL"].dropna(), regression="c", nlags="auto")

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

lb = acorr_ljungbox(df["RESIDUAL_FINAL"].dropna(), lags=[5, 10, 20], return_df=True)
print(lb)
# Out:
#        lb_stat      lb_pvalue
# 5   443.692147   1.126806e-93
# 10  616.352992  5.511761e-126
# 20  918.482012  9.148386e-182

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plot_acf(df["RESIDUAL_FINAL"].dropna(), lags=30, ax=axes[0])
plot_pacf(df["RESIDUAL_FINAL"].dropna(), lags=30, ax=axes[1], method="ywm")
axes[0].set_title("ACF of RESIDUAL_FINAL")
axes[1].set_title("PACF of RESIDUAL_FINAL")
plt.tight_layout()
plt.show()

# %%
# Cell 1: VAR용 데이터셋
var_df = df[["BTC_DOWNSIDE_24_std", "RESIDUAL_FINAL"]].dropna().copy()

print(var_df.shape)
print(var_df.head())
print(var_df.describe())
# Out:
# (715, 2)
#                            BTC_DOWNSIDE_24_std  RESIDUAL_FINAL
# datetime_utc
# 2025-06-03 09:00:00+00:00            -0.424500        0.000057
# 2025-06-03 10:00:00+00:00            -0.435480        0.000006
# 2025-06-03 11:00:00+00:00            -0.460536        0.000411
# 2025-06-03 12:00:00+00:00            -0.460536        0.000123
# 2025-06-04 09:00:00+00:00            -0.450348        0.001048
#        BTC_DOWNSIDE_24_std  RESIDUAL_FINAL
# count           715.000000    7.150000e+02
# mean              0.000000   -7.763797e-20
# std               1.000000    9.426537e-04
# min              -0.686195   -5.410193e-03
# 25%              -0.511235   -5.257328e-04
# 50%              -0.277498    8.890861e-05
# 75%               0.163425    6.222176e-04
# max               9.546653    2.273317e-03

# %%
# Cell 2: 단순 상관 확인
print(var_df.corr())
# Out:
#                      BTC_DOWNSIDE_24_std  RESIDUAL_FINAL
# BTC_DOWNSIDE_24_std             1.000000       -0.289077
# RESIDUAL_FINAL                 -0.289077        1.000000

# %%
# Cell 3: VAR lag selection
from statsmodels.tsa.api import VAR

var_model = VAR(var_df)
lag_sel = var_model.select_order(10)

print(lag_sel.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -14.01      -13.99   8.270e-07      -14.00
# 1       -15.06      -15.02   2.891e-07      -15.04
# 2       -15.10      -15.04   2.757e-07      -15.08
# 3       -15.14      -15.05   2.657e-07      -15.11
# 4       -15.26     -15.14*   2.366e-07     -15.21*
# 5       -15.26      -15.11   2.366e-07      -15.20
# 6       -15.25      -15.08   2.379e-07      -15.19
# 7      -15.26*      -15.07  2.351e-07*      -15.19
# 8       -15.25      -15.03   2.371e-07      -15.17
# 9       -15.25      -15.01   2.379e-07      -15.16
# 10      -15.24      -14.97   2.400e-07      -15.14
# --------------------------------------------------
# c:\Users\김수빈\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Cell 4: VAR 적합 (메인 스펙: BIC 기준 lag 4)
p = 4

var_res = var_model.fit(p)

print(var_res.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 09, Apr, 2026
# Time:                     11:49:09
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -15.1490
# Nobs:                     711.000    HQIC:                  -15.2200
# Log likelihood:           3426.85    FPE:                2.34775e-07
# AIC:                     -15.2646    Det(Omega_mle):     2.28942e-07
# --------------------------------------------------------------------
# Results for equation BTC_DOWNSIDE_24_std
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                          0.001976         0.022290            0.089           0.929
# L1.BTC_DOWNSIDE_24_std         0.878287         0.035947           24.433           0.000
# L1.RESIDUAL_FINAL            -51.336423        27.737934           -1.851           0.064
# L2.BTC_DOWNSIDE_24_std         0.010427         0.045948            0.227           0.820
# L2.RESIDUAL_FINAL             18.070359        28.764676            0.628           0.530
# L3.BTC_DOWNSIDE_24_std        -0.443820         0.045993           -9.650           0.000
# L3.RESIDUAL_FINAL            -24.618360        28.799401           -0.855           0.393
# L4.BTC_DOWNSIDE_24_std         0.328600         0.035692            9.207           0.000
# L4.RESIDUAL_FINAL            -21.249525        27.887113           -0.762           0.446
# =========================================================================================
#
# Results for equation RESIDUAL_FINAL
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                         -0.000002         0.000031           -0.064           0.949
# L1.BTC_DOWNSIDE_24_std        -0.000148         0.000049           -3.014           0.003
# L1.RESIDUAL_FINAL              0.295378         0.037985            7.776           0.000
# L2.BTC_DOWNSIDE_24_std         0.000114         0.000063            1.817           0.069
# L2.RESIDUAL_FINAL              0.145238         0.039391            3.687           0.000
# L3.BTC_DOWNSIDE_24_std        -0.000022         0.000063           -0.347           0.728
# L3.RESIDUAL_FINAL              0.102733         0.039438            2.605           0.009
# L4.BTC_DOWNSIDE_24_std         0.000003         0.000049            0.057           0.954
# L4.RESIDUAL_FINAL              0.092730         0.038189            2.428           0.015
# =========================================================================================
#
# Correlation matrix of residuals
#                        BTC_DOWNSIDE_24_std  RESIDUAL_FINAL
# BTC_DOWNSIDE_24_std               1.000000       -0.146804
# RESIDUAL_FINAL                   -0.146804        1.000000

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

resid = var_res.resid

print(acorr_ljungbox(resid["RESIDUAL_FINAL"], lags=[4,8,12], return_df=True))
print(acorr_ljungbox(resid["BTC_DOWNSIDE_24_std"], lags=[4,8,12], return_df=True))
# Out:
#      lb_stat  lb_pvalue
# 4   2.292887   0.682064
# 8   6.912745   0.546075
# 12  7.963726   0.787959
#       lb_stat  lb_pvalue
# 4    2.334999   0.674404
# 8   12.521330   0.129415
# 12  20.501943   0.058167

# %% [markdown]
# # IRF

# %%
print("Is stable:", var_res.is_stable(verbose=True))
# Out:
# Eigenvalues of VAR(1) rep
# 0.7472855859224843
# 0.7329062612656712
# 0.7329062612656712
# 0.851898072116908
# 0.7845919876162728
# 0.4650125400346177
# 0.49468320558577444
# 0.49468320558577444
# Is stable: True

# %%
irf = var_res.irf(10)

# %%
irf.plot(orth=False)

# %% [markdown]
# 한국 USDT premium의 residual은
# 시장 공통요인이나 글로벌 depeg로 설명되지 않으며,
# 평균적 스트레스 상태가 아니라
# 하단 tail에서 downside shock에 대해 비대칭적으로 반응하는 구조적 변수이다.
#
# 한국 USDT residual은 downside risk 상황에서 발생하는 달러 접근/헤지 수요를 반영하는 가격 왜곡이다

# %% [markdown]
# downside risk 상황에서
# 한국 USDT 시장에서 가격이 체계적으로 반응하며
# 이는 stablecoin이 hedging 또는 dollar-access 수단으로 활용되는 패턴과 일치한다
#
# “시장 급락 시 stablecoin이 hedging 또는 달러 접근 수단으로 사용되는 것과 일관된 가격 반응이 한국 USDT residual에서 나타난다.”

# %%
# irf.plot(impulse="BTC_DOWNSIDE_24_std", response="RESIDUAL_FINAL", orth=False)

# %% [markdown]
# 보류

# %%
# import matplotlib.pyplot as plt

# plt.plot(res_std_df["q"], res_std_df["beta_downside_std"], marker='o')
# plt.axhline(0, linestyle='--')

# plt.xlabel("Quantile")
# plt.ylabel("Coefficient (standardized downside)")
# plt.title("Quantile Regression (Standardized)")

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.plot(res_std_df["q"], res_std_df["beta_downside_std"], marker='o')
#       4 plt.axhline(0, linestyle='--')
#       6 plt.xlabel("Quantile")
#
# NameError: name 'res_std_df' is not defined

# %%
# from statsmodels.tsa.api import VAR

# var_df = df[["RESIDUAL_OLS", "BTC_DOWNSIDE_24"]].dropna()

# model = VAR(var_df)
# results = model.fit(1)

# print(results.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 24, Mar, 2026
# Time:                     13:11:23
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -34.5550
# Nobs:                     694.000    HQIC:                  -34.5791
# Log likelihood:           10040.7    FPE:                9.46032e-16
# AIC:                     -34.5943    Det(Omega_mle):     9.37906e-16
# --------------------------------------------------------------------
# Results for equation RESIDUAL_OLS
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.000136         0.000040            3.402           0.001
# L1.RESIDUAL_OLS            0.387792         0.035329           10.977           0.000
# L1.BTC_DOWNSIDE_24        -1.166322         0.206920           -5.637           0.000
# =====================================================================================
#
# Results for equation BTC_DOWNSIDE_24
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.000004         0.000002            2.029           0.042
# L1.RESIDUAL_OLS           -0.002070         0.001559           -1.327           0.184
# L1.BTC_DOWNSIDE_24         0.969946         0.009133          106.200           0.000
# =====================================================================================
#
# Correlation matrix of residuals
#                    RESIDUAL_OLS  BTC_DOWNSIDE_24
# RESIDUAL_OLS           1.000000        -0.096963
# BTC_DOWNSIDE_24       -0.096963         1.000000
# c:\Users\김수빈\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# downside stress는 residual에 선행적으로 영향을 주고, residual은 자기지속성이 있으며, 반대로 residual이 downside stress를 유의하게 예측하지는 않는다.
#
# 지금까지 :
#
# - USDT_KP의 대부분은 시장 공통 premium
# - 그래도 남는 RESIDUAL_OLS가 존재
# - 그 residual은 downside stress와 관련
# - 이제 VAR에서 보니 downside stress가 선행적으로 residual을 설명
#
# 즉, static 결과에서 보인 관계가 dynamic에서도 유지
#
# 지금까지 확보한 메시지 :
# - residual은 단순 noise가 아니다
# - residual에는 persistence가 있다
# - downside stress는 residual의 선행 설명변수다
# - 반대로 residual이 downside stress를 유의하게 예측하지는 않는다
#
# “구조적 drivers + 지속성” 에 대한 실증 근거

# %%
# irf = results.irf(10)   # 10시간(또는 10 step) 반응

# irf.plot(orth=False)

# %% [markdown]
# t=0 → 바로 큰 음(-) 충격
#
# t=1~3 → 더 커짐 (peak negative)
#
# t=4 이후 → 천천히 완화
#
# t=10까지도 완전히 0 안 돌아옴
#
# downside shock이 premium residual을 “지속적으로” 깎는다
#
# “BTC downside risk는 김프 residual을 단기적으로 강하게 압축시키고, 그 효과는 수 시간 지속된다"

# %%
# model = VAR(var_df)

# lag_order = model.select_order(maxlags=10)
# print(lag_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -31.44      -31.43   2.212e-14      -31.44
# 1       -34.57     -34.53*   9.699e-16      -34.55
# 2       -34.59      -34.53   9.454e-16     -34.57*
# 3       -34.60      -34.51   9.412e-16      -34.56
# 4      -34.61*      -34.49  9.292e-16*      -34.57
# 5       -34.61      -34.46   9.329e-16      -34.55
# 6       -34.60      -34.43   9.402e-16      -34.53
# 7       -34.59      -34.39   9.487e-16      -34.51
# 8       -34.59      -34.37   9.463e-16      -34.51
# 9       -34.58      -34.33   9.558e-16      -34.49
# 10      -34.58      -34.30   9.613e-16      -34.47
# --------------------------------------------------
# c:\Users\김수빈\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# BIC → 1 lag
#
# HQIC → 2 lag
#
# AIC → 4 lag
#
# FPE → 4 lag
#
#
# BIC는 더 보수적이라 짧은 lag를 고르고, AIC/FPE는 더 유연해서 약간 긴 lag를 고른다.
#
# 연구의 현재 목적은
#
# downside shock이 residual에 선행적으로 영향을 주는지
#
# 그 효과가 몇 시간 지속되는지
#
# 를 보는 거라서, 너무 긴 lag는 오히려 해석을 복잡하게 만들 수 있음
#
# ==
# VAR(1)
#
# 이유:
#
# - BIC가 1을 선택
# - 이미 VAR(1) 결과가 해석 가능하고 깔끔함
# - IRF도 의미 있게 나왔음
# - 연구의 첫 동적 결과를 설명하기에 가장 간결함
#
# 강건성
#
# VAR(2) 또는 VAR(4) 를 robustness로 한 번 더 보는 게 좋다.
#
# 이유:
#
# - HQIC는 2를 고름
# - AIC/FPE는 4를 고름
# - 따라서 “lag choice에 따라 결론이 바뀌지 않는지” 확인할 필요는 있음
#
# Main: VAR(1)
# Robustness: VAR(2), 필요하면 VAR(4)

# %%
# results_var2 = model.fit(2)
# print(results_var2.summary())

# irf2 = results_var2.irf(10)
# irf2.plot(orth=False)
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 24, Mar, 2026
# Time:                     13:11:33
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -34.5519
# Nobs:                     693.000    HQIC:                  -34.5921
# Log likelihood:           10038.3    FPE:                9.24384e-16
# AIC:                     -34.6174    Det(Omega_mle):     9.11188e-16
# --------------------------------------------------------------------
# Results for equation RESIDUAL_OLS
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.000105         0.000040            2.619           0.009
# L1.RESIDUAL_OLS            0.316627         0.037652            8.409           0.000
# L1.BTC_DOWNSIDE_24        -1.824095         0.852629           -2.139           0.032
# L2.RESIDUAL_OLS            0.184054         0.037705            4.881           0.000
# L2.BTC_DOWNSIDE_24         0.917672         0.848733            1.081           0.280
# =====================================================================================
#
# Results for equation BTC_DOWNSIDE_24
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.000004         0.000002            2.268           0.023
# L1.RESIDUAL_OLS           -0.000991         0.001688           -0.587           0.557
# L1.BTC_DOWNSIDE_24         0.982449         0.038226           25.701           0.000
# L2.RESIDUAL_OLS           -0.002788         0.001690           -1.649           0.099
# L2.BTC_DOWNSIDE_24        -0.016483         0.038052           -0.433           0.665
# =====================================================================================
#
# Correlation matrix of residuals
#                    RESIDUAL_OLS  BTC_DOWNSIDE_24
# RESIDUAL_OLS           1.000000        -0.086727
# BTC_DOWNSIDE_24       -0.086727         1.000000

# %% [markdown]
# residual은 persistence를 가진다
#
# downside stress는 residual을 선행적으로 설명한다
#
# 반대 방향은 약하다
#
# lag를 1에서 2로 늘려도 이 결론이 유지된다
#
# 즉, 동적 구조의 핵심 결론이 lag choice에 크게 흔들리지 않는다

# %% [markdown]
# # Lagged quantile dynamics

# %%
df_dyn = df.copy()

df_dyn["RESIDUAL_FINAL_lag1"] = df_dyn["RESIDUAL_FINAL"].shift(1)
df_dyn["BTC_DOWNSIDE_24_std_lag1"] = df_dyn["BTC_DOWNSIDE_24_std"].shift(1)
df_dyn["DXY_ret_lag1"] = df_dyn["DXY_ret"].shift(1)

df_dyn = df_dyn.dropna(subset=[
    "RESIDUAL_FINAL",
    "RESIDUAL_FINAL_lag1",
    "BTC_DOWNSIDE_24_std_lag1",
    "DXY_ret_lag1"
])

print("df_dyn shape:", df_dyn.shape)
print(df_dyn[[
    "RESIDUAL_FINAL",
    "RESIDUAL_FINAL_lag1",
    "BTC_DOWNSIDE_24_std_lag1",
    "DXY_ret_lag1"
]].head())
# Out:
# df_dyn shape: (714, 34)
#                            RESIDUAL_FINAL  RESIDUAL_FINAL_lag1  \
# datetime_utc
# 2025-06-03 10:00:00+00:00        0.000006             0.000057
# 2025-06-03 11:00:00+00:00        0.000411             0.000006
# 2025-06-03 12:00:00+00:00        0.000123             0.000411
# 2025-06-04 09:00:00+00:00        0.001048             0.000123
# 2025-06-04 10:00:00+00:00        0.000992             0.001048
#
#                            BTC_DOWNSIDE_24_std_lag1  DXY_ret_lag1
# datetime_utc
# 2025-06-03 10:00:00+00:00                 -0.424500      0.002777
# 2025-06-03 11:00:00+00:00                 -0.435480      0.000544
# 2025-06-03 12:00:00+00:00                 -0.460536      0.000242
# 2025-06-04 09:00:00+00:00                 -0.460536     -0.000232
# 2025-06-04 10:00:00+00:00                 -0.450348     -0.003382

# %%
import statsmodels.formula.api as smf

mod_q10_dyn = smf.quantreg(
    "RESIDUAL_FINAL ~ RESIDUAL_FINAL_lag1 + BTC_DOWNSIDE_24_std_lag1 + DXY_ret_lag1",
    df_dyn
).fit(q=0.1, max_iter=5000)

mod_q50_dyn = smf.quantreg(
    "RESIDUAL_FINAL ~ RESIDUAL_FINAL_lag1 + BTC_DOWNSIDE_24_std_lag1 + DXY_ret_lag1",
    df_dyn
).fit(q=0.5, max_iter=5000)

mod_q90_dyn = smf.quantreg(
    "RESIDUAL_FINAL ~ RESIDUAL_FINAL_lag1 + BTC_DOWNSIDE_24_std_lag1 + DXY_ret_lag1",
    df_dyn
).fit(q=0.9, max_iter=5000)

print(mod_q10_dyn.summary())
print(mod_q50_dyn.summary())
print(mod_q90_dyn.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   Pseudo R-squared:               0.1595
# Model:                       QuantReg   Bandwidth:                   0.0003792
# Method:                 Least Squares   Sparsity:                     0.005018
# Date:                Thu, 09 Apr 2026   No. Observations:                  714
# Time:                        11:50:11   Df Residuals:                      710
#                                         Df Model:                            3
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0011   5.73e-05    -18.634      0.000      -0.001      -0.001
# RESIDUAL_FINAL_lag1          0.5608      0.080      7.046      0.000       0.405       0.717
# BTC_DOWNSIDE_24_std_lag1    -0.0001   5.44e-05     -1.991      0.047      -0.000   -1.49e-06
# DXY_ret_lag1                 0.0025      0.029      0.087      0.931      -0.054       0.059
# ============================================================================================
#
# The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   Pseudo R-squared:              0.09759
# Model:                       QuantReg   Bandwidth:                   0.0004211
# Method:                 Least Squares   Sparsity:                     0.001932
# Date:                Thu, 09 Apr 2026   No. Observations:                  714
# Time:                        11:50:11   Df Residuals:                      710
#                                         Df Model:                            3
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 2.316e-05   3.62e-05      0.641      0.522   -4.78e-05    9.41e-05
# RESIDUAL_FINAL_lag1          0.4100      0.040     10.227      0.000       0.331       0.489
# BTC_DOWNSIDE_24_std_lag1    -0.0001   3.78e-05     -3.918      0.000      -0.000   -7.39e-05
# DXY_ret_lag1                 0.0021      0.018      0.120      0.905      -0.033       0.037
# ============================================================================================
#
# The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:         RESIDUAL_FINAL   Pseudo R-squared:              0.06965
# Model:                       QuantReg   Bandwidth:                   0.0003655
# Method:                 Least Squares   Sparsity:                     0.003972
# Date:                Thu, 09 Apr 2026   No. Observations:                  714
# Time:                        11:50:11   Df Residuals:                      710
#                                         Df Model:                            3
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0010   4.53e-05     22.293      0.000       0.001       0.001
# RESIDUAL_FINAL_lag1          0.2768      0.052      5.303      0.000       0.174       0.379
# BTC_DOWNSIDE_24_std_lag1 -8.061e-05   5.73e-05     -1.407      0.160      -0.000    3.18e-05
# DXY_ret_lag1                -0.0258      0.019     -1.357      0.175      -0.063       0.012
# ============================================================================================
#
# The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import pandas as pd

horizons = [1, 2, 3, 6, 12]
quantiles = [0.1, 0.5, 0.9]

results_lp = []

for h in horizons:
    temp = df_dyn.copy()
    temp[f"RESIDUAL_lead_{h}"] = temp["RESIDUAL_FINAL"].shift(-h)

    temp = temp.dropna(subset=[f"RESIDUAL_lead_{h}"])

    print(f"h={h}, sample size={len(temp)}")

    for q in quantiles:
        mod = smf.quantreg(
            f"RESIDUAL_lead_{h} ~ RESIDUAL_FINAL + BTC_DOWNSIDE_24_std_lag1 + DXY_ret_lag1",
            temp
        ).fit(q=q, max_iter=5000)

        results_lp.append({
            "h": h,
            "q": q,
            "beta": mod.params["BTC_DOWNSIDE_24_std_lag1"],
            "p_beta": mod.pvalues["BTC_DOWNSIDE_24_std_lag1"],
            "n": len(temp),
        })

lp_df = pd.DataFrame(results_lp)

print(lp_df)
print(lp_df.pivot(index="h", columns="q", values="beta"))
# Out:
# h=1, sample size=713
# h=2, sample size=712
# h=3, sample size=711
# h=6, sample size=708
# h=12, sample size=702
#      h    q      beta        p_beta    n
# 0    1  0.1 -0.000129  2.951014e-03  713
# 1    1  0.5 -0.000099  9.445270e-03  713
# 2    1  0.9 -0.000013  8.210653e-01  713
# 3    2  0.1 -0.000121  2.846145e-02  712
# 4    2  0.5 -0.000016  6.722629e-01  712
# 5    2  0.9 -0.000053  3.801031e-01  712
# 6    3  0.1 -0.000149  1.185853e-02  711
# 7    3  0.5 -0.000023  5.659255e-01  711
# 8    3  0.9 -0.000010  8.665748e-01  711
# 9    6  0.1 -0.000298  3.867939e-10  708
# 10   6  0.5 -0.000058  1.467301e-01  708
# 11   6  0.9  0.000008  9.037306e-01  708
# 12  12  0.1 -0.000594  1.683484e-25  702
# 13  12  0.5 -0.000114  5.402417e-03  702
# 14  12  0.9 -0.000084  2.029414e-01  702
# q        0.1       0.5       0.9
# h
# 1  -0.000129 -0.000099 -0.000013
# 2  -0.000121 -0.000016 -0.000053
# 3  -0.000149 -0.000023 -0.000010
# 6  -0.000298 -0.000058  0.000008
# 12 -0.000594 -0.000114 -0.000084

# %% [markdown]
# [ “downside shock이 이후 h시간 동안 residual에 어떻게 영향을 주는가 (분위수별로) ]
#
# downside shock의 효과는 하단 tail에서만 강하고, 시간이 지날수록 더 커진다
#
# mean이 아니라 tail에서, 그것도 시간이 지나면서 강화되는 downside-driven 구조

# %% [markdown]
# “Downside shocks have a disproportionately larger impact when the premium is already low.”

# %%
# # 1) 결과를 DataFrame으로 정리
# lp_df = pd.DataFrame(results_lp)

# print(lp_df)
# Out:
#      h    q      beta
# 0    1  0.1 -4.362464
# 1    1  0.5 -1.859692
# 2    1  0.9 -0.877438
# 3    2  0.1 -4.357420
# 4    2  0.5 -1.862717
# 5    2  0.9 -0.863451
# 6    3  0.1 -4.389137
# 7    3  0.5 -1.816133
# 8    3  0.9 -0.861774
# 9    6  0.1 -4.361050
# 10   6  0.5 -1.817289
# 11   6  0.9 -0.649533
# 12  12  0.1 -3.751408
# 13  12  0.5 -1.529695
# 14  12  0.9 -0.718866

# %%
# # 2) 분위수별 계수 경로 표
# lp_pivot = lp_df.pivot(index="h", columns="q", values="beta")
# print(lp_pivot)
# Out:
# q        0.1       0.5       0.9
# h
# 1  -4.362464 -1.859692 -0.877438
# 2  -4.357420 -1.862717 -0.863451
# 3  -4.389137 -1.816133 -0.861774
# 6  -4.361050 -1.817289 -0.649533
# 12 -3.751408 -1.529695 -0.718866

# %%
# horizons = [1, 2, 3, 6, 12]
# quantiles = [0.1, 0.5, 0.9]

# results_lp = []
# sample_sizes = []

# for h in horizons:
#     temp = df_dyn.copy()
#     temp[f"RESIDUAL_lead_{h}"] = temp["RESIDUAL_OLS"].shift(-h)

#     temp = temp.dropna(subset=[
#         f"RESIDUAL_lead_{h}",
#         "BTC_DOWNSIDE_24_lag1"
#     ])

#     sample_sizes.append({"h": h, "n": len(temp)})

#     for q in quantiles:
#         mod = smf.quantreg(
#             f"RESIDUAL_lead_{h} ~ BTC_DOWNSIDE_24_lag1",
#             temp
#         ).fit(q=q, max_iter=5000)

#         results_lp.append({
#             "h": h,
#             "q": q,
#             "beta": mod.params["BTC_DOWNSIDE_24_lag1"],
#             "intercept": mod.params["Intercept"],
#             "p_beta": mod.pvalues["BTC_DOWNSIDE_24_lag1"],
#             "n": len(temp),
#         })

# lp_df = pd.DataFrame(results_lp)
# n_df = pd.DataFrame(sample_sizes)

# print("Sample sizes by horizon:")
# print(n_df)

# print("\nLocal projection quantile results:")
# print(lp_df)

# print("\nPivot table of beta:")
# print(lp_df.pivot(index="h", columns="q", values="beta"))
# Out:
# Sample sizes by horizon:
#     h    n
# 0   1  693
# 1   2  692
# 2   3  691
# 3   6  688
# 4  12  682
#
# Local projection quantile results:
#      h    q      beta  intercept        p_beta    n
# 0    1  0.1 -4.362464  -0.000738  1.604459e-26  693
# 1    1  0.5 -1.859692   0.000272  5.367398e-14  693
# 2    1  0.9 -0.877438   0.001196  2.659674e-03  693
# 3    2  0.1 -4.357420  -0.000739  3.626407e-26  692
# 4    2  0.5 -1.862717   0.000275  6.449997e-14  692
# 5    2  0.9 -0.863451   0.001187  3.365130e-03  692
# 6    3  0.1 -4.389137  -0.000727  1.850260e-29  691
# 7    3  0.5 -1.816133   0.000274  3.405396e-13  691
# 8    3  0.9 -0.861774   0.001185  3.875724e-03  691
# 9    6  0.1 -4.361050  -0.000733  8.044715e-30  688
# 10   6  0.5 -1.817289   0.000279  5.767825e-13  688
# 11   6  0.9 -0.649533   0.001177  2.424512e-02  688
# 12  12  0.1 -3.751408  -0.000778  2.144736e-22  682
# 13  12  0.5 -1.529695   0.000261  1.331045e-09  682
# 14  12  0.9 -0.718866   0.001187  9.910668e-03  682
#
# Pivot table of beta:
# q        0.1       0.5       0.9
# h
# 1  -4.362464 -1.859692 -0.877438
# 2  -4.357420 -1.862717 -0.863451
# 3  -4.389137 -1.816133 -0.861774
# 6  -4.361050 -1.817289 -0.649533
# 12 -3.751408 -1.529695 -0.718866

# %%
# import matplotlib.pyplot as plt

# pivot_beta = lp_df.pivot(index="h", columns="q", values="beta")

# for q in pivot_beta.columns:
#     plt.plot(pivot_beta.index, pivot_beta[q], marker="o", label=f"q={q}")

# plt.axhline(0, linestyle="--")
# plt.xlabel("Horizon")
# plt.ylabel("Beta on BTC_DOWNSIDE_24_lag1")
# plt.title("Quantile Local Projection Coefficients")
# plt.legend()
# plt.show()

# %%
# =========================================
# Timeline figure: event windows + residual jumps
# Assumption: df already exists in memory
# Required columns:
#   - RESIDUAL_FINAL
# Optional column:
#   - BTC_DOWNSIDE_24_std  (if exists, second panel plots it)
# Index:
#   - datetime_utc (UTC) or convertible datetime index
# =========================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# 0) Basic prep
# -----------------------------
plot_df = df.copy()

# Ensure datetime index
if not isinstance(plot_df.index, pd.DatetimeIndex):
    if "datetime_utc" in plot_df.columns:
        plot_df["datetime_utc"] = pd.to_datetime(plot_df["datetime_utc"], utc=True)
        plot_df = plot_df.set_index("datetime_utc")
    else:
        raise ValueError("DatetimeIndex가 없고 'datetime_utc' 컬럼도 없습니다.")

# Ensure UTC
if plot_df.index.tz is None:
    plot_df.index = plot_df.index.tz_localize("UTC")
else:
    plot_df.index = plot_df.index.tz_convert("UTC")

# Keep needed columns only
needed_cols = ["RESIDUAL_FINAL"]
optional_cols = [c for c in ["BTC_DOWNSIDE_24_std"] if c in plot_df.columns]
plot_df = plot_df[needed_cols + optional_cols].sort_index().dropna(subset=["RESIDUAL_FINAL"]).copy()

print("plot_df shape:", plot_df.shape)
print("sample start:", plot_df.index.min())
print("sample end  :", plot_df.index.max())

# -----------------------------
# 1) Define event windows
# -----------------------------
event_windows = {
    "2025-10-10/11 crypto crash": (
        pd.Timestamp("2025-10-10 00:00:00", tz="UTC"),
        pd.Timestamp("2025-10-11 23:59:59", tz="UTC")
    ),
    "2026-01-31~2026-02-05 crypto slump/liquidation": (
        pd.Timestamp("2026-01-31 00:00:00", tz="UTC"),
        pd.Timestamp("2026-02-05 23:59:59", tz="UTC")
    ),
}

# -----------------------------
# 2) Detect residual jump points
#    Rule: top 1% absolute hourly changes
# -----------------------------
plot_df["RESIDUAL_DIFF"] = plot_df["RESIDUAL_FINAL"].diff()
plot_df["ABS_RESIDUAL_DIFF"] = plot_df["RESIDUAL_DIFF"].abs()

jump_threshold = plot_df["ABS_RESIDUAL_DIFF"].quantile(0.99)
jump_df = plot_df.loc[plot_df["ABS_RESIDUAL_DIFF"] >= jump_threshold, ["RESIDUAL_FINAL", "RESIDUAL_DIFF", "ABS_RESIDUAL_DIFF"]].copy()

print("\nJump threshold (top 1% abs change):", jump_threshold)
print("\nResidual jump points:")
print(jump_df.sort_values("ABS_RESIDUAL_DIFF", ascending=False).head(20))

# For labeling on the figure: use top 8 largest jumps
top_jumps = jump_df.sort_values("ABS_RESIDUAL_DIFF", ascending=False).head(8).copy()

# -----------------------------
# 3) Make figure
# -----------------------------
use_two_panels = "BTC_DOWNSIDE_24_std" in plot_df.columns

if use_two_panels:
    fig, axes = plt.subplots(
        2, 1, figsize=(16, 9), sharex=True,
        gridspec_kw={"height_ratios": [2.0, 1.0]}
    )
    ax1, ax2 = axes
else:
    fig, ax1 = plt.subplots(figsize=(16, 7))
    ax2 = None

# ---- Top panel: residual
ax1.plot(plot_df.index, plot_df["RESIDUAL_FINAL"], linewidth=1.2, label="RESIDUAL_FINAL")
ax1.scatter(top_jumps.index, top_jumps["RESIDUAL_FINAL"], s=35, zorder=5, label="Top residual jumps")

# Shade event windows
for label, (start, end) in event_windows.items():
    ax1.axvspan(start, end, alpha=0.18)
    # place label near the top of current y-range
    y_top = ax1.get_ylim()[1]
    ax1.text(start, y_top, label, fontsize=9, va="top", ha="left", rotation=90)

# Annotate jump timestamps
for ts, row in top_jumps.iterrows():
    ax1.annotate(
        ts.strftime("%Y-%m-%d %H:%M"),
        xy=(ts, row["RESIDUAL_FINAL"]),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=8
    )

ax1.set_title("Sample Timeline: Korean USDT Residual, Event Windows, and Residual Jump Points")
ax1.set_ylabel("RESIDUAL_FINAL")
ax1.legend(loc="upper left")
ax1.grid(alpha=0.3)

# ---- Bottom panel: downside proxy if available
if use_two_panels:
    ax2.plot(plot_df.index, plot_df["BTC_DOWNSIDE_24_std"], linewidth=1.1, label="BTC_DOWNSIDE_24_std")
    for label, (start, end) in event_windows.items():
        ax2.axvspan(start, end, alpha=0.18)
    ax2.set_ylabel("BTC downside (std)")
    ax2.set_xlabel("UTC time")
    ax2.legend(loc="upper left")
    ax2.grid(alpha=0.3)
else:
    ax1.set_xlabel("UTC time")

plt.tight_layout()
plt.show()

# -----------------------------
# 4) Event-window summary table
# -----------------------------
summary_rows = []
for label, (start, end) in event_windows.items():
    sub = plot_df.loc[(plot_df.index >= start) & (plot_df.index <= end)].copy()
    if len(sub) == 0:
        summary_rows.append({
            "event": label,
            "n_obs": 0,
            "residual_mean": np.nan,
            "residual_min": np.nan,
            "residual_max": np.nan,
            "abs_diff_max": np.nan,
        })
    else:
        summary_rows.append({
            "event": label,
            "n_obs": len(sub),
            "residual_mean": sub["RESIDUAL_FINAL"].mean(),
            "residual_min": sub["RESIDUAL_FINAL"].min(),
            "residual_max": sub["RESIDUAL_FINAL"].max(),
            "abs_diff_max": sub["ABS_RESIDUAL_DIFF"].max(),
        })

event_summary = pd.DataFrame(summary_rows)
print("\nEvent-window summary:")
print(event_summary)

# -----------------------------
# 5) Which jump points fall inside event windows?
# -----------------------------
def which_event(ts):
    hits = []
    for label, (start, end) in event_windows.items():
        if start <= ts <= end:
            hits.append(label)
    return ", ".join(hits) if hits else "Outside event windows"

jump_event_map = top_jumps.copy()
jump_event_map["event_window"] = [which_event(ts) for ts in jump_event_map.index]

print("\nTop jump points mapped to event windows:")
print(jump_event_map[["RESIDUAL_FINAL", "RESIDUAL_DIFF", "ABS_RESIDUAL_DIFF", "event_window"]])
# Out:
# plot_df shape: (715, 2)
# sample start: 2025-06-03 09:00:00+00:00
# sample end  : 2026-03-19 12:00:00+00:00
#
# Jump threshold (top 1% abs change): 0.00256999757968208
#
# Residual jump points:
#                            RESIDUAL_FINAL  RESIDUAL_DIFF  ABS_RESIDUAL_DIFF
# datetime_utc
# 2025-12-03 09:00:00+00:00        0.000554       0.004210           0.004210
# 2025-11-28 11:00:00+00:00       -0.005410      -0.003676           0.003676
# 2026-03-19 09:00:00+00:00       -0.001508      -0.003364           0.003364
# 2026-02-23 11:00:00+00:00        0.002089       0.003224           0.003224
# 2026-01-15 09:00:00+00:00       -0.001909      -0.003121           0.003121
# 2026-01-13 09:00:00+00:00        0.000704       0.003069           0.003069
# 2026-02-12 09:00:00+00:00        0.000510       0.002983           0.002983
# 2026-03-18 09:00:00+00:00        0.000625       0.002574           0.002574
# Event-window summary:
#                                             event  n_obs  residual_mean  \
# 0                      2025-10-10/11 crypto crash      4       0.000359
# 1  2026-01-31~2026-02-05 crypto slump/liquidation     12      -0.000514
#
#    residual_min  residual_max  abs_diff_max
# 0      0.000013      0.000953      0.000940
# 1     -0.002147      0.001244      0.002215
#
# Top jump points mapped to event windows:
#                            RESIDUAL_FINAL  RESIDUAL_DIFF  ABS_RESIDUAL_DIFF  \
# datetime_utc
# 2025-12-03 09:00:00+00:00        0.000554       0.004210           0.004210
# 2025-11-28 11:00:00+00:00       -0.005410      -0.003676           0.003676
# 2026-03-19 09:00:00+00:00       -0.001508      -0.003364           0.003364
# 2026-02-23 11:00:00+00:00        0.002089       0.003224           0.003224
# 2026-01-15 09:00:00+00:00       -0.001909      -0.003121           0.003121
# 2026-01-13 09:00:00+00:00        0.000704       0.003069           0.003069
# 2026-02-12 09:00:00+00:00        0.000510       0.002983           0.002983
# 2026-03-18 09:00:00+00:00        0.000625       0.002574           0.002574
#
#                                     event_window
# datetime_utc
# 2025-12-03 09:00:00+00:00  Outside event windows
# 2025-11-28 11:00:00+00:00  Outside event windows
# 2026-03-19 09:00:00+00:00  Outside event windows
# 2026-02-23 11:00:00+00:00  Outside event windows
# 2026-01-15 09:00:00+00:00  Outside event windows
# 2026-01-13 09:00:00+00:00  Outside event windows
# 2026-02-12 09:00:00+00:00  Outside event windows
# 2026-03-18 09:00:00+00:00  Outside event windows

# %%
# -----------------------------
# 1) Downside regime 정의
# -----------------------------
df_reg = df.copy()

# datetime index 정리 (혹시 필요하면)
if not isinstance(df_reg.index, pd.DatetimeIndex):
    df_reg["datetime_utc"] = pd.to_datetime(df_reg["datetime_utc"], utc=True)
    df_reg = df_reg.set_index("datetime_utc")

# downside threshold (상위 10%)
threshold = df_reg["BTC_DOWNSIDE_24_std"].quantile(0.9)

# regime dummy
df_reg["DOWNSIDE"] = (df_reg["BTC_DOWNSIDE_24_std"] >= threshold).astype(int)

print("Downside threshold:", threshold)
print(df_reg["DOWNSIDE"].value_counts())
# Out:
# Downside threshold: 0.8103860496081203
# DOWNSIDE
# 0    643
# 1     72
# Name: count, dtype: int64

# %%
# -----------------------------
# 2) Residual 통계 비교
# -----------------------------
summary = df_reg.groupby("DOWNSIDE")["RESIDUAL_FINAL"].agg(
    count="count",
    mean="mean",
    std="std",
    min="min",
    max="max",
    skew="skew"
)

print("\nDownside vs Normal summary:")
print(summary)
# Out:
# Downside vs Normal summary:
#           count      mean       std      min       max      skew
# DOWNSIDE
# 0           643  0.000058  0.000906 -0.00541  0.002273 -0.758222
# 1            72 -0.000515  0.001104 -0.00427  0.002089 -1.078057

# %%
# -----------------------------
# 3) Quantile 비교 (tail)
# -----------------------------
quantiles = df_reg.groupby("DOWNSIDE")["RESIDUAL_FINAL"].quantile([0.01, 0.05, 0.1, 0.5, 0.9]).unstack()

print("\nQuantile comparison:")
print(quantiles)
# Out:
# Quantile comparison:
#               0.01      0.05      0.10      0.50      0.90
# DOWNSIDE
# 0        -0.002277 -0.001485 -0.001126  0.000128  0.001139
# 1        -0.004020 -0.002321 -0.001581 -0.000410  0.000736

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.boxplot(x="DOWNSIDE", y="RESIDUAL_FINAL", data=df_reg)
plt.title("Residual Distribution: Downside vs Normal")
plt.xlabel("Downside (1 = stress)")
plt.ylabel("RESIDUAL_FINAL")
plt.grid(alpha=0.3)
plt.show()

# %%
from scipy.stats import ttest_ind

res_down = df_reg[df_reg["DOWNSIDE"] == 1]["RESIDUAL_FINAL"]
res_norm = df_reg[df_reg["DOWNSIDE"] == 0]["RESIDUAL_FINAL"]

t_stat, p_val = ttest_ind(res_down, res_norm, equal_var=False)

print("\nT-test:")
print("t-stat:", t_stat)
print("p-value:", p_val)
# Out:
# T-test:
# t-stat: -4.242959050239954
# p-value: 5.762673439231241e-05

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# =========================================================
# 0) 기본 준비
# =========================================================
df_plot = df.copy()

if not isinstance(df_plot.index, pd.DatetimeIndex):
    if "datetime_utc" in df_plot.columns:
        df_plot["datetime_utc"] = pd.to_datetime(df_plot["datetime_utc"], utc=True)
        df_plot = df_plot.set_index("datetime_utc")
    else:
        raise ValueError("DatetimeIndex가 없고 datetime_utc 컬럼도 없습니다.")

if df_plot.index.tz is None:
    df_plot.index = df_plot.index.tz_localize("UTC")
else:
    df_plot.index = df_plot.index.tz_convert("UTC")

needed = ["RESIDUAL_FINAL", "BTC_DOWNSIDE_24_std"]
missing = [c for c in needed if c not in df_plot.columns]
if missing:
    raise ValueError(f"필요 컬럼 누락: {missing}")

df_plot = df_plot[needed].dropna().sort_index().copy()

# =========================================================
# 1) downside regime 정의
#    상위 10%를 downside stress로 정의
# =========================================================
threshold = df_plot["BTC_DOWNSIDE_24_std"].quantile(0.90)
df_plot["DOWNSIDE"] = (df_plot["BTC_DOWNSIDE_24_std"] >= threshold).astype(int)

print("Downside threshold:", threshold)
print(df_plot["DOWNSIDE"].value_counts())

# =========================================================
# 2) Figure 1: downside indicator 시계열
#    - threshold 선
#    - downside 구간 shading
# =========================================================
fig, ax = plt.subplots(figsize=(14, 5))

ax.plot(df_plot.index, df_plot["BTC_DOWNSIDE_24_std"], linewidth=1.2, label="BTC_DOWNSIDE_24_std")
ax.axhline(threshold, linestyle="--", linewidth=1.2, label=f"90th percentile threshold = {threshold:.3f}")

# downside 구간 shading
down_mask = df_plot["DOWNSIDE"] == 1
start = None
for i, is_down in enumerate(down_mask):
    if is_down and start is None:
        start = df_plot.index[i]
    elif (not is_down) and start is not None:
        end = df_plot.index[i-1]
        ax.axvspan(start, end, alpha=0.18)
        start = None
if start is not None:
    ax.axvspan(start, df_plot.index[-1], alpha=0.18)

ax.set_title("Figure 1. Downside Stress Indicator over the Sample")
ax.set_ylabel("BTC_DOWNSIDE_24_std")
ax.set_xlabel("UTC time")
ax.legend(loc="upper left")
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# =========================================================
# 3) Table 1: downside vs normal 통계 비교
# =========================================================
summary = df_plot.groupby("DOWNSIDE")["RESIDUAL_FINAL"].agg(
    count="count",
    mean="mean",
    std="std",
    min="min",
    q01=lambda x: x.quantile(0.01),
    q05=lambda x: x.quantile(0.05),
    q10=lambda x: x.quantile(0.10),
    median="median",
    q90=lambda x: x.quantile(0.90),
    max="max",
    skew="skew"
)

summary.index = ["Normal", "Downside"]
print("\nTable 1. Residual distribution: Downside vs Normal")
print(summary.round(6))

# =========================================================
# 4) t-test
# =========================================================
res_norm = df_plot.loc[df_plot["DOWNSIDE"] == 0, "RESIDUAL_FINAL"]
res_down = df_plot.loc[df_plot["DOWNSIDE"] == 1, "RESIDUAL_FINAL"]

t_stat, p_val = ttest_ind(res_down, res_norm, equal_var=False)

print("\nT-test (Downside vs Normal)")
print("t-stat :", round(t_stat, 6))
print("p-value:", p_val)

# =========================================================
# 5) Figure 2: boxplot
# =========================================================
fig, ax = plt.subplots(figsize=(8, 5))

data_to_plot = [
    df_plot.loc[df_plot["DOWNSIDE"] == 0, "RESIDUAL_FINAL"],
    df_plot.loc[df_plot["DOWNSIDE"] == 1, "RESIDUAL_FINAL"]
]

ax.boxplot(data_to_plot, labels=["Normal", "Downside"])
ax.set_title("Figure 2. Residual Distribution: Downside vs Normal")
ax.set_ylabel("RESIDUAL_FINAL")
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Downside threshold: 0.8103860496081203
# DOWNSIDE
# 0    643
# 1     72
# Name: count, dtype: int64
# Table 1. Residual distribution: Downside vs Normal
#           count      mean       std      min       q01       q05       q10  \
# Normal      643  0.000058  0.000906 -0.00541 -0.002277 -0.001485 -0.001126
# Downside     72 -0.000515  0.001104 -0.00427 -0.004020 -0.002321 -0.001581
#
#             median       q90       max      skew
# Normal    0.000128  0.001139  0.002273 -0.758222
# Downside -0.000410  0.000736  0.002089 -1.078057
#
# T-test (Downside vs Normal)
# t-stat : -4.242959
# p-value: 5.762673439231241e-05

# %% [markdown]
# Stree regime 만들기

# %%
print(df.columns.tolist())
# Out:
# ['RESIDUAL_RAW', 'USDT_KP', 'MKT_KP_EQ', 'VIX_ret', 'SPY_ret', 'DXY_ret', 'XAUUSD_ret', 'BTC_RET', 'BTC_VOL_24', 'BTC_RET_POS', 'BTC_RET_NEG', 'BTC_RET_ABS', 'BTC_DOWNSIDE_24', 'BTC_BIG_UP', 'BTC_BIG_DOWN', 'BTC_VOL_RATIO_LOG', 'ETH_VOL_RATIO_LOG', 'XRP_VOL_RATIO_LOG', 'SOL_VOL_RATIO_LOG', 'DOGE_VOL_RATIO_LOG', 'RESIDUAL_OLS', 'BTC_DOWNSIDE_24_std']

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# regime 분석용 master panel
df_regime = pd.read_csv(
    "baseline_dataset_with_micro.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)

df_regime.index = pd.to_datetime(df_regime.index, utc=True)

print(df_regime.shape)
print(df_regime.columns.tolist())
# Out:
# (719, 55)
# ['BTC_BINANCE_CLOSE', 'ETH_BINANCE_CLOSE', 'XRP_BINANCE_CLOSE', 'SOL_BINANCE_CLOSE', 'DOGE_BINANCE_CLOSE', 'USDT_BINANCE_CLOSE', 'BTC_UPBIT_CLOSE', 'ETH_UPBIT_CLOSE', 'XRP_UPBIT_CLOSE', 'SOL_UPBIT_CLOSE', 'DOGE_UPBIT_CLOSE', 'USDT_UPBIT_CLOSE', 'USDKRW', 'BTC_KP', 'ETH_KP', 'XRP_KP', 'SOL_KP', 'DOGE_KP', 'USDT_KP', 'MKT_KP_EQ', 'RESIDUAL_RAW', 'BTC_KP_pct', 'ETH_KP_pct', 'XRP_KP_pct', 'SOL_KP_pct', 'DOGE_KP_pct', 'USDT_KP_pct', 'MKT_KP_EQ_pct', 'RESIDUAL_RAW_pct', 'VIX', 'SPY', 'DXY', 'XAUUSD', 'VIX_ret', 'SPY_ret', 'DXY_ret', 'XAUUSD_ret', 'BTC_RET', 'BTC_VOL_24', 'BTC_RET_POS', 'BTC_RET_NEG', 'BTC_RET_ABS', 'BTC_DOWNSIDE_24', 'BTC_BIG_UP', 'BTC_BIG_DOWN', 'BTC_VOL_RATIO', 'BTC_VOL_RATIO_LOG', 'ETH_VOL_RATIO', 'ETH_VOL_RATIO_LOG', 'XRP_VOL_RATIO', 'XRP_VOL_RATIO_LOG', 'SOL_VOL_RATIO', 'SOL_VOL_RATIO_LOG', 'DOGE_VOL_RATIO', 'DOGE_VOL_RATIO_LOG']

# %%
import statsmodels.api as sm

# Step 1에서 했던 residual 생성 다시
X = sm.add_constant(df_regime["MKT_KP_EQ"])
y = df_regime["USDT_KP"]

model_resid = sm.OLS(y, X, missing="drop").fit()

# index 맞춰서 저장
df_regime["RESIDUAL_OLS"] = np.nan
df_regime.loc[model_resid.resid.index, "RESIDUAL_OLS"] = model_resid.resid

# %%
# stress regime: VIX upper 20%
vix_thr = df_regime["VIX"].quantile(0.8)

df_regime["HIGH_STRESS"] = (df_regime["VIX"] >= vix_thr).astype(int)
df_regime["LOW_STRESS"] = (df_regime["VIX"] < vix_thr).astype(int)

print("VIX threshold:", vix_thr)
print(df_regime["HIGH_STRESS"].value_counts(dropna=False))
# Out:
# VIX threshold: 19.518
# HIGH_STRESS
# 0    575
# 1    144
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# =========================
# 1) master panel load
# =========================
df_regime = pd.read_csv(
    "baseline_dataset_with_micro.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)
df_regime.index = pd.to_datetime(df_regime.index, utc=True)

# =========================
# 2) RESIDUAL_OLS 생성 (없으면)
# =========================
if "RESIDUAL_OLS" not in df_regime.columns:
    X = sm.add_constant(df_regime["MKT_KP_EQ"])
    y = df_regime["USDT_KP"]

    model_resid = sm.OLS(y, X, missing="drop").fit()

    df_regime["RESIDUAL_OLS"] = np.nan
    df_regime.loc[model_resid.resid.index, "RESIDUAL_OLS"] = model_resid.resid

# =========================
# 3) HIGH_STRESS 생성
# =========================
vix_thr = df_regime["VIX"].quantile(0.8)
df_regime["HIGH_STRESS"] = (df_regime["VIX"] >= vix_thr).astype(int)

# =========================
# 4) lag 변수 생성
# =========================
df_dyn = df_regime.copy()

df_dyn["RESIDUAL_OLS_lag1"] = df_dyn["RESIDUAL_OLS"].shift(1)
df_dyn["BTC_DOWNSIDE_24_lag1"] = df_dyn["BTC_DOWNSIDE_24"].shift(1)
df_dyn["DXY_ret_lag1"] = df_dyn["DXY_ret"].shift(1)
df_dyn["HIGH_STRESS_lag1"] = df_dyn["HIGH_STRESS"].shift(1)

df_dyn = df_dyn.dropna(subset=[
    "RESIDUAL_OLS",
    "RESIDUAL_OLS_lag1",
    "BTC_DOWNSIDE_24_lag1",
    "DXY_ret_lag1",
    "HIGH_STRESS_lag1"
])

print("df_dyn shape:", df_dyn.shape)

# =========================
# 5) regime interaction local projection (corrected)
# =========================
horizons = [1, 2, 3, 6, 12]
results_regime = []

for h in horizons:
    temp = df_dyn.copy()
    temp[f"RESIDUAL_lead_{h}"] = temp["RESIDUAL_OLS"].shift(-h)

    temp = temp.dropna(subset=[
        f"RESIDUAL_lead_{h}",
        "RESIDUAL_OLS_lag1",
        "BTC_DOWNSIDE_24_lag1",
        "DXY_ret_lag1",
        "HIGH_STRESS_lag1"
    ])

    for q in [0.1, 0.5, 0.9]:
        mod = smf.quantreg(
            f"""
            RESIDUAL_lead_{h} ~ 
            RESIDUAL_OLS_lag1
            + DXY_ret_lag1
            + HIGH_STRESS_lag1
            + BTC_DOWNSIDE_24_lag1
            + BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1
            """,
            temp
        ).fit(q=q, max_iter=5000)

        beta_normal = mod.params["BTC_DOWNSIDE_24_lag1"]
        interaction_name = "BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1"
        beta_interaction = mod.params[interaction_name]
        p_interaction = mod.pvalues[interaction_name]

        results_regime.append({
            "h": h,
            "q": q,
            "n": len(temp),
            "beta_normal": beta_normal,
            "beta_stress": beta_normal + beta_interaction,
            "interaction": beta_interaction,
            "p_interaction": p_interaction,
            "beta_regime_main": mod.params["HIGH_STRESS_lag1"],
            "p_regime_main": mod.pvalues["HIGH_STRESS_lag1"],
            "beta_resid_lag1": mod.params["RESIDUAL_OLS_lag1"],
            "p_resid_lag1": mod.pvalues["RESIDUAL_OLS_lag1"],
        })

df_regime_lp = pd.DataFrame(results_regime)

print("\nRegime LP results:")
print(df_regime_lp)

print("\nPivot: beta_normal")
print(df_regime_lp.pivot(index="h", columns="q", values="beta_normal"))

print("\nPivot: beta_stress")
print(df_regime_lp.pivot(index="h", columns="q", values="beta_stress"))

print("\nPivot: interaction")
print(df_regime_lp.pivot(index="h", columns="q", values="interaction"))

print("\nPivot: p_interaction")
print(df_regime_lp.pivot(index="h", columns="q", values="p_interaction"))
# Out:
# df_dyn shape: (694, 61)
#
# Regime LP results:
#      h    q    n  beta_normal  beta_stress  interaction  p_interaction  \
# 0    1  0.1  693    -3.100940    -1.236212     1.864729   4.600395e-02
# 1    1  0.5  693    -1.444611    -0.989016     0.455594   3.782822e-01
# 2    1  0.9  693    -0.320287    -1.347844    -1.027556   2.155699e-01
# 3    2  0.1  692    -2.938321    -1.577981     1.360341   8.143233e-02
# 4    2  0.5  692    -0.868434    -1.590127    -0.721694   1.864675e-01
# 5    2  0.9  692    -0.240861    -0.925898    -0.685037   4.240615e-01
# 6    3  0.1  691    -3.825392    -1.111804     2.713588   1.243051e-03
# 7    3  0.5  691    -0.881144    -1.876990    -0.995846   5.798036e-02
# 8    3  0.9  691    -0.428654    -0.990766    -0.562112   5.048107e-01
# 9    6  0.1  688    -3.785303    -1.729028     2.056275   4.559553e-03
# 10   6  0.5  688    -0.864013    -1.455816    -0.591803   2.971063e-01
# 11   6  0.9  688    -0.307067    -1.717475    -1.410408   5.818103e-02
# 12  12  0.1  682    -1.340666    -3.280727    -1.940060   1.923700e-01
# 13  12  0.5  682    -0.639539    -3.485457    -2.845918   8.850549e-07
# 14  12  0.9  682     0.227910    -1.754218    -1.982128   1.202611e-03
#
#     beta_regime_main  p_regime_main  beta_resid_lag1  p_resid_lag1
# 0          -0.000471       0.025406         0.376973  5.511920e-08
# 1           0.000018       0.883028         0.312329  1.501676e-13
# 2           0.000422       0.020818         0.145792  5.940152e-03
# 3          -0.000515       0.008429         0.331071  3.763714e-06
# 4           0.000020       0.877125         0.247526  2.163415e-08
# 5           0.000164       0.367917         0.123183  1.949631e-02
# 6          -0.000524       0.006135         0.310784  3.459353e-06
# 7           0.000158       0.213678         0.249977  4.285904e-09
# 8           0.000116       0.525208         0.075604  2.250895e-01
# 9          -0.000300       0.091166         0.300731  2.476305e-07
# 10          0.000068       0.623959         0.191279  2.814786e-05
# 11          0.000307       0.077034         0.069416  2.313110e-01
# 12         -0.000105       0.751479         0.357580  1.657042e-04
# 13          0.000376       0.008900         0.274230  3.582464e-09
# 14          0.000455       0.003473         0.111868  2.781314e-02
#
# Pivot: beta_normal
# q        0.1       0.5       0.9
# h
# 1  -3.100940 -1.444611 -0.320287
# 2  -2.938321 -0.868434 -0.240861
# 3  -3.825392 -0.881144 -0.428654
# 6  -3.785303 -0.864013 -0.307067
# 12 -1.340666 -0.639539  0.227910
#
# Pivot: beta_stress
# q        0.1       0.5       0.9
# h
# 1  -1.236212 -0.989016 -1.347844
# 2  -1.577981 -1.590127 -0.925898
# 3  -1.111804 -1.876990 -0.990766
# 6  -1.729028 -1.455816 -1.717475
# 12 -3.280727 -3.485457 -1.754218
#
# Pivot: interaction
# q        0.1       0.5       0.9
# h
# 1   1.864729  0.455594 -1.027556
# 2   1.360341 -0.721694 -0.685037
# 3   2.713588 -0.995846 -0.562112
# 6   2.056275 -0.591803 -1.410408
# 12 -1.940060 -2.845918 -1.982128
#
# Pivot: p_interaction
# q        0.1           0.5       0.9
# h
# 1   0.046004  3.782822e-01  0.215570
# 2   0.081432  1.864675e-01  0.424061
# 3   0.001243  5.798036e-02  0.504811
# 6   0.004560  2.971063e-01  0.058181
# 12  0.192370  8.850549e-07  0.001203

# %%
import matplotlib.pyplot as plt

for q in [0.1, 0.5, 0.9]:
    subset = df_regime_lp[df_regime_lp["q"] == q]

    plt.plot(subset["h"], subset["beta_normal"], label="Normal")
    plt.plot(subset["h"], subset["beta_stress"], label="Stress")

    plt.title(f"IRF (q={q})")
    plt.legend()
    plt.show()

# %%
horizons = [1, 2, 3, 6, 12]
results_dollar = []

for h in horizons:
    temp = df_dyn.copy()
    temp[f"RESIDUAL_lead_{h}"] = temp["RESIDUAL_OLS"].shift(-h)

    temp = temp.dropna(subset=[
        f"RESIDUAL_lead_{h}",
        "RESIDUAL_OLS_lag1",
        "BTC_DOWNSIDE_24_lag1",
        "DXY_ret_lag1",
        "HIGH_STRESS_lag1"
    ])

    for q in [0.1, 0.5, 0.9]:
        mod = smf.quantreg(
            f"""
            RESIDUAL_lead_{h} ~ 
            RESIDUAL_OLS_lag1
            + HIGH_STRESS_lag1
            + BTC_DOWNSIDE_24_lag1
            + BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1
            + DXY_ret_lag1
            + DXY_ret_lag1:HIGH_STRESS_lag1
            """,
            temp
        ).fit(q=q, max_iter=5000)

        results_dollar.append({
            "h": h,
            "q": q,
            "beta_dxy": mod.params["DXY_ret_lag1"],
            "beta_dxy_stress": mod.params["DXY_ret_lag1"] 
                               + mod.params["DXY_ret_lag1:HIGH_STRESS_lag1"],
            "p_dxy_interaction": mod.pvalues["DXY_ret_lag1:HIGH_STRESS_lag1"]
        })

df_dollar = pd.DataFrame(results_dollar)

print(df_dollar)
print(df_dollar.pivot(index="h", columns="q", values="beta_dxy_stress"))
# Out:
#      h    q  beta_dxy  beta_dxy_stress  p_dxy_interaction
# 0    1  0.1  0.006334         0.060221           0.370699
# 1    1  0.5 -0.012430        -0.017127           0.906590
# 2    1  0.9 -0.019518        -0.028386           0.915102
# 3    2  0.1  0.081384        -0.022145           0.117063
# 4    2  0.5 -0.008104        -0.030779           0.590025
# 5    2  0.9 -0.015046        -0.036410           0.661411
# 6    3  0.1 -0.004495        -0.087812           0.020348
# 7    3  0.5  0.034936        -0.042916           0.050194
# 8    3  0.9  0.032381         0.017425           0.729287
# 9    6  0.1  0.063727         0.088981           0.625833
# 10   6  0.5  0.014218         0.046338           0.461647
# 11   6  0.9 -0.003443        -0.019500           0.705937
# 12  12  0.1  0.029413         0.009596           0.822183
# 13  12  0.5  0.017783        -0.001706           0.655680
# 14  12  0.9  0.004232         0.005357           0.986571
# q        0.1       0.5       0.9
# h
# 1   0.060221 -0.017127 -0.028386
# 2  -0.022145 -0.030779 -0.036410
# 3  -0.087812 -0.042916  0.017425
# 6   0.088981  0.046338 -0.019500
# 12  0.009596 -0.001706  0.005357

# %% [markdown]
# 스테이블코인은 달러 대체 수단이라기보다, crypto-native liquidity / funding constraint의 반영 변수다

# %% [markdown]
# H1: USDT residual은 달러 거시변수보다 crypto-native liquidity / funding constraint를 더 강하게 반영한다.

# %%
core_cols = [
    "RESIDUAL_OLS",
    "RESIDUAL_OLS_lag1",
    "HIGH_STRESS_lag1",
    "BTC_DOWNSIDE_24_lag1",
    "DXY_ret_lag1",
    "FUNDING_lag1",
    "OI_lag1",
    "LIQUIDATION_lag1"
]

existing_cols = [c for c in core_cols if c in df_dyn.columns]
missing_cols = [c for c in core_cols if c not in df_dyn.columns]

print("=== Existing columns ===")
print(existing_cols)

print("\n=== Missing columns ===")
print(missing_cols)

print("\n=== Missing ratio ===")
print(df_dyn[existing_cols].isna().mean().sort_values())

print("\n=== Summary stats ===")
print(df_dyn[existing_cols].describe().T)
# Out:
# === Existing columns ===
# ['RESIDUAL_OLS', 'RESIDUAL_OLS_lag1', 'HIGH_STRESS_lag1', 'BTC_DOWNSIDE_24_lag1', 'DXY_ret_lag1']
#
# === Missing columns ===
# ['FUNDING_lag1', 'OI_lag1', 'LIQUIDATION_lag1']
#
# === Missing ratio ===
# RESIDUAL_OLS            0.0
# RESIDUAL_OLS_lag1       0.0
# HIGH_STRESS_lag1        0.0
# BTC_DOWNSIDE_24_lag1    0.0
# DXY_ret_lag1            0.0
# dtype: float64
#
# === Summary stats ===
#                       count      mean       std           min       25%  \
# RESIDUAL_OLS          694.0 -0.000017  0.000959 -5.272469e-03 -0.000543
# RESIDUAL_OLS_lag1     694.0 -0.000015  0.000959 -5.272469e-03 -0.000536
# HIGH_STRESS_lag1      694.0  0.206052  0.404760  0.000000e+00  0.000000
# BTC_DOWNSIDE_24_lag1  694.0  0.000118  0.000164  7.229045e-07  0.000025
# DXY_ret_lag1          694.0  0.000009  0.002043 -1.148698e-02 -0.000661
#
#                            50%       75%       max
# RESIDUAL_OLS          0.000092  0.000596  0.002226
# RESIDUAL_OLS_lag1     0.000097  0.000596  0.002226
# HIGH_STRESS_lag1      0.000000  0.000000  1.000000
# BTC_DOWNSIDE_24_lag1  0.000056  0.000132  0.000784
# DXY_ret_lag1         -0.000020  0.000792  0.010351

# %%
check_cols = [
    "RESIDUAL_OLS",
    "RESIDUAL_OLS_lag1",
    "HIGH_STRESS_lag1",
    "BTC_DOWNSIDE_24_lag1",
    "DXY_ret_lag1"
]

print(df_dyn[check_cols].isna().mean().sort_values())
print(df_dyn[check_cols].describe().T)
# Out:
# RESIDUAL_OLS            0.0
# RESIDUAL_OLS_lag1       0.0
# HIGH_STRESS_lag1        0.0
# BTC_DOWNSIDE_24_lag1    0.0
# DXY_ret_lag1            0.0
# dtype: float64
#                       count      mean       std           min       25%  \
# RESIDUAL_OLS          694.0 -0.000017  0.000959 -5.272469e-03 -0.000543
# RESIDUAL_OLS_lag1     694.0 -0.000015  0.000959 -5.272469e-03 -0.000536
# HIGH_STRESS_lag1      694.0  0.206052  0.404760  0.000000e+00  0.000000
# BTC_DOWNSIDE_24_lag1  694.0  0.000118  0.000164  7.229045e-07  0.000025
# DXY_ret_lag1          694.0  0.000009  0.002043 -1.148698e-02 -0.000661
#
#                            50%       75%       max
# RESIDUAL_OLS          0.000092  0.000596  0.002226
# RESIDUAL_OLS_lag1     0.000097  0.000596  0.002226
# HIGH_STRESS_lag1      0.000000  0.000000  1.000000
# BTC_DOWNSIDE_24_lag1  0.000056  0.000132  0.000784
# DXY_ret_lag1         -0.000020  0.000792  0.010351

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

horizons = [1, 2, 3, 6, 12]
quantiles = [0.1, 0.5, 0.9]

results_base = []

for h in horizons:
    temp = df_dyn.copy()
    temp[f"RESIDUAL_lead_{h}"] = temp["RESIDUAL_OLS"].shift(-h)

    need_cols = [
        f"RESIDUAL_lead_{h}",
        "RESIDUAL_OLS_lag1",
        "HIGH_STRESS_lag1",
        "BTC_DOWNSIDE_24_lag1",
        "DXY_ret_lag1"
    ]
    temp = temp.dropna(subset=need_cols)

    for q in quantiles:
        mod = smf.quantreg(
            f"""
            RESIDUAL_lead_{h} ~
            RESIDUAL_OLS_lag1
            + HIGH_STRESS_lag1
            + BTC_DOWNSIDE_24_lag1
            + BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1
            + DXY_ret_lag1
            + DXY_ret_lag1:HIGH_STRESS_lag1
            """,
            temp
        ).fit(q=q, max_iter=5000)

        results_base.append({
            "h": h,
            "q": q,
            "n": len(temp),
            "beta_dxy": mod.params.get("DXY_ret_lag1", np.nan),
            "beta_dxy_inter": mod.params.get("DXY_ret_lag1:HIGH_STRESS_lag1", np.nan),
            "beta_dxy_stress_total": mod.params.get("DXY_ret_lag1", 0.0)
                                     + mod.params.get("DXY_ret_lag1:HIGH_STRESS_lag1", 0.0),
            "p_dxy": mod.pvalues.get("DXY_ret_lag1", np.nan),
            "p_dxy_inter": mod.pvalues.get("DXY_ret_lag1:HIGH_STRESS_lag1", np.nan)
        })

df_base = pd.DataFrame(results_base)
print(df_base.round(4))
# Out:
#      h    q    n  beta_dxy  beta_dxy_inter  beta_dxy_stress_total   p_dxy  \
# 0    1  0.1  693    0.0063          0.0539                 0.0602  0.8755
# 1    1  0.5  693   -0.0124         -0.0047                -0.0171  0.5652
# 2    1  0.9  693   -0.0195         -0.0089                -0.0284  0.3578
# 3    2  0.1  692    0.0814         -0.1035                -0.0221  0.0015
# 4    2  0.5  692   -0.0081         -0.0227                -0.0308  0.7213
# 5    2  0.9  692   -0.0150         -0.0214                -0.0364  0.6214
# 6    3  0.1  691   -0.0045         -0.0833                -0.0878  0.8415
# 7    3  0.5  691    0.0349         -0.0779                -0.0429  0.1033
# 8    3  0.9  691    0.0324         -0.0150                 0.0174  0.3124
# 9    6  0.1  688    0.0637          0.0253                 0.0890  0.0312
# 10   6  0.5  688    0.0142          0.0321                 0.0463  0.5457
# 11   6  0.9  688   -0.0034         -0.0161                -0.0195  0.9135
# 12  12  0.1  682    0.0294         -0.0198                 0.0096  0.5446
# 13  12  0.5  682    0.0178         -0.0195                -0.0017  0.4480
# 14  12  0.9  682    0.0042          0.0011                 0.0054  0.8400
#
#     p_dxy_inter
# 0        0.3707
# 1        0.9066
# 2        0.9151
# 3        0.1171
# 4        0.5900
# 5        0.6614
# 6        0.0203
# 7        0.0502
# 8        0.7293
# 9        0.6258
# 10       0.4616
# 11       0.7059
# 12       0.8222
# 13       0.6557
# 14       0.9866

# %% [markdown]
# DXY가 residual을 안정적으로 설명한다는 증거는 매우 약하다.
#
# DXY 효과는 존재하더라도 전반적·지배적·안정적 driver라기보다는, 일부 단기 horizon과 특정 tail에서만 약하게 나타나는 보조적 효과에 가깝다.
#
# residual은 단순한 dollar-proxy가 아니다.
#
# 적어도 DXY로는 충분히 설명되지 않는다.

# %% [markdown]
# DXY 수익률을 이용한 quantile-local projection 결과, 달러 측 요인은 스테이블코인 residual의 변동을 전반적으로 안정적으로 설명하지 못하는 것으로 나타났다. 계수는 horizon 및 quantile에 따라 부호가 자주 바뀌며, 대부분 통계적으로 유의하지 않았다. 고스트레스 국면과의 상호작용항 역시 대체로 유의하지 않아, residual이 달러 측 스트레스에 의해 체계적으로 증폭된다고 보기는 어렵다. 다만 일부 단기 하위 분위수에서는 제한적인 유의성이 관찰되었다.

# %%
[c for c in df_dyn.columns if "KRW" in c.upper() or "USD" in c.upper() or "FX" in c.upper() or "EXCHANGE" in c.upper()]
# Out:
# ['USDT_BINANCE_CLOSE',
#  'USDT_UPBIT_CLOSE',
#  'USDKRW',
#  'USDT_KP',
#  'USDT_KP_pct',
#  'XAUUSD',
#  'XAUUSD_ret']

# %%
import numpy as np

df_dyn = df_dyn.copy()
df_dyn["USDKRW_ret"] = np.log(df_dyn["USDKRW"]).diff()

# %%
df_dyn["USDKRW_ret_lag1"] = df_dyn["USDKRW_ret"].shift(1)

# %%
check_cols_fx = [
    "USDKRW",
    "USDKRW_ret",
    "USDKRW_ret_lag1",
    "RESIDUAL_OLS",
    "RESIDUAL_OLS_lag1",
    "HIGH_STRESS_lag1",
    "BTC_DOWNSIDE_24_lag1"
]

print(df_dyn[check_cols_fx].isna().mean().sort_values())
print(df_dyn[check_cols_fx].describe().T)
# Out:
# USDKRW                  0.000000
# RESIDUAL_OLS            0.000000
# RESIDUAL_OLS_lag1       0.000000
# HIGH_STRESS_lag1        0.000000
# BTC_DOWNSIDE_24_lag1    0.000000
# USDKRW_ret              0.001441
# USDKRW_ret_lag1         0.002882
# dtype: float64
#                       count         mean        std           min  \
# USDKRW                694.0  1421.671628  39.688547  1.353360e+03
# USDKRW_ret            693.0     0.000128   0.002978 -2.253561e-02
# USDKRW_ret_lag1       692.0     0.000129   0.002980 -2.253561e-02
# RESIDUAL_OLS          694.0    -0.000017   0.000959 -5.272469e-03
# RESIDUAL_OLS_lag1     694.0    -0.000015   0.000959 -5.272469e-03
# HIGH_STRESS_lag1      694.0     0.206052   0.404760  0.000000e+00
# BTC_DOWNSIDE_24_lag1  694.0     0.000118   0.000164  7.229045e-07
#
#                               25%          50%          75%          max
# USDKRW                1387.812500  1421.945000  1459.740000  1501.790000
# USDKRW_ret              -0.000782     0.000014     0.000994     0.020702
# USDKRW_ret_lag1         -0.000783     0.000017     0.000998     0.020702
# RESIDUAL_OLS            -0.000543     0.000092     0.000596     0.002226
# RESIDUAL_OLS_lag1       -0.000536     0.000097     0.000596     0.002226
# HIGH_STRESS_lag1         0.000000     0.000000     0.000000     1.000000
# BTC_DOWNSIDE_24_lag1     0.000025     0.000056     0.000132     0.000784

# %%
import pandas as pd
import statsmodels.formula.api as smf

horizons = [1, 2, 3, 6, 12]
quantiles = [0.1, 0.5, 0.9]

results_fx = []

for h in horizons:
    temp = df_dyn.copy()
    temp[f"RESIDUAL_lead_{h}"] = temp["RESIDUAL_OLS"].shift(-h)

    need_cols = [
        f"RESIDUAL_lead_{h}",
        "RESIDUAL_OLS_lag1",
        "HIGH_STRESS_lag1",
        "BTC_DOWNSIDE_24_lag1",
        "USDKRW_ret_lag1"
    ]
    temp = temp.dropna(subset=need_cols)

    for q in quantiles:
        mod = smf.quantreg(
            f"""
            RESIDUAL_lead_{h} ~
            RESIDUAL_OLS_lag1
            + HIGH_STRESS_lag1
            + BTC_DOWNSIDE_24_lag1
            + BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1
            + USDKRW_ret_lag1
            + USDKRW_ret_lag1:HIGH_STRESS_lag1
            """,
            temp
        ).fit(q=q, max_iter=5000)

        results_fx.append({
            "h": h,
            "q": q,
            "n": len(temp),
            "beta_fx": mod.params.get("USDKRW_ret_lag1", np.nan),
            "beta_fx_inter": mod.params.get("USDKRW_ret_lag1:HIGH_STRESS_lag1", np.nan),
            "beta_fx_stress_total": mod.params.get("USDKRW_ret_lag1", 0.0)
                                    + mod.params.get("USDKRW_ret_lag1:HIGH_STRESS_lag1", 0.0),
            "p_fx": mod.pvalues.get("USDKRW_ret_lag1", np.nan),
            "p_fx_inter": mod.pvalues.get("USDKRW_ret_lag1:HIGH_STRESS_lag1", np.nan)
        })

df_fx = pd.DataFrame(results_fx)
print(df_fx.round(4))
# Out:
#      h    q    n  beta_fx  beta_fx_inter  beta_fx_stress_total    p_fx  \
# 0    1  0.1  691   0.0161        -0.0079                0.0082  0.5225
# 1    1  0.5  691  -0.0177         0.0248                0.0071  0.2600
# 2    1  0.9  691  -0.0404         0.0205               -0.0199  0.0114
# 3    2  0.1  690   0.0653        -0.1100               -0.0447  0.0062
# 4    2  0.5  690  -0.0093        -0.0145               -0.0238  0.5775
# 5    2  0.9  690  -0.0042        -0.0185               -0.0226  0.8529
# 6    3  0.1  689  -0.0114        -0.0005               -0.0119  0.6030
# 7    3  0.5  689   0.0159         0.0040                0.0199  0.3157
# 8    3  0.9  689   0.0079        -0.0086               -0.0007  0.7783
# 9    6  0.1  686   0.0147         0.0334                0.0482  0.6262
# 10   6  0.5  686   0.0455        -0.0255                0.0200  0.0072
# 11   6  0.9  686   0.0064        -0.0138               -0.0074  0.7239
# 12  12  0.1  680   0.0319        -0.0411               -0.0092  0.3907
# 13  12  0.5  680   0.0192        -0.0505               -0.0313  0.2558
# 14  12  0.9  680   0.0111        -0.0017                0.0094  0.5189
#
#     p_fx_inter
# 0       0.8334
# 1       0.3378
# 2       0.6417
# 3       0.0044
# 4       0.5971
# 5       0.6000
# 6       0.9891
# 7       0.8782
# 8       0.8549
# 9       0.4271
# 10      0.3607
# 11      0.6453
# 12      0.4271
# 13      0.0747
# 14      0.9546

# %% [markdown]
# USDKRW를 이용한 quantile-local projection 결과, 직접 환율 변수는 DXY보다 일부 분위수와 horizon에서 더 유의한 설명력을 보였으나, 그 효과의 부호와 크기는 전반적으로 일관되지 않았다. 또한 고스트레스 국면과의 상호작용 효과 역시 대부분 유의하지 않아, stablecoin residual이 단순한 달러 혹은 환율 요인만으로 체계적으로 설명되지는 않는 것으로 보인다.

# %%
compare_fx_dxy = df_base.merge(df_fx, on=["h", "q"], how="outer")
print(compare_fx_dxy.round(4))
# Out:
#      h    q  n_x  beta_dxy  beta_dxy_inter  beta_dxy_stress_total   p_dxy  \
# 0    1  0.1  693    0.0063          0.0539                 0.0602  0.8755
# 1    1  0.5  693   -0.0124         -0.0047                -0.0171  0.5652
# 2    1  0.9  693   -0.0195         -0.0089                -0.0284  0.3578
# 3    2  0.1  692    0.0814         -0.1035                -0.0221  0.0015
# 4    2  0.5  692   -0.0081         -0.0227                -0.0308  0.7213
# 5    2  0.9  692   -0.0150         -0.0214                -0.0364  0.6214
# 6    3  0.1  691   -0.0045         -0.0833                -0.0878  0.8415
# 7    3  0.5  691    0.0349         -0.0779                -0.0429  0.1033
# 8    3  0.9  691    0.0324         -0.0150                 0.0174  0.3124
# 9    6  0.1  688    0.0637          0.0253                 0.0890  0.0312
# 10   6  0.5  688    0.0142          0.0321                 0.0463  0.5457
# 11   6  0.9  688   -0.0034         -0.0161                -0.0195  0.9135
# 12  12  0.1  682    0.0294         -0.0198                 0.0096  0.5446
# 13  12  0.5  682    0.0178         -0.0195                -0.0017  0.4480
# 14  12  0.9  682    0.0042          0.0011                 0.0054  0.8400
#
#     p_dxy_inter  n_y  beta_fx  beta_fx_inter  beta_fx_stress_total    p_fx  \
# 0        0.3707  691   0.0161        -0.0079                0.0082  0.5225
# 1        0.9066  691  -0.0177         0.0248                0.0071  0.2600
# 2        0.9151  691  -0.0404         0.0205               -0.0199  0.0114
# 3        0.1171  690   0.0653        -0.1100               -0.0447  0.0062
# 4        0.5900  690  -0.0093        -0.0145               -0.0238  0.5775
# 5        0.6614  690  -0.0042        -0.0185               -0.0226  0.8529
# 6        0.0203  689  -0.0114        -0.0005               -0.0119  0.6030
# 7        0.0502  689   0.0159         0.0040                0.0199  0.3157
# 8        0.7293  689   0.0079        -0.0086               -0.0007  0.7783
# 9        0.6258  686   0.0147         0.0334                0.0482  0.6262
# 10       0.4616  686   0.0455        -0.0255                0.0200  0.0072
# 11       0.7059  686   0.0064        -0.0138               -0.0074  0.7239
# 12       0.8222  680   0.0319        -0.0411               -0.0092  0.3907
# 13       0.6557  680   0.0192        -0.0505               -0.0313  0.2558
# 14       0.9866  680   0.0111        -0.0017                0.0094  0.5189
#
#     p_fx_inter
# 0       0.8334
# 1       0.3378
# 2       0.6417
# 3       0.0044
# 4       0.5971
# 5       0.6000
# 6       0.9891
# 7       0.8782
# 8       0.8549
# 9       0.4271
# 10      0.3607
# 11      0.6453
# 12      0.4271
# 13      0.0747
# 14      0.9546

# %%
cols_compare = [
    "h", "q",
    "beta_dxy", "p_dxy", "beta_dxy_inter", "p_dxy_inter", "beta_dxy_stress_total",
    "beta_fx", "p_fx", "beta_fx_inter", "p_fx_inter", "beta_fx_stress_total"
]

print(compare_fx_dxy[cols_compare].round(4))
# Out:
#      h    q  beta_dxy   p_dxy  beta_dxy_inter  p_dxy_inter  \
# 0    1  0.1    0.0063  0.8755          0.0539       0.3707
# 1    1  0.5   -0.0124  0.5652         -0.0047       0.9066
# 2    1  0.9   -0.0195  0.3578         -0.0089       0.9151
# 3    2  0.1    0.0814  0.0015         -0.1035       0.1171
# 4    2  0.5   -0.0081  0.7213         -0.0227       0.5900
# 5    2  0.9   -0.0150  0.6214         -0.0214       0.6614
# 6    3  0.1   -0.0045  0.8415         -0.0833       0.0203
# 7    3  0.5    0.0349  0.1033         -0.0779       0.0502
# 8    3  0.9    0.0324  0.3124         -0.0150       0.7293
# 9    6  0.1    0.0637  0.0312          0.0253       0.6258
# 10   6  0.5    0.0142  0.5457          0.0321       0.4616
# 11   6  0.9   -0.0034  0.9135         -0.0161       0.7059
# 12  12  0.1    0.0294  0.5446         -0.0198       0.8222
# 13  12  0.5    0.0178  0.4480         -0.0195       0.6557
# 14  12  0.9    0.0042  0.8400          0.0011       0.9866
#
#     beta_dxy_stress_total  beta_fx    p_fx  beta_fx_inter  p_fx_inter  \
# 0                  0.0602   0.0161  0.5225        -0.0079      0.8334
# 1                 -0.0171  -0.0177  0.2600         0.0248      0.3378
# 2                 -0.0284  -0.0404  0.0114         0.0205      0.6417
# 3                 -0.0221   0.0653  0.0062        -0.1100      0.0044
# 4                 -0.0308  -0.0093  0.5775        -0.0145      0.5971
# 5                 -0.0364  -0.0042  0.8529        -0.0185      0.6000
# 6                 -0.0878  -0.0114  0.6030        -0.0005      0.9891
# 7                 -0.0429   0.0159  0.3157         0.0040      0.8782
# 8                  0.0174   0.0079  0.7783        -0.0086      0.8549
# 9                  0.0890   0.0147  0.6262         0.0334      0.4271
# 10                 0.0463   0.0455  0.0072        -0.0255      0.3607
# 11                -0.0195   0.0064  0.7239        -0.0138      0.6453
# 12                 0.0096   0.0319  0.3907        -0.0411      0.4271
# 13                -0.0017   0.0192  0.2558        -0.0505      0.0747
# 14                 0.0054   0.0111  0.5189        -0.0017      0.9546
#
#     beta_fx_stress_total
# 0                 0.0082
# 1                 0.0071
# 2                -0.0199
# 3                -0.0447
# 4                -0.0238
# 5                -0.0226
# 6                -0.0119
# 7                 0.0199
# 8                -0.0007
# 9                 0.0482
# 10                0.0200
# 11               -0.0074
# 12               -0.0092
# 13               -0.0313
# 14                0.0094

# %% [markdown]
# # Funding + OI

# %%
import requests
import pandas as pd
import numpy as np
import time

BASE = "https://fapi.binance.com"

def get_json(url, params=None, timeout=20):
    r = requests.get(url, params=params, timeout=timeout)
    r.raise_for_status()
    return r.json()

# 1) Funding rate history
# 공식: GET /fapi/v1/fundingRate
# 최대 1000개, startTime/endTime(ms) 지원
def fetch_funding_rate(symbol="BTCUSDT", start_ms=None, end_ms=None, limit=1000, sleep=0.2):
    out = []
    cur = start_ms

    while True:
        params = {"symbol": symbol, "limit": limit}
        if cur is not None:
            params["startTime"] = cur
        if end_ms is not None:
            params["endTime"] = end_ms

        data = get_json(f"{BASE}/fapi/v1/fundingRate", params=params)
        if not data:
            break

        out.extend(data)

        # 마지막 fundingTime 다음부터 이어받기
        last_t = data[-1]["fundingTime"]
        if len(data) < limit:
            break
        if end_ms is not None and last_t >= end_ms:
            break

        cur = last_t + 1
        time.sleep(sleep)

    df = pd.DataFrame(out)
    if df.empty:
        return df

    df["fundingTime"] = pd.to_datetime(df["fundingTime"], unit="ms", utc=True)
    df["fundingRate"] = pd.to_numeric(df["fundingRate"], errors="coerce")
    return df[["symbol", "fundingTime", "fundingRate"]].drop_duplicates()


# 2) Current open interest snapshot
# 공식: GET /fapi/v1/openInterest
def fetch_open_interest_snapshot(symbol="BTCUSDT"):
    data = get_json(f"{BASE}/fapi/v1/openInterest", params={"symbol": symbol})
    df = pd.DataFrame([data])
    df["time"] = pd.to_datetime(df["time"], unit="ms", utc=True)
    df["openInterest"] = pd.to_numeric(df["openInterest"], errors="coerce")
    return df[["symbol", "time", "openInterest"]]


# 3) Historical open interest statistics
# 공식: GET /futures/data/openInterestHist
# period: "5m","15m","30m","1h","2h","4h","6h","12h","1d"
def fetch_open_interest_hist(symbol="BTCUSDT", period="1h", start_ms=None, end_ms=None, limit=500):
    params = {
        "symbol": symbol,
        "period": period,
        "limit": limit,
    }
    if start_ms is not None:
        params["startTime"] = start_ms
    if end_ms is not None:
        params["endTime"] = end_ms

    data = get_json(f"{BASE}/futures/data/openInterestHist", params=params)
    df = pd.DataFrame(data)
    if df.empty:
        return df

    # Binance 응답 필드명은 문서/버전별로 약간 다를 수 있어 방어적으로 처리
    if "timestamp" in df.columns:
        ts_col = "timestamp"
    elif "time" in df.columns:
        ts_col = "time"
    else:
        raise ValueError(f"Unexpected columns: {df.columns.tolist()}")

    df["datetime"] = pd.to_datetime(df[ts_col], unit="ms", utc=True)

    # 흔히 sumOpenInterest, sumOpenInterestValue가 옴
    for c in ["sumOpenInterest", "sumOpenInterestValue", "CMCCirculatingSupply"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")

    keep = ["symbol", "datetime"]
    for c in ["sumOpenInterest", "sumOpenInterestValue", "CMCCirculatingSupply"]:
        if c in df.columns:
            keep.append(c)

    return df[keep].drop_duplicates().sort_values("datetime")

# %%
start = pd.Timestamp("2025-06-02 09:00:00", tz="UTC")
end   = pd.Timestamp("2026-03-19 12:00:00", tz="UTC")

start_ms = int(start.timestamp() * 1000)
end_ms   = int(end.timestamp() * 1000)

df_funding = fetch_funding_rate(
    symbol="BTCUSDT",
    start_ms=start_ms,
    end_ms=end_ms,
    limit=1000
)

print(df_funding.head())
print(df_funding.tail())
print(len(df_funding))
# Out:
#     symbol                      fundingTime   fundingRate
# 0  BTCUSDT        2025-06-02 16:00:00+00:00  4.467000e-05
# 1  BTCUSDT        2025-06-03 00:00:00+00:00  5.005000e-05
# 2  BTCUSDT        2025-06-03 08:00:00+00:00  6.066000e-05
# 3  BTCUSDT 2025-06-03 16:00:00.001000+00:00  4.456000e-05
# 4  BTCUSDT        2025-06-04 00:00:00+00:00 -1.100000e-07
#       symbol                      fundingTime  fundingRate
# 865  BTCUSDT 2026-03-18 00:00:00.002000+00:00    -0.000066
# 866  BTCUSDT 2026-03-18 08:00:00.002000+00:00    -0.000048
# 867  BTCUSDT 2026-03-18 16:00:00.005000+00:00     0.000024
# 868  BTCUSDT        2026-03-19 00:00:00+00:00    -0.000010
# 869  BTCUSDT 2026-03-19 08:00:00.003000+00:00    -0.000030
# 870

# %% [markdown]
# # Corrected main empirical pipeline
#
# ?? ??? ?? ??? ?? ? ??? ???? ??? ????, ?? ?? ??? ?? ?? ?? ??? ???? ?????.
#
# ?? ??:
# - `USDT_KP ~ MKT_KP_EQ`? ?? ?? ???? ??
# - `RESIDUAL_OLS ~ DEPEG_GLOBAL`? ??? stablecoin depeg proxy ??
# - ?? ?? ?? ??? `RESIDUAL_FINAL` ???? ??
# - ?? ????? ????? lagged downside shock? ?? ??
# - VIX stress regime? tail asymmetry? ???? ?? ?? ???? ??
#
# ??: ?? exploratory cell?? `RESIDUAL_OLS`? ?? ?? ??? ?? ??? ??? robustness ?? ?? ?? ??? ????.

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# =========================================================
# Corrected Step 0: Load existing collected/preprocessed data
# =========================================================
# Data collection cells are intentionally left untouched.
# This file already contains KP, exogenous variables, micro variables, and USDT_BINANCE_CLOSE.
df_main = pd.read_csv(
    "baseline_dataset_with_micro.csv",
    parse_dates=["datetime_utc"],
    index_col="datetime_utc"
)
df_main.index = pd.to_datetime(df_main.index, utc=True)

required_cols = [
    "USDT_KP", "MKT_KP_EQ", "USDT_BINANCE_CLOSE",
    "BTC_DOWNSIDE_24", "DXY_ret", "USDKRW_ret", "VIX"
]
missing = [c for c in required_cols if c not in df_main.columns]
if missing:
    raise KeyError(f"Missing required columns: {missing}")

df_main = df_main.dropna(subset=required_cols).copy()

# =========================================================
# Corrected Step 1: Remove market-common Korean premium
# =========================================================
step1 = df_main[["USDT_KP", "MKT_KP_EQ"]].dropna().copy()
model_market = sm.OLS(
    step1["USDT_KP"],
    sm.add_constant(step1["MKT_KP_EQ"])
).fit(cov_type="HAC", cov_kwds={"maxlags": 5})

df_main["RESIDUAL_OLS"] = np.nan
df_main.loc[step1.index, "RESIDUAL_OLS"] = model_market.resid

# =========================================================
# Corrected Step 2: Remove global stablecoin depeg proxy
# =========================================================
# In the collection block, USDT_BINANCE_CLOSE is Binance USDCUSDT.
# Treat abs(USDCUSDT - 1) as a Binance stablecoin-pair depeg proxy.
df_main["DEPEG_GLOBAL"] = (df_main["USDT_BINANCE_CLOSE"] - 1.0).abs()

step2 = df_main[["RESIDUAL_OLS", "DEPEG_GLOBAL"]].dropna().copy()
model_depeg = sm.OLS(
    step2["RESIDUAL_OLS"],
    sm.add_constant(step2["DEPEG_GLOBAL"])
).fit(cov_type="HAC", cov_kwds={"maxlags": 5})

df_main["RESIDUAL_FINAL"] = np.nan
df_main.loc[step2.index, "RESIDUAL_FINAL"] = model_depeg.resid

# =========================================================
# Corrected Step 3: Lagged variables for main identification
# =========================================================
df_main["RESIDUAL_FINAL_lag1"] = df_main["RESIDUAL_FINAL"].shift(1)
df_main["BTC_DOWNSIDE_24_lag1"] = df_main["BTC_DOWNSIDE_24"].shift(1)
df_main["DXY_ret_lag1"] = df_main["DXY_ret"].shift(1)
df_main["USDKRW_ret_lag1"] = df_main["USDKRW_ret"].shift(1)

# VIX stress regime is a comparison benchmark, not the main identification device.
vix_threshold = df_main["VIX"].quantile(0.80)
df_main["HIGH_STRESS"] = (df_main["VIX"] >= vix_threshold).astype(int)
df_main["HIGH_STRESS_lag1"] = df_main["HIGH_STRESS"].shift(1)

main_cols = [
    "RESIDUAL_FINAL", "RESIDUAL_FINAL_lag1",
    "BTC_DOWNSIDE_24_lag1", "DXY_ret_lag1", "USDKRW_ret_lag1",
    "HIGH_STRESS_lag1"
]
df_emp = df_main.dropna(subset=main_cols).copy()

print("df_emp shape:", df_emp.shape)
print("sample:", df_emp.index.min(), "~", df_emp.index.max())
print("\nStep 1: USDT_KP ~ MKT_KP_EQ")
print(model_market.summary())
print("\nStep 2: RESIDUAL_OLS ~ DEPEG_GLOBAL")
print(model_depeg.summary())

# Save the corrected master dataset for reproducibility.
df_main.index.name = "datetime_utc"
df_main.to_csv("baseline_dataset_with_residual_final.csv")
print("\nSaved: baseline_dataset_with_residual_final.csv")

# %%
# =========================================================
# Corrected main tests
# =========================================================
# Research question: Is the final residual a structured lower-tail response,
# rather than a simple average stress-regime effect?

# 1) Mean response with HAC standard errors
main_formula = (
    "RESIDUAL_FINAL ~ RESIDUAL_FINAL_lag1 "
    "+ BTC_DOWNSIDE_24_lag1 + DXY_ret_lag1 + USDKRW_ret_lag1"
)
model_main_ols = smf.ols(main_formula, data=df_emp).fit(
    cov_type="HAC", cov_kwds={"maxlags": 5}
)
print("===== Main HAC OLS: lagged downside on RESIDUAL_FINAL =====")
print(model_main_ols.summary())

# 2) Tail asymmetry: quantile regression across residual distribution
quantiles = [0.10, 0.25, 0.50, 0.75, 0.90]
quantile_results = []

for q in quantiles:
    mod = smf.quantreg(main_formula, df_emp).fit(q=q, max_iter=5000)
    quantile_results.append({
        "q": q,
        "beta_downside_lag1": mod.params["BTC_DOWNSIDE_24_lag1"],
        "p_downside_lag1": mod.pvalues["BTC_DOWNSIDE_24_lag1"],
        "beta_dxy_lag1": mod.params["DXY_ret_lag1"],
        "p_dxy_lag1": mod.pvalues["DXY_ret_lag1"],
        "beta_fx_lag1": mod.params["USDKRW_ret_lag1"],
        "p_fx_lag1": mod.pvalues["USDKRW_ret_lag1"],
        "n": int(mod.nobs),
    })

quantile_results_df = pd.DataFrame(quantile_results)
print("\n===== Quantile response: tail asymmetry =====")
print(quantile_results_df.round(6))
quantile_results_df.to_csv("corrected_quantile_tail_results.csv", index=False)

# 3) Stress-regime comparison: does VIX high-stress explain more than tail position?
regime_formula = (
    "RESIDUAL_FINAL ~ RESIDUAL_FINAL_lag1 "
    "+ BTC_DOWNSIDE_24_lag1 + HIGH_STRESS_lag1 "
    "+ BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1 "
    "+ DXY_ret_lag1 + USDKRW_ret_lag1"
)
regime_results = []

for q in [0.10, 0.50, 0.90]:
    mod = smf.quantreg(regime_formula, df_emp).fit(q=q, max_iter=5000)
    interaction = "BTC_DOWNSIDE_24_lag1:HIGH_STRESS_lag1"
    regime_results.append({
        "q": q,
        "beta_downside_normal": mod.params["BTC_DOWNSIDE_24_lag1"],
        "beta_downside_stress_total": mod.params["BTC_DOWNSIDE_24_lag1"] + mod.params[interaction],
        "p_downside_stress_interaction": mod.pvalues[interaction],
        "n": int(mod.nobs),
    })

regime_results_df = pd.DataFrame(regime_results)
print("\n===== Stress-regime comparison =====")
print(regime_results_df.round(6))
regime_results_df.to_csv("corrected_regime_tail_compare.csv", index=False)

# 4) Local projection version for persistence over horizons
horizons = [1, 2, 3, 6, 12]
lp_results = []

for h in horizons:
    temp = df_emp.copy()
    temp[f"RESIDUAL_FINAL_lead_{h}"] = temp["RESIDUAL_FINAL"].shift(-h)
    temp = temp.dropna(subset=[f"RESIDUAL_FINAL_lead_{h}"])

    lp_formula = (
        f"RESIDUAL_FINAL_lead_{h} ~ RESIDUAL_FINAL_lag1 "
        "+ BTC_DOWNSIDE_24_lag1 + DXY_ret_lag1 + USDKRW_ret_lag1"
    )

    for q in [0.10, 0.50, 0.90]:
        mod = smf.quantreg(lp_formula, temp).fit(q=q, max_iter=5000)
        lp_results.append({
            "h": h,
            "q": q,
            "beta_downside_lag1": mod.params["BTC_DOWNSIDE_24_lag1"],
            "p_downside_lag1": mod.pvalues["BTC_DOWNSIDE_24_lag1"],
            "n": int(mod.nobs),
        })

lp_results_df = pd.DataFrame(lp_results)
print("\n===== Quantile local projection =====")
print(lp_results_df.round(6))
lp_results_df.to_csv("corrected_quantile_local_projection.csv", index=False)

print("\nSaved:")
print("- corrected_quantile_tail_results.csv")
print("- corrected_regime_tail_compare.csv")
print("- corrected_quantile_local_projection.csv")
